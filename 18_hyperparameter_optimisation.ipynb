# %%
import pandas as pd
from xgboost import XGBClassifier
from sklearn import preprocessing
from sklearn.model_selection import GridSearchCV

# %%
X = pd.read_csv("data/17_selected_features_trainset.tsv", sep="\t")
y = X.pop("class")

# %%
le = preprocessing.LabelEncoder()
le.fit(X["splice_site"])
X["splice_site"] = le.transform(X["splice_site"])

X
# Out:
#         recount3_score  antisense_exon_start_ss  antisense_exon_end_ss  \
# 0                59151                    False                  False
# 1                61021                    False                  False
# 2                   21                    False                  False
# 3                  526                    False                  False
# 4                    0                    False                  False
# ...                ...                      ...                    ...
# 484602               0                    False                  False
# 484603           31374                    False                  False
# 484604              67                    False                  False
# 484605           18958                    False                  False
# 484606               0                    False                  False
#
#         nearest_alt_start_ss_dist  nearest_alt_end_ss_dist  \
# 0                             170                      362
# 1                              24                      232
# 2                              24                      246
# 3                             322                      232
# 4                             322                      232
# ...                           ...                      ...
# 484602                        487                       25
# 484603                        777                      464
# 484604                        572                     2963
# 484605                       1178                        2
# 484606                        232                       24
#
#         MaxEntScan_start_ss  MaxEntScan_end_ss  CpG_island  intron_length  \
# 0                      9.09              11.90       False            385
# 1                      7.66               3.89       False            499
# 2                      7.15               7.61       False            277
# 3                      1.14               3.89       False            168
# 4                    -12.10               7.63       False             78
# ...                     ...                ...         ...            ...
# 484602               -19.72               3.66        True            909
# 484603                 9.21              13.74       False            415
# 484604                 8.56               2.38       False           2970
# 484605               -12.64               5.91       False           2358
# 484606                 7.66               3.89       False            498
#
#         phyloP_score  ...  repeat_features_start_site_Satellite repeats  \
# 0            5.65175  ...                                             0
# 1            1.40575  ...                                             0
# 2            5.75650  ...                                             0
# 3            5.35750  ...                                             0
# 4            3.62350  ...                                             0
# ...              ...  ...                                           ...
# 484602       0.58700  ...                                             0
# 484603       2.74250  ...                                             0
# 484604      -0.89575  ...                                             0
# 484605       2.41200  ...                                             0
# 484606       2.04075  ...                                             0
#
#         repeat_features_start_site_Unknown  \
# 0                                        0
# 1                                        0
# 2                                        0
# 3                                        0
# 4                                        0
# ...                                    ...
# 484602                                   0
# 484603                                   0
# 484604                                   0
# 484605                                   0
# 484606                                   0
#
#         repeat_features_start_site_Type II Transposons  \
# 0                                                    0
# 1                                                    0
# 2                                                    0
# 3                                                    0
# 4                                                    0
# ...                                                ...
# 484602                                               0
# 484603                                               0
# 484604                                               0
# 484605                                               0
# 484606                                               0
#
#         repeat_features_end_site_Tandem repeats  \
# 0                                             0
# 1                                             0
# 2                                             0
# 3                                             0
# 4                                             0
# ...                                         ...
# 484602                                        0
# 484603                                        0
# 484604                                        0
# 484605                                        0
# 484606                                        0
#
#         repeat_features_end_site_LTRs  \
# 0                                   0
# 1                                   0
# 2                                   0
# 3                                   0
# 4                                   0
# ...                               ...
# 484602                              0
# 484603                              0
# 484604                              0
# 484605                              0
# 484606                              0
#
#         repeat_features_end_site_Type I Transposons/SINE  \
# 0                                                      0
# 1                                                      0
# 2                                                      0
# 3                                                      0
# 4                                                      0
# ...                                                  ...
# 484602                                                 0
# 484603                                                 0
# 484604                                                 0
# 484605                                                 0
# 484606                                                 0
#
#         repeat_features_end_site_Satellite repeats  \
# 0                                                0
# 1                                                0
# 2                                                0
# 3                                                0
# 4                                                0
# ...                                            ...
# 484602                                           0
# 484603                                           0
# 484604                                           0
# 484605                                           0
# 484606                                           0
#
#         repeat_features_end_site_Type I Transposons/LINE  splice_site  \
# 0                                                      0            2
# 1                                                      0            2
# 2                                                      0            2
# 3                                                      0            1
# 4                                                      0            2
# ...                                                  ...          ...
# 484602                                                 0            2
# 484603                                                 0            2
# 484604                                                 0            2
# 484605                                                 0            2
# 484606                                                 0            2
#
#         repeat_features_start_site_Type I Transposons/SINE
# 0                                                       0
# 1                                                       0
# 2                                                       0
# 3                                                       0
# 4                                                       0
# ...                                                   ...
# 484602                                                  0
# 484603                                                  0
# 484604                                                  0
# 484605                                                  0
# 484606                                                  0
#
# [484607 rows x 26 columns]

# %%
X = X.fillna(0)

# %%
# %%time
from bayes_opt import BayesianOptimization
parameter_grid = {
    'n_estimators': [50, 100, 150, 200],
    'learning_rate': [0.01, 0.1, 0.2, 0.3],
    'max_depth': [5, 6, 7],
    'min_child_weight': [1, 3, 5],
    'subsample': [0.8, 0.9, 1.0],
    'colsample_bytree': [0.8, 0.9, 1.0]
}

model = XGBClassifier(tree_method="gpu_hist")

grid_search = GridSearchCV(model, parameter_grid, scoring="matthews_corrcoef", cv=3, verbose=1, n_jobs=12)

grid_search.fit(X, y)
# Out:
# Fitting 3 folds for each of 1296 candidates, totalling 3888 fits
# CPU times: user 11.5 s, sys: 1.23 s, total: 12.7 s
# Wall time: 1h 5min 13s
# GridSearchCV(cv=3,
#              estimator=XGBClassifier(base_score=None, booster=None,
#                                      callbacks=None, colsample_bylevel=None,
#                                      colsample_bynode=None,
#                                      colsample_bytree=None,
#                                      early_stopping_rounds=None,
#                                      enable_categorical=False, eval_metric=None,
#                                      gamma=None, gpu_id=None, grow_policy=None,
#                                      importance_type=None,
#                                      interaction_constraints=None,
#                                      learning_rate=None, max_bin=None,
#                                      max_ca...
#                                      n_estimators=100, n_jobs=None,
#                                      num_parallel_tree=None, predictor=None,
#                                      random_state=None, reg_alpha=None,
#                                      reg_lambda=None, ...),
#              n_jobs=12,
#              param_grid={'colsample_bytree': [0.8, 0.9, 1.0],
#                          'learning_rate': [0.01, 0.1, 0.2, 0.3],
#                          'max_depth': [5, 6, 7], 'min_child_weight': [1, 3, 5],
#                          'n_estimators': [50, 100, 150, 200],
#                          'subsample': [0.8, 0.9, 1.0]},
#              scoring='matthews_corrcoef', verbose=1)

# %%
df_grid_search_result = pd.DataFrame(grid_search.cv_results_)
df_grid_search_result.to_csv("data/18_hyperparameter_opt_result.tsv", sep="\t")
df_grid_search_result
# Out:
#       mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0          4.502714      0.001570         0.271742        0.012913
# 1          4.463886      0.054376         0.292894        0.015541
# 2          3.944259      0.563497         0.263358        0.014848
# 3          5.736898      0.092272         0.298172        0.028339
# 4          5.430502      0.700245         0.310719        0.002166
# ...             ...           ...              ...             ...
# 1291      18.302688      0.218331         0.497518        0.000931
# 1292      18.025753      0.424667         0.444883        0.030711
# 1293      20.833965      0.317261         0.424439        0.019300
# 1294      17.223778      0.386428         0.412365        0.015024
# 1295      14.639879      0.462648         0.405718        0.011408
#
#      param_colsample_bytree param_learning_rate param_max_depth  \
# 0                       0.8                0.01               5
# 1                       0.8                0.01               5
# 2                       0.8                0.01               5
# 3                       0.8                0.01               5
# 4                       0.8                0.01               5
# ...                     ...                 ...             ...
# 1291                    1.0                 0.3               7
# 1292                    1.0                 0.3               7
# 1293                    1.0                 0.3               7
# 1294                    1.0                 0.3               7
# 1295                    1.0                 0.3               7
#
#      param_min_child_weight param_n_estimators param_subsample  \
# 0                         1                 50             0.8
# 1                         1                 50             0.9
# 2                         1                 50             1.0
# 3                         1                100             0.8
# 4                         1                100             0.9
# ...                     ...                ...             ...
# 1291                      5                150             0.9
# 1292                      5                150             1.0
# 1293                      5                200             0.8
# 1294                      5                200             0.9
# 1295                      5                200             1.0
#
#                                                  params  split0_test_score  \
# 0     {'colsample_bytree': 0.8, 'learning_rate': 0.0...           0.860016
# 1     {'colsample_bytree': 0.8, 'learning_rate': 0.0...           0.859641
# 2     {'colsample_bytree': 0.8, 'learning_rate': 0.0...           0.859675
# 3     {'colsample_bytree': 0.8, 'learning_rate': 0.0...           0.861579
# 4     {'colsample_bytree': 0.8, 'learning_rate': 0.0...           0.861199
# ...                                                 ...                ...
# 1291  {'colsample_bytree': 1.0, 'learning_rate': 0.3...           0.883443
# 1292  {'colsample_bytree': 1.0, 'learning_rate': 0.3...           0.883171
# 1293  {'colsample_bytree': 1.0, 'learning_rate': 0.3...           0.882202
# 1294  {'colsample_bytree': 1.0, 'learning_rate': 0.3...           0.883590
# 1295  {'colsample_bytree': 1.0, 'learning_rate': 0.3...           0.882307
#
#       split1_test_score  split2_test_score  mean_test_score  std_test_score  \
# 0              0.894865           0.790842         0.848574        0.043231
# 1              0.895526           0.789940         0.848369        0.043836
# 2              0.895387           0.790379         0.848480        0.043594
# 3              0.897349           0.795451         0.851460        0.042211
# 4              0.897245           0.794912         0.851118        0.042381
# ...                 ...                ...              ...             ...
# 1291           0.913408           0.807783         0.868211        0.044446
# 1292           0.913421           0.809499         0.868697        0.043643
# 1293           0.913004           0.807630         0.867612        0.044239
# 1294           0.911889           0.806607         0.867362        0.044487
# 1295           0.912627           0.809116         0.868016        0.043450
#
#       rank_test_score
# 0                1254
# 1                1260
# 2                1258
# 3                1215
# 4                1230
# ...               ...
# 1291              601
# 1292              474
# 1293              752
# 1294              791
# 1295              655
#
# [1296 rows x 17 columns]

# %%
print("Best Parameters:\n", grid_search.best_params_)
# Out:
# Best Parameters:
#  {'colsample_bytree': 0.9, 'learning_rate': 0.1, 'max_depth': 7, 'min_child_weight': 5, 'n_estimators': 200, 'subsample': 0.9}
