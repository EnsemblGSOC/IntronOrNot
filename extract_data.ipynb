# %%
import numpy as np
import scipy as sp
import Bio
from tqdm import tqdm
import pandas as pd

# %%
trna_counter = []
gene_counter = []

with open('./ftp-data/gencode.v44.annotation.gtf') as topo_file:
    # counter = 0
    for line in topo_file:

        if line.startswith("#"):
            continue
        columns = line.split(sep="\t")
        feature_type = columns[2]
        length = int(columns[4])-int(columns[3])

        if feature_type == "tRNA":
            trna_counter.append(length)
        elif feature_type == "gene":
            gene_counter.append(length)

# %%
len(gene_counter)
# Out:
# 62700

# %%
from BCBio.GFF import GFFExaminer

in_file = "./ftp-data/gencode.v44.annotation.gtf"
examiner = GFFExaminer()

# %%
examiner.available_limits(in_file)
# Out:
# {'gff_id': {('chr1',): 317470,
#   ('chr2',): 259975,
#   ('chr3',): 222905,
#   ('chr4',): 142001,
#   ('chr5',): 154025,
#   ('chr6',): 162467,
#   ('chr7',): 162555,
#   ('chr8',): 124698,
#   ('chr9',): 129496,
#   ('chr10',): 135061,
#   ('chr11',): 202627,
#   ('chr12',): 188637,
#   ('chr13',): 56972,
#   ('chr14',): 122480,
#   ('chr15',): 120500,
#   ('chr16',): 151172,
#   ('chr17',): 204071,
#   ('chr18',): 57932,
#   ('chr19',): 188662,
#   ('chr20',): 80173,
#   ('chr21',): 38256,
#   ('chr22',): 71439,
#   ('chrX',): 120574,
#   ('chrY',): 9898,
#   ('chrM',): 143},
#  'gff_source_type': {('HAVANA', 'gene'): 55120,
#   ('HAVANA', 'transcript'): 241005,
#   ('HAVANA', 'exon'): 1598650,
#   ('ENSEMBL', 'gene'): 7580,
#   ('ENSEMBL', 'transcript'): 11830,
#   ('ENSEMBL', 'exon'): 50826,
#   ('HAVANA', 'CDS'): 847237,
#   ('HAVANA', 'start_codon'): 93933,
#   ('HAVANA', 'stop_codon'): 87801,
#   ('HAVANA', 'UTR'): 371663,
#   ('ENSEMBL', 'CDS'): 37872,
#   ('ENSEMBL', 'start_codon'): 4029,
#   ('ENSEMBL', 'stop_codon'): 4034,
#   ('ENSEMBL', 'UTR'): 12479,
#   ('HAVANA', 'Selenocysteine'): 130},
#  'gff_source': {('HAVANA',): 3295539, ('ENSEMBL',): 128650},
#  'gff_type': {('gene',): 62700,
#   ('transcript',): 252835,
#   ('exon',): 1649476,
#   ('CDS',): 885109,
#   ('start_codon',): 97962,
#   ('stop_codon',): 91835,
#   ('UTR',): 384142,
#   ('Selenocysteine',): 130}}

# %%
from pprint import pprint
from BCBio import GFF

current_gene = None
last_index = None
introns_lst = []
with open(in_file) as handle:
    for rec in GFF.parse(handle, target_lines=100):
        for feature in rec.features:
            if feature.type == "gene":
                print(feature)
                pprint(vars(feature))

                # Access gene attributes using feature qualifiers
                gene_id = feature.qualifiers.get("gene_id", [""])[0]
                gene_name = feature.qualifiers.get("gene_name", [""])[0]
                gene_type = feature.qualifiers.get("gene_type", [""])[0]
                gene_start = feature.location.start.position
                gene_end = feature.location.end.position

                current_gene = gene_id
                # last_index = gene_end
                # Do something with the gene information
                # print(feature.)
                print("Gene ID:", gene_id)
                print("Gene Name:", gene_name)
                print("Gene Type:", gene_type)
                print("Gene Start:", gene_start)
                print("Gene Ends:", gene_end)
                print("-------------------------")
                # print("SUB", GFF.(feature))

            if feature.type == "exon":
                if last_index:
                    intron_dict = {
                        "gene_id": gene_id,
                        "intron_start": last_index+1,
                        "intron_ends": gene_start-1,
                    }
                    introns_lst.append(intron_dict)
                last_index = gene_end
                print("last_index", last_index)


        break

introns_lst
# Out:
# type: gene
# location: [11868:14409](+)
# qualifiers:
#     Key: gene_id, Value: ['ENSG00000290825.1']
#     Key: gene_name, Value: ['DDX11L2']
#     Key: gene_type, Value: ['lncRNA']
#     Key: level, Value: ['2']
#     Key: source, Value: ['HAVANA']
#     Key: tag, Value: ['overlaps_pseudogene']
#
# {'id': '',
#  'location': SimpleLocation(ExactPosition(11868), ExactPosition(14409), strand=1),
#  'qualifiers': {'gene_id': ['ENSG00000290825.1'],
#                 'gene_name': ['DDX11L2'],
#                 'gene_type': ['lncRNA'],
#                 'level': ['2'],
#                 'source': ['HAVANA'],
#                 'tag': ['overlaps_pseudogene']},
#  'sub_features': [],
#  'type': 'gene'}
# Gene ID: ENSG00000290825.1
# Gene Name: DDX11L2
# Gene Type: lncRNA
# Gene Start: 11868
# Gene Ends: 14409
# -------------------------
# type: gene
# location: [12009:13670](+)
# qualifiers:
#     Key: gene_id, Value: ['ENSG00000223972.6']
#     Key: gene_name, Value: ['DDX11L1']
#     Key: gene_type, Value: ['transcribed_unprocessed_pseudogene']
#     Key: havana_gene, Value: ['OTTHUMG00000000961.2']
#     Key: hgnc_id, Value: ['HGNC:37102']
#     Key: level, Value: ['2']
#     Key: source, Value: ['HAVANA']
#
# {'id': '',
#  'location': SimpleLocation(ExactPosition(12009), ExactPosition(13670), strand=1),
#  'qualifiers': {'gene_id': ['ENSG00000223972.6'],
#                 'gene_name': ['DDX11L1'],
#                 'gene_type': ['transcribed_unprocessed_pseudogene'],
#                 'havana_gene': ['OTTHUMG00000000961.2'],
#                 'hgnc_id': ['HGNC:37102'],
#                 'level': ['2'],
#                 'source': ['HAVANA']},
#  'sub_features': [],
#  'type': 'gene'}
# Gene ID: ENSG00000223972.6
# Gene Name: DDX11L1
# Gene Type: transcribed_unprocessed_pseudogene
# Gene Start: 12009
# Gene Ends: 13670
# -------------------------
# type: gene
# location: [14403:29570](-)
# qualifiers:
#     Key: gene_id, Value: ['ENSG00000227232.5']
#     Key: gene_name, Value: ['WASH7P']
#     Key: gene_type, Value: ['unprocessed_pseudogene']
#     Key: havana_gene, Value: ['OTTHUMG00000000958.1']
#     Key: hgnc_id, Value: ['HGNC:38034']
#     Key: level, Value: ['2']
#     Key: source, Value: ['HAVANA']
#
# {'id': '',
#  'location': SimpleLocation(ExactPosition(14403), ExactPosition(29570), strand=-1),
#  'qualifiers': {'gene_id': ['ENSG00000227232.5'],
#                 'gene_name': ['WASH7P'],
#                 'gene_type': ['unprocessed_pseudogene'],
#                 'havana_gene': ['OTTHUMG00000000958.1'],
#                 'hgnc_id': ['HGNC:38034'],
#                 'level': ['2'],
#                 'source': ['HAVANA']},
#  'sub_features': [],
#  'type': 'gene'}
# Gene ID: ENSG00000227232.5
# Gene Name: WASH7P
# Gene Type: unprocessed_pseudogene
# Gene Start: 14403
# Gene Ends: 29570
# -------------------------
# type: gene
# location: [17368:17436](-)
# qualifiers:
#     Key: gene_id, Value: ['ENSG00000278267.1']
#     Key: gene_name, Value: ['MIR6859-1']
#     Key: gene_type, Value: ['miRNA']
#     Key: hgnc_id, Value: ['HGNC:50039']
#     Key: level, Value: ['3']
#     Key: source, Value: ['ENSEMBL']
#
# {'id': '',
#  'location': SimpleLocation(ExactPosition(17368), ExactPosition(17436), strand=-1),
#  'qualifiers': {'gene_id': ['ENSG00000278267.1'],
#                 'gene_name': ['MIR6859-1'],
#                 'gene_type': ['miRNA'],
#                 'hgnc_id': ['HGNC:50039'],
#                 'level': ['3'],
#                 'source': ['ENSEMBL']},
#  'sub_features': [],
#  'type': 'gene'}
# Gene ID: ENSG00000278267.1
# Gene Name: MIR6859-1
# Gene Type: miRNA
# Gene Start: 17368
# Gene Ends: 17436
# -------------------------
# type: gene
# location: [29553:31109](+)
# qualifiers:
#     Key: gene_id, Value: ['ENSG00000243485.5']
#     Key: gene_name, Value: ['MIR1302-2HG']
#     Key: gene_type, Value: ['lncRNA']
#     Key: havana_gene, Value: ['OTTHUMG00000000959.2']
#     Key: hgnc_id, Value: ['HGNC:52482']
#     Key: level, Value: ['2']
#     Key: source, Value: ['HAVANA']
#     Key: tag, Value: ['ncRNA_host']
#
# {'id': '',
#  'location': SimpleLocation(ExactPosition(29553), ExactPosition(31109), strand=1),
#  'qualifiers': {'gene_id': ['ENSG00000243485.5'],
#                 'gene_name': ['MIR1302-2HG'],
#                 'gene_type': ['lncRNA'],
#                 'havana_gene': ['OTTHUMG00000000959.2'],
#                 'hgnc_id': ['HGNC:52482'],
#                 'level': ['2'],
#                 'source': ['HAVANA'],
#                 'tag': ['ncRNA_host']},
#  'sub_features': [],
#  'type': 'gene'}
# Gene ID: ENSG00000243485.5
# Gene Name: MIR1302-2HG
# Gene Type: lncRNA
# Gene Start: 29553
# Gene Ends: 31109
# -------------------------
# type: gene
# location: [30365:30503](+)
# qualifiers:
#     Key: gene_id, Value: ['ENSG00000284332.1']
#     Key: gene_name, Value: ['MIR1302-2']
#     Key: gene_type, Value: ['miRNA']
#     Key: hgnc_id, Value: ['HGNC:35294']
#     Key: level, Value: ['3']
#     Key: source, Value: ['ENSEMBL']
#
# {'id': '',
#  'location': SimpleLocation(ExactPosition(30365), ExactPosition(30503), strand=1),
#  'qualifiers': {'gene_id': ['ENSG00000284332.1'],
#                 'gene_name': ['MIR1302-2'],
#                 'gene_type': ['miRNA'],
#                 'hgnc_id': ['HGNC:35294'],
#                 'level': ['3'],
#                 'source': ['ENSEMBL']},
#  'sub_features': [],
#  'type': 'gene'}
# Gene ID: ENSG00000284332.1
# Gene Name: MIR1302-2
# Gene Type: miRNA
# Gene Start: 30365
# Gene Ends: 30503
# -------------------------
# type: gene
# location: [34553:36081](-)
# qualifiers:
#     Key: gene_id, Value: ['ENSG00000237613.2']
#     Key: gene_name, Value: ['FAM138A']
#     Key: gene_type, Value: ['lncRNA']
#     Key: havana_gene, Value: ['OTTHUMG00000000960.1']
#     Key: hgnc_id, Value: ['HGNC:32334']
#     Key: level, Value: ['2']
#     Key: source, Value: ['HAVANA']
#
# {'id': '',
#  'location': SimpleLocation(ExactPosition(34553), ExactPosition(36081), strand=-1),
#  'qualifiers': {'gene_id': ['ENSG00000237613.2'],
#                 'gene_name': ['FAM138A'],
#                 'gene_type': ['lncRNA'],
#                 'havana_gene': ['OTTHUMG00000000960.1'],
#                 'hgnc_id': ['HGNC:32334'],
#                 'level': ['2'],
#                 'source': ['HAVANA']},
#  'sub_features': [],
#  'type': 'gene'}
# Gene ID: ENSG00000237613.2
# Gene Name: FAM138A
# Gene Type: lncRNA
# Gene Start: 34553
# Gene Ends: 36081
# -------------------------
# type: gene
# location: [52472:53312](+)
# qualifiers:
#     Key: gene_id, Value: ['ENSG00000268020.3']
#     Key: gene_name, Value: ['OR4G4P']
#     Key: gene_type, Value: ['unprocessed_pseudogene']
#     Key: havana_gene, Value: ['OTTHUMG00000185779.1']
#     Key: hgnc_id, Value: ['HGNC:14822']
#     Key: level, Value: ['2']
#     Key: source, Value: ['HAVANA']
#
# {'id': '',
#  'location': SimpleLocation(ExactPosition(52472), ExactPosition(53312), strand=1),
#  'qualifiers': {'gene_id': ['ENSG00000268020.3'],
#                 'gene_name': ['OR4G4P'],
#                 'gene_type': ['unprocessed_pseudogene'],
#                 'havana_gene': ['OTTHUMG00000185779.1'],
#                 'hgnc_id': ['HGNC:14822'],
#                 'level': ['2'],
#                 'source': ['HAVANA']},
#  'sub_features': [],
#  'type': 'gene'}
# Gene ID: ENSG00000268020.3
# Gene Name: OR4G4P
# Gene Type: unprocessed_pseudogene
# Gene Start: 52472
# Gene Ends: 53312
# -------------------------
# type: gene
# location: [57597:64116](+)
# qualifiers:
#     Key: gene_id, Value: ['ENSG00000290826.1']
#     Key: gene_name, Value: ['ENSG00000290826']
#     Key: gene_type, Value: ['lncRNA']
#     Key: level, Value: ['2']
#     Key: source, Value: ['HAVANA']
#     Key: tag, Value: ['overlaps_pseudogene']
#
# {'id': '',
#  'location': SimpleLocation(ExactPosition(57597), ExactPosition(64116), strand=1),
#  'qualifiers': {'gene_id': ['ENSG00000290826.1'],
#                 'gene_name': ['ENSG00000290826'],
#                 'gene_type': ['lncRNA'],
#                 'level': ['2'],
#                 'source': ['HAVANA'],
#                 'tag': ['overlaps_pseudogene']},
#  'sub_features': [],
#  'type': 'gene'}
# Gene ID: ENSG00000290826.1
# Gene Name: ENSG00000290826
# Gene Type: lncRNA
# Gene Start: 57597
# Gene Ends: 64116
# -------------------------
# type: gene
# location: [62948:63887](+)
# qualifiers:
#     Key: gene_id, Value: ['ENSG00000240361.3']
#     Key: gene_name, Value: ['OR4G11P']
#     Key: gene_type, Value: ['transcribed_unprocessed_pseudogene']
#     Key: havana_gene, Value: ['OTTHUMG00000001095.3']
#     Key: hgnc_id, Value: ['HGNC:31276']
#     Key: level, Value: ['2']
#     Key: source, Value: ['HAVANA']
#
# {'id': '',
#  'location': SimpleLocation(ExactPosition(62948), ExactPosition(63887), strand=1),
#  'qualifiers': {'gene_id': ['ENSG00000240361.3'],
#                 'gene_name': ['OR4G11P'],
#                 'gene_type': ['transcribed_unprocessed_pseudogene'],
#                 'havana_gene': ['OTTHUMG00000001095.3'],
#                 'hgnc_id': ['HGNC:31276'],
#                 'level': ['2'],
#                 'source': ['HAVANA']},
#  'sub_features': [],
#  'type': 'gene'}
# Gene ID: ENSG00000240361.3
# Gene Name: OR4G11P
# Gene Type: transcribed_unprocessed_pseudogene
# Gene Start: 62948
# Gene Ends: 63887
# -------------------------
# type: gene
# location: [65418:71585](+)
# qualifiers:
#     Key: gene_id, Value: ['ENSG00000186092.7']
#     Key: gene_name, Value: ['OR4F5']
#     Key: gene_type, Value: ['protein_coding']
#     Key: havana_gene, Value: ['OTTHUMG00000001094.4']
#     Key: hgnc_id, Value: ['HGNC:14825']
#     Key: level, Value: ['2']
#     Key: source, Value: ['HAVANA']
#
# {'id': '',
#  'location': SimpleLocation(ExactPosition(65418), ExactPosition(71585), strand=1),
#  'qualifiers': {'gene_id': ['ENSG00000186092.7'],
#                 'gene_name': ['OR4F5'],
#                 'gene_type': ['protein_coding'],
#                 'havana_gene': ['OTTHUMG00000001094.4'],
#                 'hgnc_id': ['HGNC:14825'],
#                 'level': ['2'],
#                 'source': ['HAVANA']},
#  'sub_features': [],
#  'type': 'gene'}
# Gene ID: ENSG00000186092.7
# Gene Name: OR4F5
# Gene Type: protein_coding
# Gene Start: 65418
# Gene Ends: 71585
# -------------------------
# type: gene
# location: [89294:133723](-)
# qualifiers:
#     Key: gene_id, Value: ['ENSG00000238009.6']
#     Key: gene_name, Value: ['ENSG00000238009']
#     Key: gene_type, Value: ['lncRNA']
#     Key: havana_gene, Value: ['OTTHUMG00000001096.2']
#     Key: level, Value: ['2']
#     Key: source, Value: ['HAVANA']
#     Key: tag, Value: ['overlapping_locus']
#
# {'id': '',
#  'location': SimpleLocation(ExactPosition(89294), ExactPosition(133723), strand=-1),
#  'qualifiers': {'gene_id': ['ENSG00000238009.6'],
#                 'gene_name': ['ENSG00000238009'],
#                 'gene_type': ['lncRNA'],
#                 'havana_gene': ['OTTHUMG00000001096.2'],
#                 'level': ['2'],
#                 'source': ['HAVANA'],
#                 'tag': ['overlapping_locus']},
#  'sub_features': [],
#  'type': 'gene'}
# Gene ID: ENSG00000238009.6
# Gene Name: ENSG00000238009
# Gene Type: lncRNA
# Gene Start: 89294
# Gene Ends: 133723
# -------------------------
# type: gene
# location: [89550:91105](-)
# qualifiers:
#     Key: gene_id, Value: ['ENSG00000239945.1']
#     Key: gene_name, Value: ['ENSG00000239945']
#     Key: gene_type, Value: ['lncRNA']
#     Key: havana_gene, Value: ['OTTHUMG00000001097.2']
#     Key: level, Value: ['2']
#     Key: source, Value: ['HAVANA']
#     Key: tag, Value: ['overlapping_locus']
#
# {'id': '',
#  'location': SimpleLocation(ExactPosition(89550), ExactPosition(91105), strand=-1),
#  'qualifiers': {'gene_id': ['ENSG00000239945.1'],
#                 'gene_name': ['ENSG00000239945'],
#                 'gene_type': ['lncRNA'],
#                 'havana_gene': ['OTTHUMG00000001097.2'],
#                 'level': ['2'],
#                 'source': ['HAVANA'],
#                 'tag': ['overlapping_locus']},
#  'sub_features': [],
#  'type': 'gene'}
# Gene ID: ENSG00000239945.1
# Gene Name: ENSG00000239945
# Gene Type: lncRNA
# Gene Start: 89550
# Gene Ends: 91105
# -------------------------
# []

# %%
from pprint import pprint
from BCBio import GFF

limit_info = {"gff_type": ["transcript", "exon"]}
current_gene = None
last_index = None
introns_lst = []
with open(in_file) as handle:
    for rec in GFF.parse(handle, limit_info=limit_info, target_lines=100):
        for feature in rec.features:
            # pprint(vars(feature))
            loop = feature.sub_features if feature.strand == 1 else feature.sub_features[::-1]
            for sub_features in loop:
                # print("sub_features:::\n", sub_features)
                if sub_features.type == "transcript":
                    intron_id = 0
                    ene_id = feature.qualifiers.get("transcript_id", [""])[0]
                    transcript_name = feature.qualifiers.get("transcript_name", [""])[0]
                    # transcript_type = feature.qualifiers.get("transcript_type", [""])[0]
                    transcript_start = feature.location.start.position
                    transcript_end = feature.location.end.position
                    last_index = transcript_start
                    previous_exon_name = "Start-" + transcript_name

                if sub_features.type == "exon":
                    # pprint(vars(sub_features))
                    if last_index != sub_features.location.start.position:
                        intron_dict = {
                            "gene_id": sub_features.qualifiers["gene_id"][0],
                            "transcript_id": sub_features.qualifiers["transcript_id"][0],
                            "intron_id": intron_id,
                            "intron_start": last_index,
                            "intron_ends": sub_features.location.start.position,
                            "prev_exon_id": previous_exon_name,
                            "next_exon_id": sub_features.qualifiers["exon_id"][0]
                        }
                        introns_lst.append(intron_dict)
                        intron_id += 1

                    last_index = sub_features.location.end.position
                    previous_exon_name = sub_features.qualifiers["exon_id"][0]
introns_lst
# Out:
# [{'gene_id': 'ENSG00000290825.1',
#   'transcript_id': 'ENST00000456328.2',
#   'intron_id': 0,
#   'intron_start': 12227,
#   'intron_ends': 12612,
#   'prev_exon_id': 'ENSE00002234944.1',
#   'next_exon_id': 'ENSE00003582793.1'},
#  {'gene_id': 'ENSG00000290825.1',
#   'transcript_id': 'ENST00000456328.2',
#   'intron_id': 1,
#   'intron_start': 12721,
#   'intron_ends': 13220,
#   'prev_exon_id': 'ENSE00003582793.1',
#   'next_exon_id': 'ENSE00002312635.1'},
#  {'gene_id': 'ENSG00000223972.6',
#   'transcript_id': 'ENST00000450305.2',
#   'intron_id': 0,
#   'intron_start': 12057,
#   'intron_ends': 12178,
#   'prev_exon_id': 'ENSE00001948541.1',
#   'next_exon_id': 'ENSE00001671638.2'},
#  {'gene_id': 'ENSG00000223972.6',
#   'transcript_id': 'ENST00000450305.2',
#   'intron_id': 1,
#   'intron_start': 12227,
#   'intron_ends': 12612,
#   'prev_exon_id': 'ENSE00001671638.2',
#   'next_exon_id': 'ENSE00001758273.2'},
#  {'gene_id': 'ENSG00000223972.6',
#   'transcript_id': 'ENST00000450305.2',
#   'intron_id': 2,
#   'intron_start': 12697,
#   'intron_ends': 12974,
#   'prev_exon_id': 'ENSE00001758273.2',
#   'next_exon_id': 'ENSE00001799933.2'},
#  {'gene_id': 'ENSG00000223972.6',
#   'transcript_id': 'ENST00000450305.2',
#   'intron_id': 3,
#   'intron_start': 13052,
#   'intron_ends': 13220,
#   'prev_exon_id': 'ENSE00001799933.2',
#   'next_exon_id': 'ENSE00001746346.2'},
#  {'gene_id': 'ENSG00000223972.6',
#   'transcript_id': 'ENST00000450305.2',
#   'intron_id': 4,
#   'intron_start': 13374,
#   'intron_ends': 13452,
#   'prev_exon_id': 'ENSE00001746346.2',
#   'next_exon_id': 'ENSE00001863096.1'},
#  {'gene_id': 'ENSG00000227232.5',
#   'transcript_id': 'ENST00000488147.1',
#   'intron_id': 5,
#   'intron_start': 13670,
#   'intron_ends': 14403,
#   'prev_exon_id': 'ENSE00001863096.1',
#   'next_exon_id': 'ENSE00001843071.1'},
#  {'gene_id': 'ENSG00000227232.5',
#   'transcript_id': 'ENST00000488147.1',
#   'intron_id': 6,
#   'intron_start': 14501,
#   'intron_ends': 15004,
#   'prev_exon_id': 'ENSE00001843071.1',
#   'next_exon_id': 'ENSE00001935574.1'},
#  {'gene_id': 'ENSG00000227232.5',
#   'transcript_id': 'ENST00000488147.1',
#   'intron_id': 7,
#   'intron_start': 15038,
#   'intron_ends': 15795,
#   'prev_exon_id': 'ENSE00001935574.1',
#   'next_exon_id': 'ENSE00002030414.1'},
#  {'gene_id': 'ENSG00000227232.5',
#   'transcript_id': 'ENST00000488147.1',
#   'intron_id': 8,
#   'intron_start': 15947,
#   'intron_ends': 16606,
#   'prev_exon_id': 'ENSE00002030414.1',
#   'next_exon_id': 'ENSE00003621279.1'},
#  {'gene_id': 'ENSG00000227232.5',
#   'transcript_id': 'ENST00000488147.1',
#   'intron_id': 9,
#   'intron_start': 16765,
#   'intron_ends': 16857,
#   'prev_exon_id': 'ENSE00003621279.1',
#   'next_exon_id': 'ENSE00003553898.1'},
#  {'gene_id': 'ENSG00000227232.5',
#   'transcript_id': 'ENST00000488147.1',
#   'intron_id': 10,
#   'intron_start': 17055,
#   'intron_ends': 17232,
#   'prev_exon_id': 'ENSE00003553898.1',
#   'next_exon_id': 'ENSE00003502542.1'},
#  {'gene_id': 'ENSG00000227232.5',
#   'transcript_id': 'ENST00000488147.1',
#   'intron_id': 11,
#   'intron_start': 17368,
#   'intron_ends': 17605,
#   'prev_exon_id': 'ENSE00003502542.1',
#   'next_exon_id': 'ENSE00003475637.1'},
#  {'gene_id': 'ENSG00000227232.5',
#   'transcript_id': 'ENST00000488147.1',
#   'intron_id': 12,
#   'intron_start': 17742,
#   'intron_ends': 17914,
#   'prev_exon_id': 'ENSE00003475637.1',
#   'next_exon_id': 'ENSE00003565697.1'},
#  {'gene_id': 'ENSG00000227232.5',
#   'transcript_id': 'ENST00000488147.1',
#   'intron_id': 13,
#   'intron_start': 18061,
#   'intron_ends': 18267,
#   'prev_exon_id': 'ENSE00003565697.1',
#   'next_exon_id': 'ENSE00003477500.1'},
#  {'gene_id': 'ENSG00000227232.5',
#   'transcript_id': 'ENST00000488147.1',
#   'intron_id': 14,
#   'intron_start': 18366,
#   'intron_ends': 24737,
#   'prev_exon_id': 'ENSE00003477500.1',
#   'next_exon_id': 'ENSE00003507205.1'},
#  {'gene_id': 'ENSG00000227232.5',
#   'transcript_id': 'ENST00000488147.1',
#   'intron_id': 15,
#   'intron_start': 24891,
#   'intron_ends': 29533,
#   'prev_exon_id': 'ENSE00003507205.1',
#   'next_exon_id': 'ENSE00001890219.1'},
#  {'gene_id': 'ENSG00000278267.1',
#   'transcript_id': 'ENST00000619216.1',
#   'intron_id': 0,
#   'intron_start': 14403,
#   'intron_ends': 17368,
#   'prev_exon_id': 'Start-',
#   'next_exon_id': 'ENSE00003746039.1'},
#  {'gene_id': 'ENSG00000243485.5',
#   'transcript_id': 'ENST00000473358.1',
#   'intron_id': 0,
#   'intron_start': 30039,
#   'intron_ends': 30563,
#   'prev_exon_id': 'ENSE00001947070.1',
#   'next_exon_id': 'ENSE00001922571.1'},
#  {'gene_id': 'ENSG00000243485.5',
#   'transcript_id': 'ENST00000473358.1',
#   'intron_id': 1,
#   'intron_start': 30667,
#   'intron_ends': 30975,
#   'prev_exon_id': 'ENSE00001922571.1',
#   'next_exon_id': 'ENSE00001827679.1'},
#  {'gene_id': 'ENSG00000243485.5',
#   'transcript_id': 'ENST00000469289.1',
#   'intron_id': 0,
#   'intron_start': 30667,
#   'intron_ends': 30975,
#   'prev_exon_id': 'ENSE00001841699.1',
#   'next_exon_id': 'ENSE00001890064.1'},
#  {'gene_id': 'ENSG00000237613.2',
#   'transcript_id': 'ENST00000417324.1',
#   'intron_id': 0,
#   'intron_start': 30503,
#   'intron_ends': 34553,
#   'prev_exon_id': 'ENSE00003695741.1',
#   'next_exon_id': 'ENSE00001727627.1'},
#  {'gene_id': 'ENSG00000237613.2',
#   'transcript_id': 'ENST00000417324.1',
#   'intron_id': 1,
#   'intron_start': 35174,
#   'intron_ends': 35276,
#   'prev_exon_id': 'ENSE00001727627.1',
#   'next_exon_id': 'ENSE00001669267.1'},
#  {'gene_id': 'ENSG00000237613.2',
#   'transcript_id': 'ENST00000417324.1',
#   'intron_id': 2,
#   'intron_start': 35481,
#   'intron_ends': 35720,
#   'prev_exon_id': 'ENSE00001669267.1',
#   'next_exon_id': 'ENSE00001656588.1'},
#  {'gene_id': 'ENSG00000237613.2',
#   'transcript_id': 'ENST00000461467.1',
#   'intron_id': 0,
#   'intron_start': 34553,
#   'intron_ends': 35244,
#   'prev_exon_id': 'Start-',
#   'next_exon_id': 'ENSE00001874421.1'},
#  {'gene_id': 'ENSG00000237613.2',
#   'transcript_id': 'ENST00000461467.1',
#   'intron_id': 1,
#   'intron_start': 35481,
#   'intron_ends': 35720,
#   'prev_exon_id': 'ENSE00001874421.1',
#   'next_exon_id': 'ENSE00001618781.2'},
#  {'gene_id': 'ENSG00000290826.1',
#   'transcript_id': 'ENST00000642116.1',
#   'intron_id': 0,
#   'intron_start': 57653,
#   'intron_ends': 58699,
#   'prev_exon_id': 'ENSE00003812686.1',
#   'next_exon_id': 'ENSE00003812505.1'},
#  {'gene_id': 'ENSG00000290826.1',
#   'transcript_id': 'ENST00000642116.1',
#   'intron_id': 1,
#   'intron_start': 58856,
#   'intron_ends': 62915,
#   'prev_exon_id': 'ENSE00003812505.1',
#   'next_exon_id': 'ENSE00003811818.1'},
#  {'gene_id': 'ENSG00000186092.7',
#   'transcript_id': 'ENST00000641515.2',
#   'intron_id': 0,
#   'intron_start': 65433,
#   'intron_ends': 65519,
#   'prev_exon_id': 'ENSE00003812156.1',
#   'next_exon_id': 'ENSE00003813641.1'},
#  {'gene_id': 'ENSG00000186092.7',
#   'transcript_id': 'ENST00000641515.2',
#   'intron_id': 1,
#   'intron_start': 65573,
#   'intron_ends': 69036,
#   'prev_exon_id': 'ENSE00003813641.1',
#   'next_exon_id': 'ENSE00003813949.1'},
#  {'gene_id': 'ENSG00000238009.6',
#   'transcript_id': 'ENST00000466430.5',
#   'intron_id': 2,
#   'intron_start': 71585,
#   'intron_ends': 89294,
#   'prev_exon_id': 'ENSE00003813949.1',
#   'next_exon_id': 'ENSE00001846804.1'},
#  {'gene_id': 'ENSG00000238009.6',
#   'transcript_id': 'ENST00000466430.5',
#   'intron_id': 3,
#   'intron_start': 91629,
#   'intron_ends': 92090,
#   'prev_exon_id': 'ENSE00001846804.1',
#   'next_exon_id': 'ENSE00001944529.1'},
#  {'gene_id': 'ENSG00000238009.6',
#   'transcript_id': 'ENST00000466430.5',
#   'intron_id': 4,
#   'intron_start': 92240,
#   'intron_ends': 112699,
#   'prev_exon_id': 'ENSE00001944529.1',
#   'next_exon_id': 'ENSE00001957285.1'},
#  {'gene_id': 'ENSG00000238009.6',
#   'transcript_id': 'ENST00000466430.5',
#   'intron_id': 5,
#   'intron_start': 112804,
#   'intron_ends': 120774,
#   'prev_exon_id': 'ENSE00001957285.1',
#   'next_exon_id': 'ENSE00001606755.2'},
#  {'gene_id': 'ENSG00000238009.6',
#   'transcript_id': 'ENST00000477740.5',
#   'intron_id': 0,
#   'intron_start': 89294,
#   'intron_ends': 92229,
#   'prev_exon_id': 'Start-',
#   'next_exon_id': 'ENSE00001896976.1'},
#  {'gene_id': 'ENSG00000238009.6',
#   'transcript_id': 'ENST00000477740.5',
#   'intron_id': 1,
#   'intron_start': 92240,
#   'intron_ends': 112699,
#   'prev_exon_id': 'ENSE00001896976.1',
#   'next_exon_id': 'ENSE00001957285.1'},
#  {'gene_id': 'ENSG00000238009.6',
#   'transcript_id': 'ENST00000477740.5',
#   'intron_id': 2,
#   'intron_start': 112804,
#   'intron_ends': 120720,
#   'prev_exon_id': 'ENSE00001957285.1',
#   'next_exon_id': 'ENSE00001171005.3'},
#  {'gene_id': 'ENSG00000238009.6',
#   'transcript_id': 'ENST00000477740.5',
#   'intron_id': 3,
#   'intron_start': 120932,
#   'intron_ends': 129054,
#   'prev_exon_id': 'ENSE00001171005.3',
#   'next_exon_id': 'ENSE00001919246.1'},
#  {'gene_id': 'ENSG00000238009.6',
#   'transcript_id': 'ENST00000471248.1',
#   'intron_id': 0,
#   'intron_start': 92229,
#   'intron_ends': 110952,
#   'prev_exon_id': 'Start-',
#   'next_exon_id': 'ENSE00001879696.1'},
#  {'gene_id': 'ENSG00000238009.6',
#   'transcript_id': 'ENST00000471248.1',
#   'intron_id': 1,
#   'intron_start': 111357,
#   'intron_ends': 112699,
#   'prev_exon_id': 'ENSE00001879696.1',
#   'next_exon_id': 'ENSE00001957285.1'},
#  {'gene_id': 'ENSG00000238009.6',
#   'transcript_id': 'ENST00000471248.1',
#   'intron_id': 2,
#   'intron_start': 112804,
#   'intron_ends': 129054,
#   'prev_exon_id': 'ENSE00001957285.1',
#   'next_exon_id': 'ENSE00001934975.1'},
#  {'gene_id': 'ENSG00000238009.6',
#   'transcript_id': 'ENST00000610542.1',
#   'intron_id': 0,
#   'intron_start': 110952,
#   'intron_ends': 120724,
#   'prev_exon_id': 'Start-',
#   'next_exon_id': 'ENSE00003749543.1'},
#  {'gene_id': 'ENSG00000238009.6',
#   'transcript_id': 'ENST00000610542.1',
#   'intron_id': 1,
#   'intron_start': 120869,
#   'intron_ends': 120873,
#   'prev_exon_id': 'ENSE00003749543.1',
#   'next_exon_id': 'ENSE00003740919.1'},
#  {'gene_id': 'ENSG00000238009.6',
#   'transcript_id': 'ENST00000610542.1',
#   'intron_id': 2,
#   'intron_start': 120932,
#   'intron_ends': 129054,
#   'prev_exon_id': 'ENSE00003740919.1',
#   'next_exon_id': 'ENSE00003734824.1'},
#  {'gene_id': 'ENSG00000238009.6',
#   'transcript_id': 'ENST00000610542.1',
#   'intron_id': 3,
#   'intron_start': 129223,
#   'intron_ends': 133373,
#   'prev_exon_id': 'ENSE00003734824.1',
#   'next_exon_id': 'ENSE00003748456.1'},
#  {'gene_id': 'ENSG00000238009.6',
#   'transcript_id': 'ENST00000453576.2',
#   'intron_id': 0,
#   'intron_start': 120724,
#   'intron_ends': 129080,
#   'prev_exon_id': 'Start-',
#   'next_exon_id': 'ENSE00001827073.1'},
#  {'gene_id': 'ENSG00000238009.6',
#   'transcript_id': 'ENST00000453576.2',
#   'intron_id': 1,
#   'intron_start': 129223,
#   'intron_ends': 133373,
#   'prev_exon_id': 'ENSE00001827073.1',
#   'next_exon_id': 'ENSE00001737600.2'},
#  {'gene_id': 'ENSG00000239945.1',
#   'transcript_id': 'ENST00000495576.1',
#   'intron_id': 0,
#   'intron_start': 129080,
#   'intron_ends': 89550,
#   'prev_exon_id': 'Start-',
#   'next_exon_id': 'ENSE00001927725.1'},
#  {'gene_id': 'ENSG00000239945.1',
#   'transcript_id': 'ENST00000495576.1',
#   'intron_id': 1,
#   'intron_start': 90050,
#   'intron_ends': 90286,
#   'prev_exon_id': 'ENSE00001927725.1',
#   'next_exon_id': 'ENSE00001907785.1'},
#  {'gene_id': 'ENSG00000268903.1',
#   'transcript_id': 'ENST00000494149.2',
#   'intron_id': 0,
#   'intron_start': 134836,
#   'intron_ends': 135140,
#   'prev_exon_id': 'ENSE00001625118.3',
#   'next_exon_id': 'ENSE00001879101.2'},
#  {'gene_id': 'ENSG00000269981.1',
#   'transcript_id': 'ENST00000595919.1',
#   'intron_id': 0,
#   'intron_start': 135140,
#   'intron_ends': 137681,
#   'prev_exon_id': 'Start-',
#   'next_exon_id': 'ENSE00001936432.2'},
#  {'gene_id': 'ENSG00000239906.1',
#   'transcript_id': 'ENST00000493797.1',
#   'intron_id': 0,
#   'intron_start': 137681,
#   'intron_ends': 139789,
#   'prev_exon_id': 'Start-',
#   'next_exon_id': 'ENSE00001922992.1'},
#  {'gene_id': 'ENSG00000239906.1',
#   'transcript_id': 'ENST00000493797.1',
#   'intron_id': 1,
#   'intron_start': 139847,
#   'intron_ends': 140074,
#   'prev_exon_id': 'ENSE00001922992.1',
#   'next_exon_id': 'ENSE00001913281.1'},
#  {'gene_id': 'ENSG00000241860.7',
#   'transcript_id': 'ENST00000484859.1',
#   'intron_id': 0,
#   'intron_start': 139789,
#   'intron_ends': 141473,
#   'prev_exon_id': 'Start-',
#   'next_exon_id': 'ENSE00001911218.1'},
#  {'gene_id': 'ENSG00000241860.7',
#   'transcript_id': 'ENST00000484859.1',
#   'intron_id': 1,
#   'intron_start': 143011,
#   'intron_ends': 146385,
#   'prev_exon_id': 'ENSE00001911218.1',
#   'next_exon_id': 'ENSE00001860404.1'},
#  {'gene_id': 'ENSG00000241860.7',
#   'transcript_id': 'ENST00000490997.5',
#   'intron_id': 0,
#   'intron_start': 141473,
#   'intron_ends': 142807,
#   'prev_exon_id': 'Start-',
#   'next_exon_id': 'ENSE00001838397.1'},
#  {'gene_id': 'ENSG00000241860.7',
#   'transcript_id': 'ENST00000490997.5',
#   'intron_id': 1,
#   'intron_start': 143011,
#   'intron_ends': 146385,
#   'prev_exon_id': 'ENSE00001838397.1',
#   'next_exon_id': 'ENSE00001853409.1'},
#  {'gene_id': 'ENSG00000241860.7',
#   'transcript_id': 'ENST00000490997.5',
#   'intron_id': 2,
#   'intron_start': 146509,
#   'intron_ends': 146641,
#   'prev_exon_id': 'ENSE00001853409.1',
#   'next_exon_id': 'ENSE00001868647.1'},
#  {'gene_id': 'ENSG00000241860.7',
#   'transcript_id': 'ENST00000466557.6',
#   'intron_id': 0,
#   'intron_start': 142807,
#   'intron_ends': 146385,
#   'prev_exon_id': 'Start-',
#   'next_exon_id': 'ENSE00001853409.1'},
#  {'gene_id': 'ENSG00000241860.7',
#   'transcript_id': 'ENST00000466557.6',
#   'intron_id': 1,
#   'intron_start': 146509,
#   'intron_ends': 155766,
#   'prev_exon_id': 'ENSE00001853409.1',
#   'next_exon_id': 'ENSE00001799309.2'},
#  {'gene_id': 'ENSG00000241860.7',
#   'transcript_id': 'ENST00000466557.6',
#   'intron_id': 2,
#   'intron_start': 155831,
#   'intron_ends': 164262,
#   'prev_exon_id': 'ENSE00001799309.2',
#   'next_exon_id': 'ENSE00001862111.2'},
#  {'gene_id': 'ENSG00000241860.7',
#   'transcript_id': 'ENST00000466557.6',
#   'intron_id': 3,
#   'intron_start': 164791,
#   'intron_ends': 165883,
#   'prev_exon_id': 'ENSE00001862111.2',
#   'next_exon_id': 'ENSE00001949945.1'},
#  {'gene_id': 'ENSG00000241860.7',
#   'transcript_id': 'ENST00000466557.6',
#   'intron_id': 4,
#   'intron_start': 165942,
#   'intron_ends': 168099,
#   'prev_exon_id': 'ENSE00001949945.1',
#   'next_exon_id': 'ENSE00001947087.1'},
#  {'gene_id': 'ENSG00000241860.7',
#   'transcript_id': 'ENST00000466557.6',
#   'intron_id': 5,
#   'intron_start': 168165,
#   'intron_ends': 169048,
#   'prev_exon_id': 'ENSE00001947087.1',
#   'next_exon_id': 'ENSE00001922566.1'},
#  {'gene_id': 'ENSG00000241860.7',
#   'transcript_id': 'ENST00000466557.6',
#   'intron_id': 6,
#   'intron_start': 169264,
#   'intron_ends': 172556,
#   'prev_exon_id': 'ENSE00001922566.1',
#   'next_exon_id': 'ENSE00001890990.1'},
#  {'gene_id': 'ENSG00000241860.7',
#   'transcript_id': 'ENST00000466557.6',
#   'intron_id': 7,
#   'intron_start': 172688,
#   'intron_ends': 173752,
#   'prev_exon_id': 'ENSE00001890990.1',
#   'next_exon_id': 'ENSE00001947154.2'},
#  {'gene_id': 'ENSG00000241860.7',
#   'transcript_id': 'ENST00000662089.1',
#   'intron_id': 8,
#   'intron_start': 173862,
#   'intron_ends': 165490,
#   'prev_exon_id': 'ENSE00001947154.2',
#   'next_exon_id': 'ENSE00003873220.1'},
#  {'gene_id': 'ENSG00000241860.7',
#   'transcript_id': 'ENST00000662089.1',
#   'intron_id': 9,
#   'intron_start': 165942,
#   'intron_ends': 167958,
#   'prev_exon_id': 'ENSE00003873220.1',
#   'next_exon_id': 'ENSE00003868429.1'},
#  {'gene_id': 'ENSG00000241860.7',
#   'transcript_id': 'ENST00000662089.1',
#   'intron_id': 10,
#   'intron_start': 168165,
#   'intron_ends': 169048,
#   'prev_exon_id': 'ENSE00003868429.1',
#   'next_exon_id': 'ENSE00003878614.1'},
#  {'gene_id': 'ENSG00000241860.7',
#   'transcript_id': 'ENST00000491962.1',
#   'intron_id': 0,
#   'intron_start': 165490,
#   'intron_ends': 165888,
#   'prev_exon_id': 'Start-',
#   'next_exon_id': 'ENSE00001898156.1'},
#  {'gene_id': 'ENSG00000241860.7',
#   'transcript_id': 'ENST00000491962.1',
#   'intron_id': 1,
#   'intron_start': 165942,
#   'intron_ends': 168099,
#   'prev_exon_id': 'ENSE00001898156.1',
#   'next_exon_id': 'ENSE00001947087.1'},
#  {'gene_id': 'ENSG00000241860.7',
#   'transcript_id': 'ENST00000491962.1',
#   'intron_id': 2,
#   'intron_start': 168165,
#   'intron_ends': 168609,
#   'prev_exon_id': 'ENSE00001947087.1',
#   'next_exon_id': 'ENSE00001939117.1'},
#  {'gene_id': 'ENSG00000241860.7',
#   'transcript_id': 'ENST00000655252.1',
#   'intron_id': 0,
#   'intron_start': 165888,
#   'intron_ends': 167128,
#   'prev_exon_id': 'Start-',
#   'next_exon_id': 'ENSE00003876756.1'},
#  {'gene_id': 'ENSG00000241860.7',
#   'transcript_id': 'ENST00000655252.1',
#   'intron_id': 1,
#   'intron_start': 168165,
#   'intron_ends': 169048,
#   'prev_exon_id': 'ENSE00003876756.1',
#   'next_exon_id': 'ENSE00003878771.1'},
#  {'gene_id': 'ENSG00000222623.1',
#   'transcript_id': 'ENST00000410691.1',
#   'intron_id': 0,
#   'intron_start': 167128,
#   'intron_ends': 157783,
#   'prev_exon_id': 'Start-',
#   'next_exon_id': 'ENSE00001807945.1'},
#  {'gene_id': 'ENSG00000241599.1',
#   'transcript_id': 'ENST00000496488.1',
#   'intron_id': 0,
#   'intron_start': 160690,
#   'intron_ends': 161313,
#   'prev_exon_id': 'ENSE00001882727.1',
#   'next_exon_id': 'ENSE00001895361.1'},
#  {'gene_id': 'ENSG00000279928.2',
#   'transcript_id': 'ENST00000624431.2',
#   'intron_id': 0,
#   'intron_start': 182746,
#   'intron_ends': 183131,
#   'prev_exon_id': 'ENSE00003759020.2',
#   'next_exon_id': 'ENSE00003759581.2'},
#  {'gene_id': 'ENSG00000279928.2',
#   'transcript_id': 'ENST00000624431.2',
#   'intron_id': 1,
#   'intron_start': 183216,
#   'intron_ends': 183493,
#   'prev_exon_id': 'ENSE00003759581.2',
#   'next_exon_id': 'ENSE00003804405.1'},
#  {'gene_id': 'ENSG00000279928.2',
#   'transcript_id': 'ENST00000624431.2',
#   'intron_id': 2,
#   'intron_start': 183571,
#   'intron_ends': 183739,
#   'prev_exon_id': 'ENSE00003804405.1',
#   'next_exon_id': 'ENSE00003807458.1'},
#  {'gene_id': 'ENSG00000279928.2',
#   'transcript_id': 'ENST00000624431.2',
#   'intron_id': 3,
#   'intron_start': 183901,
#   'intron_ends': 183980,
#   'prev_exon_id': 'ENSE00003807458.1',
#   'next_exon_id': 'ENSE00003760199.2'},
#  {'gene_id': 'ENSG00000279457.4',
#   'transcript_id': 'ENST00000623083.4',
#   'intron_id': 4,
#   'intron_start': 184174,
#   'intron_ends': 185216,
#   'prev_exon_id': 'ENSE00003760199.2',
#   'next_exon_id': 'ENSE00003755076.2'},
#  {'gene_id': 'ENSG00000279457.4',
#   'transcript_id': 'ENST00000623083.4',
#   'intron_id': 5,
#   'intron_start': 185350,
#   'intron_ends': 185490,
#   'prev_exon_id': 'ENSE00003755076.2',
#   'next_exon_id': 'ENSE00003757943.1'},
#  {'gene_id': 'ENSG00000279457.4',
#   'transcript_id': 'ENST00000623083.4',
#   'intron_id': 6,
#   'intron_start': 185559,
#   'intron_ends': 186316,
#   'prev_exon_id': 'ENSE00003757943.1',
#   'next_exon_id': 'ENSE00003757727.1'},
#  {'gene_id': 'ENSG00000279457.4',
#   'transcript_id': 'ENST00000623083.4',
#   'intron_id': 7,
#   'intron_start': 186469,
#   'intron_ends': 187128,
#   'prev_exon_id': 'ENSE00003757727.1',
#   'next_exon_id': 'ENSE00003759679.1'},
#  {'gene_id': 'ENSG00000279457.4',
#   'transcript_id': 'ENST00000623083.4',
#   'intron_id': 8,
#   'intron_start': 187287,
#   'intron_ends': 187375,
#   'prev_exon_id': 'ENSE00003759679.1',
#   'next_exon_id': 'ENSE00003755701.1'},
#  {'gene_id': 'ENSG00000279457.4',
#   'transcript_id': 'ENST00000623083.4',
#   'intron_id': 9,
#   'intron_start': 187577,
#   'intron_ends': 187754,
#   'prev_exon_id': 'ENSE00003755701.1',
#   'next_exon_id': 'ENSE00003757255.2'},
#  {'gene_id': 'ENSG00000279457.4',
#   'transcript_id': 'ENST00000623083.4',
#   'intron_id': 10,
#   'intron_start': 187890,
#   'intron_ends': 188129,
#   'prev_exon_id': 'ENSE00003757255.2',
#   'next_exon_id': 'ENSE00003759270.1'},
#  {'gene_id': 'ENSG00000279457.4',
#   'transcript_id': 'ENST00000623083.4',
#   'intron_id': 11,
#   'intron_start': 188266,
#   'intron_ends': 188438,
#   'prev_exon_id': 'ENSE00003759270.1',
#   'next_exon_id': 'ENSE00003755821.2'},
#  {'gene_id': 'ENSG00000279457.4',
#   'transcript_id': 'ENST00000623083.4',
#   'intron_id': 12,
#   'intron_start': 188584,
#   'intron_ends': 188790,
#   'prev_exon_id': 'ENSE00003755821.2',
#   'next_exon_id': 'ENSE00003755850.1'},
#  {'gene_id': 'ENSG00000279457.4',
#   'transcript_id': 'ENST00000623083.4',
#   'intron_id': 13,
#   'intron_start': 188902,
#   'intron_ends': 195262,
#   'prev_exon_id': 'ENSE00003755850.1',
#   'next_exon_id': 'ENSE00003755778.1'},
#  {'gene_id': 'ENSG00000273874.1',
#   'transcript_id': 'ENST00000612080.1',
#   'intron_id': 0,
#   'intron_start': 185216,
#   'intron_ends': 187890,
#   'prev_exon_id': 'Start-',
#   'next_exon_id': 'ENSE00003737837.1'},
#  {'gene_id': 'ENSG00000228463.10',
#   'transcript_id': 'ENST00000442116.1',
#   'intron_id': 0,
#   'intron_start': 187890,
#   'intron_ends': 257863,
#   'prev_exon_id': 'Start-',
#   'next_exon_id': 'ENSE00001677641.1'},
#  {'gene_id': 'ENSG00000228463.10',
#   'transcript_id': 'ENST00000442116.1',
#   'intron_id': 1,
#   'intron_start': 259025,
#   'intron_ends': 264603,
#   'prev_exon_id': 'ENSE00001677641.1',
#   'next_exon_id': 'ENSE00001149252.5'},
#  {'gene_id': 'ENSG00000228463.10',
#   'transcript_id': 'ENST00000448958.2',
#   'intron_id': 0,
#   'intron_start': 257863,
#   'intron_ends': 257912,
#   'prev_exon_id': 'Start-',
#   'next_exon_id': 'ENSE00003813893.1'},
#  {'gene_id': 'ENSG00000228463.10',
#   'transcript_id': 'ENST00000448958.2',
#   'intron_id': 1,
#   'intron_start': 259025,
#   'intron_ends': 261549,
#   'prev_exon_id': 'ENSE00003813893.1',
#   'next_exon_id': 'ENSE00003786235.1'},
#  {'gene_id': 'ENSG00000228463.10',
#   'transcript_id': 'ENST00000448958.2',
#   'intron_id': 2,
#   'intron_start': 261634,
#   'intron_ends': 267302,
#   'prev_exon_id': 'ENSE00003786235.1',
#   'next_exon_id': 'ENSE00001769002.1'},
#  {'gene_id': 'ENSG00000228463.10',
#   'transcript_id': 'ENST00000448958.2',
#   'intron_id': 3,
#   'intron_start': 268204,
#   'intron_ends': 268666,
#   'prev_exon_id': 'ENSE00001769002.1',
#   'next_exon_id': 'ENSE00001688505.1'},
#  {'gene_id': 'ENSG00000228463.10',
#   'transcript_id': 'ENST00000441866.2',
#   'intron_id': 0,
#   'intron_start': 257912,
#   'intron_ends': 258143,
#   'prev_exon_id': 'Start-',
#   'next_exon_id': 'ENSE00001697698.1'},
#  {'gene_id': 'ENSG00000228463.10',
#   'transcript_id': 'ENST00000441866.2',
#   'intron_id': 1,
#   'intron_start': 259025,
#   'intron_ends': 356684,
#   'prev_exon_id': 'ENSE00001697698.1',
#   'next_exon_id': 'ENSE00003789911.2'},
#  {'gene_id': 'ENSG00000228463.10',
#   'transcript_id': 'ENST00000441866.2',
#   'intron_id': 2,
#   'intron_start': 357586,
#   'intron_ends': 358048,
#   'prev_exon_id': 'ENSE00003789911.2',
#   'next_exon_id': 'ENSE00001729229.1'},
#  {'gene_id': 'ENSG00000228463.10',
#   'transcript_id': 'ENST00000441866.2',
#   'intron_id': 3,
#   'intron_start': 358183,
#   'intron_ends': 359344,
#   'prev_exon_id': 'ENSE00001729229.1',
#   'next_exon_id': 'ENSE00001670287.1'},
#  {'gene_id': 'ENSG00000228463.10',
#   'transcript_id': 'ENST00000634344.2',
#   'intron_id': 0,
#   'intron_start': 258143,
#   'intron_ends': 258523,
#   'prev_exon_id': 'Start-',
#   'next_exon_id': 'ENSE00003789731.2'},
#  {'gene_id': 'ENSG00000228463.10',
#   'transcript_id': 'ENST00000634344.2',
#   'intron_id': 1,
#   'intron_start': 259025,
#   'intron_ends': 267302,
#   'prev_exon_id': 'ENSE00003789731.2',
#   'next_exon_id': 'ENSE00001769002.1'},
#  {'gene_id': 'ENSG00000228463.10',
#   'transcript_id': 'ENST00000634344.2',
#   'intron_id': 2,
#   'intron_start': 268204,
#   'intron_ends': 268666,
#   'prev_exon_id': 'ENSE00001769002.1',
#   'next_exon_id': 'ENSE00001688505.1'},
#  {'gene_id': 'ENSG00000228463.10',
#   'transcript_id': 'ENST00000450734.1',
#   'intron_id': 0,
#   'intron_start': 258523,
#   'intron_ends': 258567,
#   'prev_exon_id': 'Start-',
#   'next_exon_id': 'ENSE00001787230.1'},
#  {'gene_id': 'ENSG00000228463.10',
#   'transcript_id': 'ENST00000424587.7',
#   'intron_id': 0,
#   'intron_start': 258567,
#   'intron_ends': 263014,
#   'prev_exon_id': 'Start-',
#   'next_exon_id': 'ENSE00001785078.3'},
#  {'gene_id': 'ENSG00000228463.10',
#   'transcript_id': 'ENST00000424587.7',
#   'intron_id': 1,
#   'intron_start': 268204,
#   'intron_ends': 268666,
#   'prev_exon_id': 'ENSE00001785078.3',
#   'next_exon_id': 'ENSE00001688505.1'},
#  {'gene_id': 'ENSG00000228463.10',
#   'transcript_id': 'ENST00000424587.7',
#   'intron_id': 2,
#   'intron_start': 268816,
#   'intron_ends': 289265,
#   'prev_exon_id': 'ENSE00001688505.1',
#   'next_exon_id': 'ENSE00001694491.1'},
#  {'gene_id': 'ENSG00000228463.10',
#   'transcript_id': 'ENST00000424587.7',
#   'intron_id': 3,
#   'intron_start': 289370,
#   'intron_ends': 297344,
#   'prev_exon_id': 'ENSE00001694491.1',
#   'next_exon_id': 'ENSE00001697423.1'},
#  {'gene_id': 'ENSG00000286448.1',
#   'transcript_id': 'ENST00000669836.1',
#   'intron_id': 0,
#   'intron_start': 267056,
#   'intron_ends': 268121,
#   'prev_exon_id': 'ENSE00003865469.1',
#   'next_exon_id': 'ENSE00003852409.1'},
#  {'gene_id': 'ENSG00000236679.2',
#   'transcript_id': 'ENST00000458203.2',
#   'intron_id': 1,
#   'intron_start': 268655,
#   'intron_ends': 347981,
#   'prev_exon_id': 'ENSE00003852409.1',
#   'next_exon_id': 'ENSE00001707201.2'},
#  {'gene_id': 'ENSG00000236601.2',
#   'transcript_id': 'ENST00000450983.1',
#   'intron_id': 0,
#   'intron_start': 358929,
#   'intron_ends': 365170,
#   'prev_exon_id': 'ENSE00001634442.1',
#   'next_exon_id': 'ENSE00001787178.1'},
#  {'gene_id': 'ENSG00000236601.2',
#   'transcript_id': 'ENST00000412666.1',
#   'intron_id': 0,
#   'intron_start': 358957,
#   'intron_ends': 365170,
#   'prev_exon_id': 'ENSE00001700697.1',
#   'next_exon_id': 'ENSE00001745103.1'},
#  {'gene_id': 'ENSG00000236601.2',
#   'transcript_id': 'ENST00000635159.1',
#   'intron_id': 0,
#   'intron_start': 360168,
#   'intron_ends': 365170,
#   'prev_exon_id': 'ENSE00003784495.1',
#   'next_exon_id': 'ENSE00003791014.1'},
#  {'gene_id': 'ENSG00000290385.1',
#   'transcript_id': 'ENST00000431321.2',
#   'intron_id': 1,
#   'intron_start': 366052,
#   'intron_ends': 365388,
#   'prev_exon_id': 'ENSE00003791014.1',
#   'next_exon_id': 'ENSE00001656291.1'},
#  {'gene_id': 'ENSG00000290385.1',
#   'transcript_id': 'ENST00000431321.2',
#   'intron_id': 2,
#   'intron_start': 365692,
#   'intron_ends': 366018,
#   'prev_exon_id': 'ENSE00001656291.1',
#   'next_exon_id': 'ENSE00001610890.3'},
#  {'gene_id': 'ENSG00000290385.1',
#   'transcript_id': 'ENST00000453935.1',
#   'intron_id': 0,
#   'intron_start': 365388,
#   'intron_ends': 365394,
#   'prev_exon_id': 'Start-',
#   'next_exon_id': 'ENSE00001798578.1'},
#  {'gene_id': 'ENSG00000290385.1',
#   'transcript_id': 'ENST00000453935.1',
#   'intron_id': 1,
#   'intron_start': 365692,
#   'intron_ends': 368250,
#   'prev_exon_id': 'ENSE00001798578.1',
#   'next_exon_id': 'ENSE00001651491.1'},
#  {'gene_id': 'ENSG00000290385.1',
#   'transcript_id': 'ENST00000440163.1',
#   'intron_id': 0,
#   'intron_start': 365394,
#   'intron_ends': 365614,
#   'prev_exon_id': 'Start-',
#   'next_exon_id': 'ENSE00001651822.1'},
#  {'gene_id': 'ENSG00000290385.1',
#   'transcript_id': 'ENST00000440163.1',
#   'intron_id': 1,
#   'intron_start': 365692,
#   'intron_ends': 373143,
#   'prev_exon_id': 'ENSE00001651822.1',
#   'next_exon_id': 'ENSE00001622961.1'},
#  {'gene_id': 'ENSG00000290385.1',
#   'transcript_id': 'ENST00000440163.1',
#   'intron_id': 2,
#   'intron_start': 373323,
#   'intron_ends': 379768,
#   'prev_exon_id': 'ENSE00001622961.1',
#   'next_exon_id': 'ENSE00001687828.1'},
#  {'gene_id': 'ENSG00000290385.1',
#   'transcript_id': 'ENST00000455207.5',
#   'intron_id': 0,
#   'intron_start': 365614,
#   'intron_ends': 373181,
#   'prev_exon_id': 'Start-',
#   'next_exon_id': 'ENSE00001770724.1'},
#  {'gene_id': 'ENSG00000290385.1',
#   'transcript_id': 'ENST00000455207.5',
#   'intron_id': 1,
#   'intron_start': 373323,
#   'intron_ends': 379768,
#   'prev_exon_id': 'ENSE00001770724.1',
#   'next_exon_id': 'ENSE00001628100.1'},
#  {'gene_id': 'ENSG00000290385.1',
#   'transcript_id': 'ENST00000455207.5',
#   'intron_id': 2,
#   'intron_start': 379870,
#   'intron_ends': 485039,
#   'prev_exon_id': 'ENSE00001628100.1',
#   'next_exon_id': 'ENSE00001794483.1'},
#  {'gene_id': 'ENSG00000290385.1',
#   'transcript_id': 'ENST00000455464.7',
#   'intron_id': 0,
#   'intron_start': 373181,
#   'intron_ends': 476363,
#   'prev_exon_id': 'Start-',
#   'next_exon_id': 'ENSE00001707425.2'},
#  {'gene_id': 'ENSG00000290385.1',
#   'transcript_id': 'ENST00000455464.7',
#   'intron_id': 1,
#   'intron_start': 476945,
#   'intron_ends': 485039,
#   'prev_exon_id': 'ENSE00001707425.2',
#   'next_exon_id': 'ENSE00001794483.1'},
#  {'gene_id': 'ENSG00000290385.1',
#   'transcript_id': 'ENST00000455464.7',
#   'intron_id': 2,
#   'intron_start': 485208,
#   'intron_ends': 497108,
#   'prev_exon_id': 'ENSE00001794483.1',
#   'next_exon_id': 'ENSE00003016872.1'},
#  {'gene_id': 'ENSG00000290385.1',
#   'transcript_id': 'ENST00000601814.5',
#   'intron_id': 0,
#   'intron_start': 476363,
#   'intron_ends': 484831,
#   'prev_exon_id': 'Start-',
#   'next_exon_id': 'ENSE00001690296.2'},
#  {'gene_id': 'ENSG00000290385.1',
#   'transcript_id': 'ENST00000601814.5',
#   'intron_id': 1,
#   'intron_start': 485208,
#   'intron_ends': 494991,
#   'prev_exon_id': 'ENSE00001690296.2',
#   'next_exon_id': 'ENSE00003328882.1'},
#  {'gene_id': 'ENSG00000290385.1',
#   'transcript_id': 'ENST00000601814.5',
#   'intron_id': 2,
#   'intron_start': 495049,
#   'intron_ends': 495276,
#   'prev_exon_id': 'ENSE00003328882.1',
#   'next_exon_id': 'ENSE00002997765.1'},
#  {'gene_id': 'ENSG00000290385.1',
#   'transcript_id': 'ENST00000431812.1',
#   'intron_id': 3,
#   'intron_start': 495476,
#   'intron_ends': 485065,
#   'prev_exon_id': 'ENSE00002997765.1',
#   'next_exon_id': 'ENSE00001758832.1'},
#  {'gene_id': 'ENSG00000290385.1',
#   'transcript_id': 'ENST00000431812.1',
#   'intron_id': 4,
#   'intron_start': 485208,
#   'intron_ends': 489360,
#   'prev_exon_id': 'ENSE00001758832.1',
#   'next_exon_id': 'ENSE00001628206.1'},
#  {'gene_id': 'ENSG00000290385.1',
#   'transcript_id': 'ENST00000419160.4',
#   'intron_id': 0,
#   'intron_start': 485065,
#   'intron_ends': 494381,
#   'prev_exon_id': 'Start-',
#   'next_exon_id': 'ENSE00001760607.2'},
#  {'gene_id': 'ENSG00000290385.1',
#   'transcript_id': 'ENST00000419160.4',
#   'intron_id': 1,
#   'intron_start': 494586,
#   'intron_ends': 496263,
#   'prev_exon_id': 'ENSE00001760607.2',
#   'next_exon_id': 'ENSE00001650218.4'},
#  {'gene_id': 'ENSG00000290385.1',
#   'transcript_id': 'ENST00000440038.7',
#   'intron_id': 0,
#   'intron_start': 494381,
#   'intron_ends': 494463,
#   'prev_exon_id': 'Start-',
#   'next_exon_id': 'ENSE00003003869.1'},
#  {'gene_id': 'ENSG00000290385.1',
#   'transcript_id': 'ENST00000440038.7',
#   'intron_id': 1,
#   'intron_start': 494898,
#   'intron_ends': 494991,
#   'prev_exon_id': 'ENSE00003003869.1',
#   'next_exon_id': 'ENSE00003328882.1'},
#  {'gene_id': 'ENSG00000290385.1',
#   'transcript_id': 'ENST00000440038.7',
#   'intron_id': 2,
#   'intron_start': 495049,
#   'intron_ends': 497108,
#   'prev_exon_id': 'ENSE00003328882.1',
#   'next_exon_id': 'ENSE00003075294.1'},
#  {'gene_id': 'ENSG00000290385.1',
#   'transcript_id': 'ENST00000440038.7',
#   'intron_id': 3,
#   'intron_start': 497299,
#   'intron_ends': 501555,
#   'prev_exon_id': 'ENSE00003075294.1',
#   'next_exon_id': 'ENSE00003186556.2'},
#  {'gene_id': 'ENSG00000290385.1',
#   'transcript_id': 'ENST00000440038.7',
#   'intron_id': 4,
#   'intron_start': 501620,
#   'intron_ends': 502464,
#   'prev_exon_id': 'ENSE00003186556.2',
#   'next_exon_id': 'ENSE00003813138.1'},
#  {'gene_id': 'ENSG00000290385.1',
#   'transcript_id': 'ENST00000642074.1',
#   'intron_id': 0,
#   'intron_start': 494463,
#   'intron_ends': 494474,
#   'prev_exon_id': 'Start-',
#   'next_exon_id': 'ENSE00003813292.1'},
#  {'gene_id': 'ENSG00000290385.1',
#   'transcript_id': 'ENST00000642074.1',
#   'intron_id': 1,
#   'intron_start': 494898,
#   'intron_ends': 494991,
#   'prev_exon_id': 'ENSE00003813292.1',
#   'next_exon_id': 'ENSE00003328882.1'},
#  {'gene_id': 'ENSG00000290385.1',
#   'transcript_id': 'ENST00000642074.1',
#   'intron_id': 2,
#   'intron_start': 495049,
#   'intron_ends': 495276,
#   'prev_exon_id': 'ENSE00003328882.1',
#   'next_exon_id': 'ENSE00003812802.1'},
#  {'gene_id': 'ENSG00000290385.1',
#   'transcript_id': 'ENST00000423728.6',
#   'intron_id': 0,
#   'intron_start': 494474,
#   'intron_ends': 494610,
#   'prev_exon_id': 'Start-',
#   'next_exon_id': 'ENSE00003811533.1'},
#  {'gene_id': 'ENSG00000290385.1',
#   'transcript_id': 'ENST00000423728.6',
#   'intron_id': 1,
#   'intron_start': 494898,
#   'intron_ends': 494991,
#   'prev_exon_id': 'ENSE00003811533.1',
#   'next_exon_id': 'ENSE00003328882.1'},
#  {'gene_id': 'ENSG00000290385.1',
#   'transcript_id': 'ENST00000423728.6',
#   'intron_id': 2,
#   'intron_start': 495049,
#   'intron_ends': 498683,
#   'prev_exon_id': 'ENSE00003328882.1',
#   'next_exon_id': 'ENSE00001736043.1'},
#  {'gene_id': 'ENSG00000290385.1',
#   'transcript_id': 'ENST00000616311.5',
#   'intron_id': 0,
#   'intron_start': 494610,
#   'intron_ends': 494770,
#   'prev_exon_id': 'Start-',
#   'next_exon_id': 'ENSE00001798174.2'},
#  {'gene_id': 'ENSG00000290385.1',
#   'transcript_id': 'ENST00000616311.5',
#   'intron_id': 1,
#   'intron_start': 494898,
#   'intron_ends': 494991,
#   'prev_exon_id': 'ENSE00001798174.2',
#   'next_exon_id': 'ENSE00003328882.1'},
#  {'gene_id': 'ENSG00000290385.1',
#   'transcript_id': 'ENST00000616311.5',
#   'intron_id': 2,
#   'intron_start': 495049,
#   'intron_ends': 497108,
#   'prev_exon_id': 'ENSE00003328882.1',
#   'next_exon_id': 'ENSE00003075294.1'},
#  {'gene_id': 'ENSG00000290385.1',
#   'transcript_id': 'ENST00000616311.5',
#   'intron_id': 3,
#   'intron_start': 497299,
#   'intron_ends': 498398,
#   'prev_exon_id': 'ENSE00003075294.1',
#   'next_exon_id': 'ENSE00001601447.1'},
#  {'gene_id': 'ENSG00000290385.1',
#   'transcript_id': 'ENST00000616311.5',
#   'intron_id': 4,
#   'intron_start': 498456,
#   'intron_ends': 498683,
#   'prev_exon_id': 'ENSE00001601447.1',
#   'next_exon_id': 'ENSE00003724255.2'},
#  {'gene_id': 'ENSG00000290385.1',
#   'transcript_id': 'ENST00000599771.6',
#   'intron_id': 0,
#   'intron_start': 494770,
#   'intron_ends': 497133,
#   'prev_exon_id': 'Start-',
#   'next_exon_id': 'ENSE00003062243.1'},
#  {'gene_id': 'ENSG00000290385.1',
#   'transcript_id': 'ENST00000599771.6',
#   'intron_id': 1,
#   'intron_start': 497299,
#   'intron_ends': 498072,
#   'prev_exon_id': 'ENSE00003062243.1',
#   'next_exon_id': 'ENSE00001760542.2'},
#  {'gene_id': 'ENSG00000290385.1',
#   'transcript_id': 'ENST00000599771.6',
#   'intron_id': 2,
#   'intron_start': 498305,
#   'intron_ends': 498398,
#   'prev_exon_id': 'ENSE00001760542.2',
#   'next_exon_id': 'ENSE00001601447.1'},
#  {'gene_id': 'ENSG00000290385.1',
#   'transcript_id': 'ENST00000641845.1',
#   'intron_id': 0,
#   'intron_start': 497133,
#   'intron_ends': 497204,
#   'prev_exon_id': 'Start-',
#   'next_exon_id': 'ENSE00003813098.1'},
#  {'gene_id': 'ENSG00000290385.1',
#   'transcript_id': 'ENST00000641845.1',
#   'intron_id': 1,
#   'intron_start': 497228,
#   'intron_ends': 498072,
#   'prev_exon_id': 'ENSE00003813098.1',
#   'next_exon_id': 'ENSE00001760542.2'},
#  {'gene_id': 'ENSG00000290385.1',
#   'transcript_id': 'ENST00000641845.1',
#   'intron_id': 2,
#   'intron_start': 498305,
#   'intron_ends': 498398,
#   'prev_exon_id': 'ENSE00001760542.2',
#   'next_exon_id': 'ENSE00001601447.1'},
#  {'gene_id': 'ENSG00000290385.1',
#   'transcript_id': 'ENST00000641845.1',
#   'intron_id': 3,
#   'intron_start': 498456,
#   'intron_ends': 501555,
#   'prev_exon_id': 'ENSE00001601447.1',
#   'next_exon_id': 'ENSE00003186556.2'},
#  {'gene_id': 'ENSG00000290385.1',
#   'transcript_id': 'ENST00000641845.1',
#   'intron_id': 4,
#   'intron_start': 501620,
#   'intron_ends': 502186,
#   'prev_exon_id': 'ENSE00003186556.2',
#   'next_exon_id': 'ENSE00003812333.1'},
#  {'gene_id': 'ENSG00000290385.1',
#   'transcript_id': 'ENST00000641845.1',
#   'intron_id': 5,
#   'intron_start': 502243,
#   'intron_ends': 502464,
#   'prev_exon_id': 'ENSE00003812333.1',
#   'next_exon_id': 'ENSE00003813663.1'},
#  {'gene_id': 'ENSG00000290385.1',
#   'transcript_id': 'ENST00000641916.1',
#   'intron_id': 0,
#   'intron_start': 497204,
#   'intron_ends': 497209,
#   'prev_exon_id': 'Start-',
#   'next_exon_id': 'ENSE00003812605.1'},
#  {'gene_id': 'ENSG00000290385.1',
#   'transcript_id': 'ENST00000641916.1',
#   'intron_id': 1,
#   'intron_start': 497299,
#   'intron_ends': 498398,
#   'prev_exon_id': 'ENSE00003812605.1',
#   'next_exon_id': 'ENSE00001601447.1'},
#  {'gene_id': 'ENSG00000290385.1',
#   'transcript_id': 'ENST00000641916.1',
#   'intron_id': 2,
#   'intron_start': 498456,
#   'intron_ends': 501555,
#   'prev_exon_id': 'ENSE00001601447.1',
#   'next_exon_id': 'ENSE00003186556.2'},
#  {'gene_id': 'ENSG00000290385.1',
#   'transcript_id': 'ENST00000641916.1',
#   'intron_id': 3,
#   'intron_start': 501620,
#   'intron_ends': 502464,
#   'prev_exon_id': 'ENSE00003186556.2',
#   'next_exon_id': 'ENSE00003811762.1'},
#  {'gene_id': 'ENSG00000290385.1',
#   'transcript_id': 'ENST00000601486.5',
#   'intron_id': 0,
#   'intron_start': 497209,
#   'intron_ends': 497239,
#   'prev_exon_id': 'Start-',
#   'next_exon_id': 'ENSE00003045569.1'},
#  {'gene_id': 'ENSG00000290385.1',
#   'transcript_id': 'ENST00000601486.5',
#   'intron_id': 1,
#   'intron_start': 497299,
#   'intron_ends': 498046,
#   'prev_exon_id': 'ENSE00003045569.1',
#   'next_exon_id': 'ENSE00003063936.1'},
#  {'gene_id': 'ENSG00000290385.1',
#   'transcript_id': 'ENST00000601486.5',
#   'intron_id': 2,
#   'intron_start': 498305,
#   'intron_ends': 498398,
#   'prev_exon_id': 'ENSE00003063936.1',
#   'next_exon_id': 'ENSE00001601447.1'},
#  {'gene_id': 'ENSG00000290385.1',
#   'transcript_id': 'ENST00000601486.5',
#   'intron_id': 3,
#   'intron_start': 498456,
#   'intron_ends': 498683,
#   'prev_exon_id': 'ENSE00001601447.1',
#   'next_exon_id': 'ENSE00003097839.1'},
#  {'gene_id': 'ENSG00000290385.1',
#   'transcript_id': 'ENST00000641579.1',
#   'intron_id': 0,
#   'intron_start': 497239,
#   'intron_ends': 497244,
#   'prev_exon_id': 'Start-',
#   'next_exon_id': 'ENSE00003772014.2'},
#  {'gene_id': 'ENSG00000290385.1',
#   'transcript_id': 'ENST00000641579.1',
#   'intron_id': 1,
#   'intron_start': 497299,
#   'intron_ends': 498072,
#   'prev_exon_id': 'ENSE00003772014.2',
#   'next_exon_id': 'ENSE00001760542.2'},
#  {'gene_id': 'ENSG00000290385.1',
#   'transcript_id': 'ENST00000641579.1',
#   'intron_id': 2,
#   'intron_start': 498305,
#   'intron_ends': 498398,
#   'prev_exon_id': 'ENSE00001760542.2',
#   'next_exon_id': 'ENSE00001601447.1'},
#  {'gene_id': 'ENSG00000290385.1',
#   'transcript_id': 'ENST00000641579.1',
#   'intron_id': 3,
#   'intron_start': 498456,
#   'intron_ends': 501555,
#   'prev_exon_id': 'ENSE00001601447.1',
#   'next_exon_id': 'ENSE00003186556.2'},
#  {'gene_id': 'ENSG00000290385.1',
#   'transcript_id': 'ENST00000641579.1',
#   'intron_id': 4,
#   'intron_start': 501620,
#   'intron_ends': 502464,
#   'prev_exon_id': 'ENSE00003186556.2',
#   'next_exon_id': 'ENSE00003813663.1'},
#  {'gene_id': 'ENSG00000290385.1',
#   'transcript_id': 'ENST00000616947.2',
#   'intron_id': 0,
#   'intron_start': 497244,
#   'intron_ends': 497274,
#   'prev_exon_id': 'Start-',
#   'next_exon_id': 'ENSE00003771994.1'},
#  {'gene_id': 'ENSG00000290385.1',
#   'transcript_id': 'ENST00000616947.2',
#   'intron_id': 1,
#   'intron_start': 497299,
#   'intron_ends': 498398,
#   'prev_exon_id': 'ENSE00003771994.1',
#   'next_exon_id': 'ENSE00003748817.2'},
#  {'gene_id': 'ENSG00000290385.1',
#   'transcript_id': 'ENST00000432964.1',
#   'intron_id': 0,
#   'intron_start': 497274,
#   'intron_ends': 498280,
#   'prev_exon_id': 'Start-',
#   'next_exon_id': 'ENSE00001803078.1'},
#  {'gene_id': 'ENSG00000290385.1',
#   'transcript_id': 'ENST00000432964.1',
#   'intron_id': 1,
#   'intron_start': 498305,
#   'intron_ends': 498398,
#   'prev_exon_id': 'ENSE00001803078.1',
#   'next_exon_id': 'ENSE00001601447.1'},
#  {'gene_id': 'ENSG00000290385.1',
#   'transcript_id': 'ENST00000432964.1',
#   'intron_id': 2,
#   'intron_start': 498456,
#   'intron_ends': 498683,
#   'prev_exon_id': 'ENSE00001601447.1',
#   'next_exon_id': 'ENSE00001736043.1'},
#  {'gene_id': 'ENSG00000290385.1',
#   'transcript_id': 'ENST00000608420.1',
#   'intron_id': 0,
#   'intron_start': 498280,
#   'intron_ends': 498983,
#   'prev_exon_id': 'Start-',
#   'next_exon_id': 'ENSE00003708499.1'},
#  {'gene_id': 'ENSG00000290385.1',
#   'transcript_id': 'ENST00000608420.1',
#   'intron_id': 1,
#   'intron_start': 499369,
#   'intron_ends': 501555,
#   'prev_exon_id': 'ENSE00003708499.1',
#   'next_exon_id': 'ENSE00003709813.1'},
#  {'gene_id': 'ENSG00000290385.1',
#   'transcript_id': 'ENST00000641303.1',
#   'intron_id': 0,
#   'intron_start': 498983,
#   'intron_ends': 501587,
#   'prev_exon_id': 'Start-',
#   'next_exon_id': 'ENSE00003812612.1'},
#  {'gene_id': 'ENSG00000290385.1',
#   'transcript_id': 'ENST00000641303.1',
#   'intron_id': 1,
#   'intron_start': 501620,
#   'intron_ends': 502861,
#   'prev_exon_id': 'ENSE00003812612.1',
#   'next_exon_id': 'ENSE00003813384.1'},
#  {'gene_id': 'ENSG00000290385.1',
#   'transcript_id': 'ENST00000641303.1',
#   'intron_id': 2,
#   'intron_start': 502955,
#   'intron_ends': 504979,
#   'prev_exon_id': 'ENSE00003813384.1',
#   'next_exon_id': 'ENSE00003812904.1'},
#  {'gene_id': 'ENSG00000290385.1',
#   'transcript_id': 'ENST00000641303.1',
#   'intron_id': 3,
#   'intron_start': 505103,
#   'intron_ends': 514358,
#   'prev_exon_id': 'ENSE00003812904.1',
#   'next_exon_id': 'ENSE00003812097.1'},
#  {'gene_id': 'ENSG00000290385.1',
#   'transcript_id': 'ENST00000641303.1',
#   'intron_id': 4,
#   'intron_start': 514423,
#   'intron_ends': 517184,
#   'prev_exon_id': 'ENSE00003812097.1',
#   'next_exon_id': 'ENSE00003813716.1'},
#  {'gene_id': 'ENSG00000290385.1',
#   'transcript_id': 'ENST00000641063.1',
#   'intron_id': 0,
#   'intron_start': 501587,
#   'intron_ends': 501603,
#   'prev_exon_id': 'Start-',
#   'next_exon_id': 'ENSE00003814035.1'},
#  {'gene_id': 'ENSG00000290385.1',
#   'transcript_id': 'ENST00000641063.1',
#   'intron_id': 1,
#   'intron_start': 501620,
#   'intron_ends': 502464,
#   'prev_exon_id': 'ENSE00003814035.1',
#   'next_exon_id': 'ENSE00003814243.1'},
#  {'gene_id': 'ENSG00000290385.1',
#   'transcript_id': 'ENST00000641063.1',
#   'intron_id': 2,
#   'intron_start': 502661,
#   'intron_ends': 504979,
#   'prev_exon_id': 'ENSE00003814243.1',
#   'next_exon_id': 'ENSE00003812904.1'},
#  {'gene_id': 'ENSG00000290385.1',
#   'transcript_id': 'ENST00000641063.1',
#   'intron_id': 3,
#   'intron_start': 505103,
#   'intron_ends': 514358,
#   'prev_exon_id': 'ENSE00003812904.1',
#   'next_exon_id': 'ENSE00003812097.1'},
#  {'gene_id': 'ENSG00000290385.1',
#   'transcript_id': 'ENST00000641063.1',
#   'intron_id': 4,
#   'intron_start': 514423,
#   'intron_ends': 517155,
#   'prev_exon_id': 'ENSE00003812097.1',
#   'next_exon_id': 'ENSE00003812919.1'},
#  {'gene_id': 'ENSG00000290385.1',
#   'transcript_id': 'ENST00000641049.1',
#   'intron_id': 0,
#   'intron_start': 501603,
#   'intron_ends': 504469,
#   'prev_exon_id': 'Start-',
#   'next_exon_id': 'ENSE00003812143.1'},
#  {'gene_id': 'ENSG00000290385.1',
#   'transcript_id': 'ENST00000641049.1',
#   'intron_id': 1,
#   'intron_start': 504933,
#   'intron_ends': 514358,
#   'prev_exon_id': 'ENSE00003812143.1',
#   'next_exon_id': 'ENSE00003812504.1'},
#  {'gene_id': 'ENSG00000290385.1',
#   'transcript_id': 'ENST00000642124.1',
#   'intron_id': 0,
#   'intron_start': 504469,
#   'intron_ends': 504864,
#   'prev_exon_id': 'Start-',
#   'next_exon_id': 'ENSE00003813395.1'},
#  {'gene_id': 'ENSG00000290385.1',
#   'transcript_id': 'ENST00000642124.1',
#   'intron_id': 1,
#   'intron_start': 505103,
#   'intron_ends': 514358,
#   'prev_exon_id': 'ENSE00003813395.1',
#   'next_exon_id': 'ENSE00003812097.1'},
#  {'gene_id': 'ENSG00000290385.1',
#   'transcript_id': 'ENST00000642124.1',
#   'intron_id': 2,
#   'intron_start': 514423,
#   'intron_ends': 517184,
#   'prev_exon_id': 'ENSE00003812097.1',
#   'next_exon_id': 'ENSE00003813543.1'},
#  {'gene_id': 'ENSG00000290385.1',
#   'transcript_id': 'ENST00000642124.1',
#   'intron_id': 3,
#   'intron_start': 517266,
#   'intron_ends': 522858,
#   'prev_exon_id': 'ENSE00003813543.1',
#   'next_exon_id': 'ENSE00003814041.1'},
#  {'gene_id': 'ENSG00000284733.2',
#   'transcript_id': 'ENST00000426406.4',
#   'intron_id': 0,
#   'intron_start': 440232,
#   'intron_ends': 450739,
#   'prev_exon_id': 'ENSE00003220883.1',
#   'next_exon_id': 'ENSE00003989331.1'},
#  {'gene_id': 'ENSG00000237094.13',
#   'transcript_id': 'ENST00000445840.2',
#   'intron_id': 0,
#   'intron_start': 450739,
#   'intron_ends': 485025,
#   'prev_exon_id': 'Start-',
#   'next_exon_id': 'ENSE00001665892.2'},
#  {'gene_id': 'ENSG00000233653.3',
#   'transcript_id': 'ENST00000432723.3',
#   'intron_id': 0,
#   'intron_start': 489387,
#   'intron_ends': 489716,
#   'prev_exon_id': 'ENSE00001705369.3',
#   'next_exon_id': 'ENSE00003569252.1'},
#  {'gene_id': 'ENSG00000250575.1',
#   'transcript_id': 'ENST00000514436.1',
#   'intron_id': 1,
#   'intron_start': 489906,
#   'intron_ends': 491224,
#   'prev_exon_id': 'ENSE00003569252.1',
#   'next_exon_id': 'ENSE00002064640.1'},
#  {'gene_id': 'ENSG00000250575.1',
#   'transcript_id': 'ENST00000514436.1',
#   'intron_id': 2,
#   'intron_start': 491989,
#   'intron_ends': 492767,
#   'prev_exon_id': 'ENSE00002064640.1',
#   'next_exon_id': 'ENSE00002058739.1'},
#  {'gene_id': 'ENSG00000278757.1',
#   'transcript_id': 'ENST00000614007.1',
#   'intron_id': 0,
#   'intron_start': 491224,
#   'intron_ends': 516375,
#   'prev_exon_id': 'Start-',
#   'next_exon_id': 'ENSE00003746310.1'},
#  {'gene_id': 'ENSG00000230021.10',
#   'transcript_id': 'ENST00000634833.2',
#   'intron_id': 0,
#   'intron_start': 516375,
#   'intron_ends': 586070,
#   'prev_exon_id': 'Start-',
#   'next_exon_id': 'ENSE00003785196.2'},
#  {'gene_id': 'ENSG00000230021.10',
#   'transcript_id': 'ENST00000634833.2',
#   'intron_id': 1,
#   'intron_start': 586358,
#   'intron_ends': 586820,
#   'prev_exon_id': 'ENSE00003785196.2',
#   'next_exon_id': 'ENSE00001647781.1'},
#  {'gene_id': 'ENSG00000230021.10',
#   'transcript_id': 'ENST00000634833.2',
#   'intron_id': 2,
#   'intron_start': 586955,
#   'intron_ends': 594628,
#   'prev_exon_id': 'ENSE00001647781.1',
#   'next_exon_id': 'ENSE00003785550.1'},
#  {'gene_id': 'ENSG00000230021.10',
#   'transcript_id': 'ENST00000634833.2',
#   'intron_id': 3,
#   'intron_start': 594756,
#   'intron_ends': 601397,
#   'prev_exon_id': 'ENSE00003785550.1',
#   'next_exon_id': 'ENSE00003791521.1'},
#  {'gene_id': 'ENSG00000230021.10',
#   'transcript_id': 'ENST00000634833.2',
#   'intron_id': 4,
#   'intron_start': 601577,
#   'intron_ends': 607954,
#   'prev_exon_id': 'ENSE00003791521.1',
#   'next_exon_id': 'ENSE00001718533.1'},
#  {'gene_id': 'ENSG00000230021.10',
#   'transcript_id': 'ENST00000634833.2',
#   'intron_id': 5,
#   'intron_start': 608056,
#   'intron_ends': 612740,
#   'prev_exon_id': 'ENSE00001718533.1',
#   'next_exon_id': 'ENSE00003812707.1'},
#  {'gene_id': 'ENSG00000230021.10',
#   'transcript_id': 'ENST00000417636.2',
#   'intron_id': 6,
#   'intron_start': 612813,
#   'intron_ends': 586277,
#   'prev_exon_id': 'ENSE00003812707.1',
#   'next_exon_id': 'ENSE00001680902.2'},
#  {'gene_id': 'ENSG00000230021.10',
#   'transcript_id': 'ENST00000417636.2',
#   'intron_id': 7,
#   'intron_start': 586358,
#   'intron_ends': 586820,
#   'prev_exon_id': 'ENSE00001680902.2',
#   'next_exon_id': 'ENSE00001647781.1'},
#  {'gene_id': 'ENSG00000230021.10',
#   'transcript_id': 'ENST00000417636.2',
#   'intron_id': 8,
#   'intron_start': 586955,
#   'intron_ends': 588116,
#   'prev_exon_id': 'ENSE00001647781.1',
#   'next_exon_id': 'ENSE00001738702.1'},
#  {'gene_id': 'ENSG00000230021.10',
#   'transcript_id': 'ENST00000419394.2',
#   'intron_id': 0,
#   'intron_start': 586277,
#   'intron_ends': 586944,
#   'prev_exon_id': 'Start-',
#   'next_exon_id': 'ENSE00003813077.1'},
#  {'gene_id': 'ENSG00000230021.10',
#   'transcript_id': 'ENST00000419394.2',
#   'intron_id': 1,
#   'intron_start': 586955,
#   'intron_ends': 703684,
#   'prev_exon_id': 'ENSE00003813077.1',
#   'next_exon_id': 'ENSE00001671684.1'},
#  {'gene_id': 'ENSG00000230021.10',
#   'transcript_id': 'ENST00000419394.2',
#   'intron_id': 2,
#   'intron_start': 703789,
#   'intron_ends': 711710,
#   'prev_exon_id': 'ENSE00001671684.1',
#   'next_exon_id': 'ENSE00001696741.1'},
#  {'gene_id': 'ENSG00000230021.10',
#   'transcript_id': 'ENST00000419394.2',
#   'intron_id': 3,
#   'intron_start': 711922,
#   'intron_ends': 720031,
#   'prev_exon_id': 'ENSE00001696741.1',
#   'next_exon_id': 'ENSE00001595248.1'},
#  {'gene_id': 'ENSG00000230021.10',
#   'transcript_id': 'ENST00000440196.3',
#   'intron_id': 0,
#   'intron_start': 586944,
#   'intron_ends': 594190,
#   'prev_exon_id': 'Start-',
#   'next_exon_id': 'ENSE00001752275.3'},
#  {'gene_id': 'ENSG00000230021.10',
#   'transcript_id': 'ENST00000440196.3',
#   'intron_id': 1,
#   'intron_start': 594756,
#   'intron_ends': 601397,
#   'prev_exon_id': 'ENSE00001752275.3',
#   'next_exon_id': 'ENSE00003791521.1'},
#  {'gene_id': 'ENSG00000230021.10',
#   'transcript_id': 'ENST00000440196.3',
#   'intron_id': 2,
#   'intron_start': 601577,
#   'intron_ends': 607954,
#   'prev_exon_id': 'ENSE00003791521.1',
#   'next_exon_id': 'ENSE00001718533.1'},
#  {'gene_id': 'ENSG00000230021.10',
#   'transcript_id': 'ENST00000440196.3',
#   'intron_id': 3,
#   'intron_start': 608056,
#   'intron_ends': 628918,
# ...
#   'intron_id': 28,
#   'intron_start': 1050591,
#   'intron_ends': 1050725,
#   'prev_exon_id': 'ENSE00001693596.1',
#   'next_exon_id': 'ENSE00001367302.1'},
#  {'gene_id': 'ENSG00000188157.15',
#   'transcript_id': 'ENST00000620552.4',
#   'intron_id': 29,
#   'intron_start': 1050837,
#   'intron_ends': 1051031,
#   'prev_exon_id': 'ENSE00001367302.1',
#   'next_exon_id': 'ENSE00001651515.1'},
#  {'gene_id': 'ENSG00000188157.15',
#   'transcript_id': 'ENST00000620552.4',
#   'intron_id': 30,
#   'intron_start': 1051043,
#   'intron_ends': 1051252,
#   'prev_exon_id': 'ENSE00001651515.1',
#   'next_exon_id': 'ENSE00001385905.1'},
#  {'gene_id': 'ENSG00000188157.15',
#   'transcript_id': 'ENST00000620552.4',
#   'intron_id': 31,
#   'intron_start': 1051369,
#   'intron_ends': 1051452,
#   'prev_exon_id': 'ENSE00001385905.1',
#   'next_exon_id': 'ENSE00001374645.1'},
#  {'gene_id': 'ENSG00000188157.15',
#   'transcript_id': 'ENST00000620552.4',
#   'intron_id': 32,
#   'intron_start': 1051645,
#   'intron_ends': 1051727,
#   'prev_exon_id': 'ENSE00001374645.1',
#   'next_exon_id': 'ENSE00001381606.1'},
#  {'gene_id': 'ENSG00000188157.15',
#   'transcript_id': 'ENST00000620552.4',
#   'intron_id': 33,
#   'intron_start': 1051815,
#   'intron_ends': 1051992,
#   'prev_exon_id': 'ENSE00001381606.1',
#   'next_exon_id': 'ENSE00001480659.1'},
#  {'gene_id': 'ENSG00000188157.15',
#   'transcript_id': 'ENST00000620552.4',
#   'intron_id': 34,
#   'intron_start': 1052016,
#   'intron_ends': 1053460,
#   'prev_exon_id': 'ENSE00001480659.1',
#   'next_exon_id': 'ENSE00001480658.1'},
#  {'gene_id': 'ENSG00000188157.15',
#   'transcript_id': 'ENST00000620552.4',
#   'intron_id': 35,
#   'intron_start': 1053493,
#   'intron_ends': 1053752,
#   'prev_exon_id': 'ENSE00001480658.1',
#   'next_exon_id': 'ENSE00002692404.1'},
#  {'gene_id': 'ENSG00000188157.15',
#   'transcript_id': 'ENST00000620552.4',
#   'intron_id': 36,
#   'intron_start': 1053977,
#   'intron_ends': 1054447,
#   'prev_exon_id': 'ENSE00002692404.1',
#   'next_exon_id': 'ENSE00003619422.1'},
#  {'gene_id': 'ENSG00000188157.15',
#   'transcript_id': 'ENST00000620552.4',
#   'intron_id': 37,
#   'intron_start': 1054551,
#   'intron_ends': 1054823,
#   'prev_exon_id': 'ENSE00003619422.1',
#   'next_exon_id': 'ENSE00003728327.1'},
#  {'gene_id': 'ENSG00000188157.15',
#   'transcript_id': 'ENST00000651234.1',
#   'intron_id': 38,
#   'intron_start': 1056118,
#   'intron_ends': 1034105,
#   'prev_exon_id': 'ENSE00003728327.1',
#   'next_exon_id': 'ENSE00001908949.1'},
#  {'gene_id': 'ENSG00000188157.15',
#   'transcript_id': 'ENST00000651234.1',
#   'intron_id': 39,
#   'intron_start': 1034703,
#   'intron_ends': 1035276,
#   'prev_exon_id': 'ENSE00001908949.1',
#   'next_exon_id': 'ENSE00003635914.1'},
#  {'gene_id': 'ENSG00000188157.15',
#   'transcript_id': 'ENST00000651234.1',
#   'intron_id': 40,
#   'intron_start': 1035324,
#   'intron_ends': 1040664,
#   'prev_exon_id': 'ENSE00003635914.1',
#   'next_exon_id': 'ENSE00003677060.1'},
#  {'gene_id': 'ENSG00000188157.15',
#   'transcript_id': 'ENST00000651234.1',
#   'intron_id': 41,
#   'intron_start': 1040880,
#   'intron_ends': 1041172,
#   'prev_exon_id': 'ENSE00003677060.1',
#   'next_exon_id': 'ENSE00003472518.1'},
#  {'gene_id': 'ENSG00000188157.15',
#   'transcript_id': 'ENST00000651234.1',
#   'intron_id': 42,
#   'intron_start': 1041397,
#   'intron_ends': 1041477,
#   'prev_exon_id': 'ENSE00003472518.1',
#   'next_exon_id': 'ENSE00001627476.1'},
#  {'gene_id': 'ENSG00000188157.15',
#   'transcript_id': 'ENST00000651234.1',
#   'intron_id': 43,
#   'intron_start': 1041702,
#   'intron_ends': 1041955,
#   'prev_exon_id': 'ENSE00001627476.1',
#   'next_exon_id': 'ENSE00001700910.1'},
#  {'gene_id': 'ENSG00000188157.15',
#   'transcript_id': 'ENST00000651234.1',
#   'intron_id': 44,
#   'intron_start': 1042162,
#   'intron_ends': 1043238,
#   'prev_exon_id': 'ENSE00001700910.1',
#   'next_exon_id': 'ENSE00001605257.1'},
#  {'gene_id': 'ENSG00000188157.15',
#   'transcript_id': 'ENST00000651234.1',
#   'intron_id': 45,
#   'intron_start': 1043457,
#   'intron_ends': 1043537,
#   'prev_exon_id': 'ENSE00001605257.1',
#   'next_exon_id': 'ENSE00001701194.1'},
#  {'gene_id': 'ENSG00000188157.15',
#   'transcript_id': 'ENST00000651234.1',
#   'intron_id': 46,
#   'intron_start': 1043732,
#   'intron_ends': 1043822,
#   'prev_exon_id': 'ENSE00001701194.1',
#   'next_exon_id': 'ENSE00001762402.1'},
#  {'gene_id': 'ENSG00000188157.15',
#   'transcript_id': 'ENST00000651234.1',
#   'intron_id': 47,
#   'intron_start': 1044023,
#   'intron_ends': 1044108,
#   'prev_exon_id': 'ENSE00001762402.1',
#   'next_exon_id': 'ENSE00001653556.1'},
#  {'gene_id': 'ENSG00000188157.15',
#   'transcript_id': 'ENST00000651234.1',
#   'intron_id': 48,
#   'intron_start': 1044257,
#   'intron_ends': 1044333,
#   'prev_exon_id': 'ENSE00001653556.1',
#   'next_exon_id': 'ENSE00001773423.1'},
#  {'gene_id': 'ENSG00000188157.15',
#   'transcript_id': 'ENST00000651234.1',
#   'intron_id': 49,
#   'intron_start': 1044439,
#   'intron_ends': 1045160,
#   'prev_exon_id': 'ENSE00001773423.1',
#   'next_exon_id': 'ENSE00001688790.1'},
#  {'gene_id': 'ENSG00000188157.15',
#   'transcript_id': 'ENST00000651234.1',
#   'intron_id': 50,
#   'intron_start': 1045277,
#   'intron_ends': 1045358,
#   'prev_exon_id': 'ENSE00001688790.1',
#   'next_exon_id': 'ENSE00001737074.1'},
#  {'gene_id': 'ENSG00000188157.15',
#   'transcript_id': 'ENST00000651234.1',
#   'intron_id': 51,
#   'intron_start': 1045523,
#   'intron_ends': 1045732,
#   'prev_exon_id': 'ENSE00001737074.1',
#   'next_exon_id': 'ENSE00003686258.1'},
#  {'gene_id': 'ENSG00000188157.15',
#   'transcript_id': 'ENST00000651234.1',
#   'intron_id': 52,
#   'intron_start': 1045876,
#   'intron_ends': 1045963,
#   'prev_exon_id': 'ENSE00003686258.1',
#   'next_exon_id': 'ENSE00003684009.1'},
#  {'gene_id': 'ENSG00000188157.15',
#   'transcript_id': 'ENST00000651234.1',
#   'intron_id': 53,
#   'intron_start': 1046088,
#   'intron_ends': 1046159,
#   'prev_exon_id': 'ENSE00003684009.1',
#   'next_exon_id': 'ENSE00001652878.1'},
#  {'gene_id': 'ENSG00000188157.15',
#   'transcript_id': 'ENST00000651234.1',
#   'intron_id': 54,
#   'intron_start': 1046265,
#   'intron_ends': 1046396,
#   'prev_exon_id': 'ENSE00001652878.1',
#   'next_exon_id': 'ENSE00001750513.1'},
#  {'gene_id': 'ENSG00000188157.15',
#   'transcript_id': 'ENST00000651234.1',
#   'intron_id': 55,
#   'intron_start': 1046735,
#   'intron_ends': 1046819,
#   'prev_exon_id': 'ENSE00001750513.1',
#   'next_exon_id': 'ENSE00001787340.1'},
#  {'gene_id': 'ENSG00000188157.15',
#   'transcript_id': 'ENST00000651234.1',
#   'intron_id': 56,
#   'intron_start': 1046957,
#   'intron_ends': 1047326,
#   'prev_exon_id': 'ENSE00001787340.1',
#   'next_exon_id': 'ENSE00001622111.1'},
#  {'gene_id': 'ENSG00000188157.15',
#   'transcript_id': 'ENST00000651234.1',
#   'intron_id': 57,
#   'intron_start': 1047454,
#   'intron_ends': 1047572,
#   'prev_exon_id': 'ENSE00001622111.1',
#   'next_exon_id': 'ENSE00003529542.1'},
#  {'gene_id': 'ENSG00000188157.15',
#   'transcript_id': 'ENST00000651234.1',
#   'intron_id': 58,
#   'intron_start': 1047687,
#   'intron_ends': 1047775,
#   'prev_exon_id': 'ENSE00003529542.1',
#   'next_exon_id': 'ENSE00001667688.1'},
#  {'gene_id': 'ENSG00000188157.15',
#   'transcript_id': 'ENST00000651234.1',
#   'intron_id': 59,
#   'intron_start': 1047895,
#   'intron_ends': 1048011,
#   'prev_exon_id': 'ENSE00001667688.1',
#   'next_exon_id': 'ENSE00001650172.1'},
#  {'gene_id': 'ENSG00000188157.15',
#   'transcript_id': 'ENST00000651234.1',
#   'intron_id': 60,
#   'intron_start': 1048365,
#   'intron_ends': 1048866,
#   'prev_exon_id': 'ENSE00001650172.1',
#   'next_exon_id': 'ENSE00001641464.1'},
#  {'gene_id': 'ENSG00000188157.15',
#   'transcript_id': 'ENST00000651234.1',
#   'intron_id': 61,
#   'intron_start': 1049059,
#   'intron_ends': 1049235,
#   'prev_exon_id': 'ENSE00001641464.1',
#   'next_exon_id': 'ENSE00001706121.1'},
#  {'gene_id': 'ENSG00000188157.15',
#   'transcript_id': 'ENST00000651234.1',
#   'intron_id': 62,
#   'intron_start': 1049451,
#   'intron_ends': 1049565,
#   'prev_exon_id': 'ENSE00001706121.1',
#   'next_exon_id': 'ENSE00001622861.1'},
#  {'gene_id': 'ENSG00000188157.15',
#   'transcript_id': 'ENST00000651234.1',
#   'intron_id': 63,
#   'intron_start': 1049795,
#   'intron_ends': 1049902,
#   'prev_exon_id': 'ENSE00001622861.1',
#   'next_exon_id': 'ENSE00001756488.1'},
#  {'gene_id': 'ENSG00000188157.15',
#   'transcript_id': 'ENST00000651234.1',
#   'intron_id': 64,
#   'intron_start': 1050037,
#   'intron_ends': 1050232,
#   'prev_exon_id': 'ENSE00001756488.1',
#   'next_exon_id': 'ENSE00001657020.1'},
#  {'gene_id': 'ENSG00000188157.15',
#   'transcript_id': 'ENST00000651234.1',
#   'intron_id': 65,
#   'intron_start': 1050329,
#   'intron_ends': 1050426,
#   'prev_exon_id': 'ENSE00001657020.1',
#   'next_exon_id': 'ENSE00001693596.1'},
#  {'gene_id': 'ENSG00000188157.15',
#   'transcript_id': 'ENST00000651234.1',
#   'intron_id': 66,
#   'intron_start': 1050591,
#   'intron_ends': 1050725,
#   'prev_exon_id': 'ENSE00001693596.1',
#   'next_exon_id': 'ENSE00001367302.1'},
#  {'gene_id': 'ENSG00000188157.15',
#   'transcript_id': 'ENST00000651234.1',
#   'intron_id': 67,
#   'intron_start': 1050837,
#   'intron_ends': 1051031,
#   'prev_exon_id': 'ENSE00001367302.1',
#   'next_exon_id': 'ENSE00001651515.1'},
#  {'gene_id': 'ENSG00000188157.15',
#   'transcript_id': 'ENST00000651234.1',
#   'intron_id': 68,
#   'intron_start': 1051043,
#   'intron_ends': 1051252,
#   'prev_exon_id': 'ENSE00001651515.1',
#   'next_exon_id': 'ENSE00001385905.1'},
#  {'gene_id': 'ENSG00000188157.15',
#   'transcript_id': 'ENST00000651234.1',
#   'intron_id': 69,
#   'intron_start': 1051369,
#   'intron_ends': 1051452,
#   'prev_exon_id': 'ENSE00001385905.1',
#   'next_exon_id': 'ENSE00001374645.1'},
#  {'gene_id': 'ENSG00000188157.15',
#   'transcript_id': 'ENST00000651234.1',
#   'intron_id': 70,
#   'intron_start': 1051645,
#   'intron_ends': 1051727,
#   'prev_exon_id': 'ENSE00001374645.1',
#   'next_exon_id': 'ENSE00001381606.1'},
#  {'gene_id': 'ENSG00000188157.15',
#   'transcript_id': 'ENST00000651234.1',
#   'intron_id': 71,
#   'intron_start': 1051815,
#   'intron_ends': 1051992,
#   'prev_exon_id': 'ENSE00001381606.1',
#   'next_exon_id': 'ENSE00001480659.1'},
#  {'gene_id': 'ENSG00000188157.15',
#   'transcript_id': 'ENST00000651234.1',
#   'intron_id': 72,
#   'intron_start': 1052016,
#   'intron_ends': 1053460,
#   'prev_exon_id': 'ENSE00001480659.1',
#   'next_exon_id': 'ENSE00001480658.1'},
#  {'gene_id': 'ENSG00000188157.15',
#   'transcript_id': 'ENST00000651234.1',
#   'intron_id': 73,
#   'intron_start': 1053493,
#   'intron_ends': 1053752,
#   'prev_exon_id': 'ENSE00001480658.1',
#   'next_exon_id': 'ENSE00002692404.1'},
#  {'gene_id': 'ENSG00000188157.15',
#   'transcript_id': 'ENST00000651234.1',
#   'intron_id': 74,
#   'intron_start': 1053977,
#   'intron_ends': 1054447,
#   'prev_exon_id': 'ENSE00002692404.1',
#   'next_exon_id': 'ENSE00003619422.1'},
#  {'gene_id': 'ENSG00000188157.15',
#   'transcript_id': 'ENST00000651234.1',
#   'intron_id': 75,
#   'intron_start': 1054551,
#   'intron_ends': 1054823,
#   'prev_exon_id': 'ENSE00003619422.1',
#   'next_exon_id': 'ENSE00001883271.1'},
#  {'gene_id': 'ENSG00000188157.15',
#   'transcript_id': 'ENST00000652369.1',
#   'intron_id': 0,
#   'intron_start': 1034703,
#   'intron_ends': 1035276,
#   'prev_exon_id': 'ENSE00001908949.1',
#   'next_exon_id': 'ENSE00003635914.1'},
#  {'gene_id': 'ENSG00000188157.15',
#   'transcript_id': 'ENST00000652369.1',
#   'intron_id': 1,
#   'intron_start': 1035324,
#   'intron_ends': 1040664,
#   'prev_exon_id': 'ENSE00003635914.1',
#   'next_exon_id': 'ENSE00003677060.1'},
#  {'gene_id': 'ENSG00000188157.15',
#   'transcript_id': 'ENST00000652369.1',
#   'intron_id': 2,
#   'intron_start': 1040880,
#   'intron_ends': 1041172,
#   'prev_exon_id': 'ENSE00003677060.1',
#   'next_exon_id': 'ENSE00003472518.1'},
#  {'gene_id': 'ENSG00000188157.15',
#   'transcript_id': 'ENST00000652369.1',
#   'intron_id': 3,
#   'intron_start': 1041397,
#   'intron_ends': 1041477,
#   'prev_exon_id': 'ENSE00003472518.1',
#   'next_exon_id': 'ENSE00001627476.1'},
#  {'gene_id': 'ENSG00000188157.15',
#   'transcript_id': 'ENST00000652369.1',
#   'intron_id': 4,
#   'intron_start': 1041702,
#   'intron_ends': 1041955,
#   'prev_exon_id': 'ENSE00001627476.1',
#   'next_exon_id': 'ENSE00001700910.1'},
#  {'gene_id': 'ENSG00000188157.15',
#   'transcript_id': 'ENST00000652369.1',
#   'intron_id': 5,
#   'intron_start': 1042162,
#   'intron_ends': 1043238,
#   'prev_exon_id': 'ENSE00001700910.1',
#   'next_exon_id': 'ENSE00001605257.1'},
#  {'gene_id': 'ENSG00000188157.15',
#   'transcript_id': 'ENST00000652369.1',
#   'intron_id': 6,
#   'intron_start': 1043457,
#   'intron_ends': 1043537,
#   'prev_exon_id': 'ENSE00001605257.1',
#   'next_exon_id': 'ENSE00001701194.1'},
#  {'gene_id': 'ENSG00000188157.15',
#   'transcript_id': 'ENST00000652369.1',
#   'intron_id': 7,
#   'intron_start': 1043732,
#   'intron_ends': 1043822,
#   'prev_exon_id': 'ENSE00001701194.1',
#   'next_exon_id': 'ENSE00001762402.1'},
#  {'gene_id': 'ENSG00000188157.15',
#   'transcript_id': 'ENST00000652369.1',
#   'intron_id': 8,
#   'intron_start': 1044023,
#   'intron_ends': 1044108,
#   'prev_exon_id': 'ENSE00001762402.1',
#   'next_exon_id': 'ENSE00001653556.1'},
#  {'gene_id': 'ENSG00000188157.15',
#   'transcript_id': 'ENST00000652369.1',
#   'intron_id': 9,
#   'intron_start': 1044257,
#   'intron_ends': 1044333,
#   'prev_exon_id': 'ENSE00001653556.1',
#   'next_exon_id': 'ENSE00001773423.1'},
#  {'gene_id': 'ENSG00000188157.15',
#   'transcript_id': 'ENST00000652369.1',
#   'intron_id': 10,
#   'intron_start': 1044439,
#   'intron_ends': 1045160,
#   'prev_exon_id': 'ENSE00001773423.1',
#   'next_exon_id': 'ENSE00001688790.1'},
#  {'gene_id': 'ENSG00000188157.15',
#   'transcript_id': 'ENST00000652369.1',
#   'intron_id': 11,
#   'intron_start': 1045277,
#   'intron_ends': 1045358,
#   'prev_exon_id': 'ENSE00001688790.1',
#   'next_exon_id': 'ENSE00001737074.1'},
#  {'gene_id': 'ENSG00000188157.15',
#   'transcript_id': 'ENST00000652369.1',
#   'intron_id': 12,
#   'intron_start': 1045523,
#   'intron_ends': 1045732,
#   'prev_exon_id': 'ENSE00001737074.1',
#   'next_exon_id': 'ENSE00003686258.1'},
#  {'gene_id': 'ENSG00000188157.15',
#   'transcript_id': 'ENST00000652369.1',
#   'intron_id': 13,
#   'intron_start': 1045876,
#   'intron_ends': 1045963,
#   'prev_exon_id': 'ENSE00003686258.1',
#   'next_exon_id': 'ENSE00003684009.1'},
#  {'gene_id': 'ENSG00000188157.15',
#   'transcript_id': 'ENST00000652369.1',
#   'intron_id': 14,
#   'intron_start': 1046088,
#   'intron_ends': 1046159,
#   'prev_exon_id': 'ENSE00003684009.1',
#   'next_exon_id': 'ENSE00001652878.1'},
#  {'gene_id': 'ENSG00000188157.15',
#   'transcript_id': 'ENST00000652369.1',
#   'intron_id': 15,
#   'intron_start': 1046265,
#   'intron_ends': 1046396,
#   'prev_exon_id': 'ENSE00001652878.1',
#   'next_exon_id': 'ENSE00001750513.1'},
#  {'gene_id': 'ENSG00000188157.15',
#   'transcript_id': 'ENST00000652369.1',
#   'intron_id': 16,
#   'intron_start': 1046735,
#   'intron_ends': 1046819,
#   'prev_exon_id': 'ENSE00001750513.1',
#   'next_exon_id': 'ENSE00001787340.1'},
#  {'gene_id': 'ENSG00000188157.15',
#   'transcript_id': 'ENST00000652369.1',
#   'intron_id': 17,
#   'intron_start': 1046957,
#   'intron_ends': 1047326,
#   'prev_exon_id': 'ENSE00001787340.1',
#   'next_exon_id': 'ENSE00001622111.1'},
#  {'gene_id': 'ENSG00000188157.15',
#   'transcript_id': 'ENST00000652369.1',
#   'intron_id': 18,
#   'intron_start': 1047454,
#   'intron_ends': 1047572,
#   'prev_exon_id': 'ENSE00001622111.1',
#   'next_exon_id': 'ENSE00003529542.1'},
#  {'gene_id': 'ENSG00000188157.15',
#   'transcript_id': 'ENST00000652369.1',
#   'intron_id': 19,
#   'intron_start': 1047687,
#   'intron_ends': 1047775,
#   'prev_exon_id': 'ENSE00003529542.1',
#   'next_exon_id': 'ENSE00001667688.1'},
#  {'gene_id': 'ENSG00000188157.15',
#   'transcript_id': 'ENST00000652369.1',
#   'intron_id': 20,
#   'intron_start': 1047895,
#   'intron_ends': 1048011,
#   'prev_exon_id': 'ENSE00001667688.1',
#   'next_exon_id': 'ENSE00001650172.1'},
#  {'gene_id': 'ENSG00000188157.15',
#   'transcript_id': 'ENST00000652369.1',
#   'intron_id': 21,
#   'intron_start': 1048365,
#   'intron_ends': 1048866,
#   'prev_exon_id': 'ENSE00001650172.1',
#   'next_exon_id': 'ENSE00001641464.1'},
#  {'gene_id': 'ENSG00000188157.15',
#   'transcript_id': 'ENST00000652369.1',
#   'intron_id': 22,
#   'intron_start': 1049059,
#   'intron_ends': 1049235,
#   'prev_exon_id': 'ENSE00001641464.1',
#   'next_exon_id': 'ENSE00001706121.1'},
#  ...]

# %%
len(introns_lst)
# Out:
# 1511324

# %%
df_introns = pd.DataFrame(introns_lst.copy())
df_introns.to_csv("gencode_v44_introns.csv", index=False)
df_introns
# Out:
#                    gene_id      transcript_id  intron_id  intron_start  \
# 0        ENSG00000290825.1  ENST00000456328.2          0         12227
# 1        ENSG00000290825.1  ENST00000456328.2          1         12721
# 2        ENSG00000223972.6  ENST00000450305.2          0         12057
# 3        ENSG00000223972.6  ENST00000450305.2          1         12227
# 4        ENSG00000223972.6  ENST00000450305.2          2         12697
# ...                    ...                ...        ...           ...
# 1511319  ENSG00000292371.1  ENST00000711270.1          0         15955
# 1511320  ENSG00000292371.1  ENST00000711270.1          1      57213125
# 1511321  ENSG00000292371.1  ENST00000711270.1          2      57213357
# 1511322  ENSG00000292371.1  ENST00000711270.1          3      57213602
# 1511323  ENSG00000292371.1  ENST00000711270.1          4      57213964
#
#          intron_ends       prev_exon_id       next_exon_id
# 0              12612  ENSE00002234944.1  ENSE00003582793.1
# 1              13220  ENSE00003582793.1  ENSE00002312635.1
# 2              12178  ENSE00001948541.1  ENSE00001671638.2
# 3              12612  ENSE00001671638.2  ENSE00001758273.2
# 4              12974  ENSE00001758273.2  ENSE00001799933.2
# ...              ...                ...                ...
# 1511319     57212183             Start-  ENSE00004015127.1
# 1511320     57213203  ENSE00004015127.1  ENSE00004015126.1
# 1511321     57213525  ENSE00004015126.1  ENSE00004015125.1
# 1511322     57213879  ENSE00004015125.1  ENSE00004015124.1
# 1511323     57214349  ENSE00004015124.1  ENSE00004015123.1
#
# [1511324 rows x 7 columns]

# %%
df_introns_1_based = df_introns.copy()
df_introns_1_based.intron_start = df_introns_1_based.intron_start + 1
df_introns_1_based
# Out:
#                      gene_id        transcript_id  intron_id  intron_start  \
# 0        [ENSG00000290825.1]  [ENST00000456328.2]          0         12228
# 1        [ENSG00000290825.1]  [ENST00000456328.2]          1         12722
# 2        [ENSG00000223972.6]  [ENST00000450305.2]          0         12058
# 3        [ENSG00000223972.6]  [ENST00000450305.2]          1         12228
# 4        [ENSG00000223972.6]  [ENST00000450305.2]          2         12698
# ...                      ...                  ...        ...           ...
# 1511319  [ENSG00000292371.1]  [ENST00000711270.1]          0         15956
# 1511320  [ENSG00000292371.1]  [ENST00000711270.1]          1      57213126
# 1511321  [ENSG00000292371.1]  [ENST00000711270.1]          2      57213358
# 1511322  [ENSG00000292371.1]  [ENST00000711270.1]          3      57213603
# 1511323  [ENSG00000292371.1]  [ENST00000711270.1]          4      57213965
#
#          intron_ends       prev_exon_id       next_exon_id
# 0              12612  ENSE00002234944.1  ENSE00003582793.1
# 1              13220  ENSE00003582793.1  ENSE00002312635.1
# 2              12178  ENSE00001948541.1  ENSE00001671638.2
# 3              12612  ENSE00001671638.2  ENSE00001758273.2
# 4              12974  ENSE00001758273.2  ENSE00001799933.2
# ...              ...                ...                ...
# 1511319     57212183             Start-  ENSE00004015127.1
# 1511320     57213203  ENSE00004015127.1  ENSE00004015126.1
# 1511321     57213525  ENSE00004015126.1  ENSE00004015125.1
# 1511322     57213879  ENSE00004015125.1  ENSE00004015124.1
# 1511323     57214349  ENSE00004015124.1  ENSE00004015123.1
#
# [1511324 rows x 7 columns]

# %%
df_introns_1_based[df_introns_1_based.intron_start == 962048]
# Out:
#                   gene_id        transcript_id  intron_id  intron_start  \
# 766  [ENSG00000187961.15]  [ENST00000338591.8]          3        962048
#
#      intron_ends       prev_exon_id       next_exon_id
# 766       962354  ENSE00003185989.1  ENSE00001375296.1

# %%
df_introns_1_based[df_introns_1_based.intron_start == 155357520]
# Out:
#                      gene_id        transcript_id  intron_id  intron_start  \
# 413070  [ENSG00000164114.19]  [ENST00000311277.9]          7     155357520
# 413084  [ENSG00000164114.19]  [ENST00000650955.1]          7     155357520
# 413098  [ENSG00000164114.19]  [ENST00000515654.5]          7     155357520
# 413112  [ENSG00000164114.19]  [ENST00000424373.5]          5     155357520
# 413123  [ENSG00000164114.19]  [ENST00000433024.5]          4     155357520
#
#         intron_ends       prev_exon_id       next_exon_id
# 413070    155360167  ENSE00001081579.1  ENSE00001081582.1
# 413084    155360167  ENSE00001081579.1  ENSE00001081582.1
# 413098    155360167  ENSE00001081579.1  ENSE00002024875.1
# 413112    155360167  ENSE00001081579.1  ENSE00001081582.1
# 413123    155360167  ENSE00001081579.1  ENSE00001081582.1
