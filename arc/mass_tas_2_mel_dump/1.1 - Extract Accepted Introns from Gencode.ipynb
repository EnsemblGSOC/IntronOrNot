# %%
import pandas as pd
from BCBio.GFF import GFFExaminer
from BCBio import GFF

# %%
in_file = "./ftp-data/gencode.v44.annotation.gtf"
examiner = GFFExaminer()

# %%
limit_info = {"gff_type": ["transcript", "exon"]}
current_gene = None
last_index = None
introns_lst = []
with open(in_file) as handle:
    for rec in GFF.parse(handle, limit_info=limit_info, target_lines=100):
        for feature in rec.features:
            loop = feature.sub_features if feature.strand == 1 else feature.sub_features[::-1]
            first_exon = True
            for sub_features in loop:
                if sub_features.type == "exon":
                    if not first_exon:
                        intron_dict = {
                            "chr": rec.id,
                            "gene_id": sub_features.qualifiers["gene_id"][0],
                            "transcript_id": sub_features.qualifiers["transcript_id"][0],
                            # "intron_id": intron_id,
                            "start": last_index,
                            "end": sub_features.location.start.position,
                            "strand": "+" if feature.strand == 1 else "-",
                            "prev_exon_id": previous_exon_name,
                            "next_exon_id": sub_features.qualifiers["exon_id"][0]
                        }
                        introns_lst.append(intron_dict)
                    last_index = sub_features.location.end.position
                    previous_exon_name = sub_features.qualifiers["exon_id"][0]

                    first_exon = False

introns_lst
# Out:
# [{'chr': 'chr1',
#   'gene_id': 'ENSG00000290825.1',
#   'transcript_id': 'ENST00000456328.2',
#   'start': 12227,
#   'end': 12612,
#   'strand': '+',
#   'prev_exon_id': 'ENSE00002234944.1',
#   'next_exon_id': 'ENSE00003582793.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000290825.1',
#   'transcript_id': 'ENST00000456328.2',
#   'start': 12721,
#   'end': 13220,
#   'strand': '+',
#   'prev_exon_id': 'ENSE00003582793.1',
#   'next_exon_id': 'ENSE00002312635.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000223972.6',
#   'transcript_id': 'ENST00000450305.2',
#   'start': 12057,
#   'end': 12178,
#   'strand': '+',
#   'prev_exon_id': 'ENSE00001948541.1',
#   'next_exon_id': 'ENSE00001671638.2'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000223972.6',
#   'transcript_id': 'ENST00000450305.2',
#   'start': 12227,
#   'end': 12612,
#   'strand': '+',
#   'prev_exon_id': 'ENSE00001671638.2',
#   'next_exon_id': 'ENSE00001758273.2'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000223972.6',
#   'transcript_id': 'ENST00000450305.2',
#   'start': 12697,
#   'end': 12974,
#   'strand': '+',
#   'prev_exon_id': 'ENSE00001758273.2',
#   'next_exon_id': 'ENSE00001799933.2'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000223972.6',
#   'transcript_id': 'ENST00000450305.2',
#   'start': 13052,
#   'end': 13220,
#   'strand': '+',
#   'prev_exon_id': 'ENSE00001799933.2',
#   'next_exon_id': 'ENSE00001746346.2'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000223972.6',
#   'transcript_id': 'ENST00000450305.2',
#   'start': 13374,
#   'end': 13452,
#   'strand': '+',
#   'prev_exon_id': 'ENSE00001746346.2',
#   'next_exon_id': 'ENSE00001863096.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000227232.5',
#   'transcript_id': 'ENST00000488147.1',
#   'start': 14501,
#   'end': 15004,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00001843071.1',
#   'next_exon_id': 'ENSE00001935574.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000227232.5',
#   'transcript_id': 'ENST00000488147.1',
#   'start': 15038,
#   'end': 15795,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00001935574.1',
#   'next_exon_id': 'ENSE00002030414.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000227232.5',
#   'transcript_id': 'ENST00000488147.1',
#   'start': 15947,
#   'end': 16606,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00002030414.1',
#   'next_exon_id': 'ENSE00003621279.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000227232.5',
#   'transcript_id': 'ENST00000488147.1',
#   'start': 16765,
#   'end': 16857,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00003621279.1',
#   'next_exon_id': 'ENSE00003553898.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000227232.5',
#   'transcript_id': 'ENST00000488147.1',
#   'start': 17055,
#   'end': 17232,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00003553898.1',
#   'next_exon_id': 'ENSE00003502542.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000227232.5',
#   'transcript_id': 'ENST00000488147.1',
#   'start': 17368,
#   'end': 17605,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00003502542.1',
#   'next_exon_id': 'ENSE00003475637.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000227232.5',
#   'transcript_id': 'ENST00000488147.1',
#   'start': 17742,
#   'end': 17914,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00003475637.1',
#   'next_exon_id': 'ENSE00003565697.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000227232.5',
#   'transcript_id': 'ENST00000488147.1',
#   'start': 18061,
#   'end': 18267,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00003565697.1',
#   'next_exon_id': 'ENSE00003477500.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000227232.5',
#   'transcript_id': 'ENST00000488147.1',
#   'start': 18366,
#   'end': 24737,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00003477500.1',
#   'next_exon_id': 'ENSE00003507205.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000227232.5',
#   'transcript_id': 'ENST00000488147.1',
#   'start': 24891,
#   'end': 29533,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00003507205.1',
#   'next_exon_id': 'ENSE00001890219.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000243485.5',
#   'transcript_id': 'ENST00000473358.1',
#   'start': 30039,
#   'end': 30563,
#   'strand': '+',
#   'prev_exon_id': 'ENSE00001947070.1',
#   'next_exon_id': 'ENSE00001922571.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000243485.5',
#   'transcript_id': 'ENST00000473358.1',
#   'start': 30667,
#   'end': 30975,
#   'strand': '+',
#   'prev_exon_id': 'ENSE00001922571.1',
#   'next_exon_id': 'ENSE00001827679.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000243485.5',
#   'transcript_id': 'ENST00000469289.1',
#   'start': 30667,
#   'end': 30975,
#   'strand': '+',
#   'prev_exon_id': 'ENSE00001841699.1',
#   'next_exon_id': 'ENSE00001890064.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000237613.2',
#   'transcript_id': 'ENST00000417324.1',
#   'start': 35174,
#   'end': 35276,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00001727627.1',
#   'next_exon_id': 'ENSE00001669267.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000237613.2',
#   'transcript_id': 'ENST00000417324.1',
#   'start': 35481,
#   'end': 35720,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00001669267.1',
#   'next_exon_id': 'ENSE00001656588.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000237613.2',
#   'transcript_id': 'ENST00000461467.1',
#   'start': 35481,
#   'end': 35720,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00001874421.1',
#   'next_exon_id': 'ENSE00001618781.2'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000290826.1',
#   'transcript_id': 'ENST00000642116.1',
#   'start': 57653,
#   'end': 58699,
#   'strand': '+',
#   'prev_exon_id': 'ENSE00003812686.1',
#   'next_exon_id': 'ENSE00003812505.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000290826.1',
#   'transcript_id': 'ENST00000642116.1',
#   'start': 58856,
#   'end': 62915,
#   'strand': '+',
#   'prev_exon_id': 'ENSE00003812505.1',
#   'next_exon_id': 'ENSE00003811818.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000186092.7',
#   'transcript_id': 'ENST00000641515.2',
#   'start': 65433,
#   'end': 65519,
#   'strand': '+',
#   'prev_exon_id': 'ENSE00003812156.1',
#   'next_exon_id': 'ENSE00003813641.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000186092.7',
#   'transcript_id': 'ENST00000641515.2',
#   'start': 65573,
#   'end': 69036,
#   'strand': '+',
#   'prev_exon_id': 'ENSE00003813641.1',
#   'next_exon_id': 'ENSE00003813949.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000238009.6',
#   'transcript_id': 'ENST00000466430.5',
#   'start': 91629,
#   'end': 92090,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00001846804.1',
#   'next_exon_id': 'ENSE00001944529.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000238009.6',
#   'transcript_id': 'ENST00000466430.5',
#   'start': 92240,
#   'end': 112699,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00001944529.1',
#   'next_exon_id': 'ENSE00001957285.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000238009.6',
#   'transcript_id': 'ENST00000466430.5',
#   'start': 112804,
#   'end': 120774,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00001957285.1',
#   'next_exon_id': 'ENSE00001606755.2'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000238009.6',
#   'transcript_id': 'ENST00000477740.5',
#   'start': 92240,
#   'end': 112699,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00001896976.1',
#   'next_exon_id': 'ENSE00001957285.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000238009.6',
#   'transcript_id': 'ENST00000477740.5',
#   'start': 112804,
#   'end': 120720,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00001957285.1',
#   'next_exon_id': 'ENSE00001171005.3'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000238009.6',
#   'transcript_id': 'ENST00000477740.5',
#   'start': 120932,
#   'end': 129054,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00001171005.3',
#   'next_exon_id': 'ENSE00001919246.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000238009.6',
#   'transcript_id': 'ENST00000471248.1',
#   'start': 111357,
#   'end': 112699,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00001879696.1',
#   'next_exon_id': 'ENSE00001957285.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000238009.6',
#   'transcript_id': 'ENST00000471248.1',
#   'start': 112804,
#   'end': 129054,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00001957285.1',
#   'next_exon_id': 'ENSE00001934975.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000238009.6',
#   'transcript_id': 'ENST00000610542.1',
#   'start': 120869,
#   'end': 120873,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00003749543.1',
#   'next_exon_id': 'ENSE00003740919.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000238009.6',
#   'transcript_id': 'ENST00000610542.1',
#   'start': 120932,
#   'end': 129054,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00003740919.1',
#   'next_exon_id': 'ENSE00003734824.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000238009.6',
#   'transcript_id': 'ENST00000610542.1',
#   'start': 129223,
#   'end': 133373,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00003734824.1',
#   'next_exon_id': 'ENSE00003748456.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000238009.6',
#   'transcript_id': 'ENST00000453576.2',
#   'start': 129223,
#   'end': 133373,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00001827073.1',
#   'next_exon_id': 'ENSE00001737600.2'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000239945.1',
#   'transcript_id': 'ENST00000495576.1',
#   'start': 90050,
#   'end': 90286,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00001927725.1',
#   'next_exon_id': 'ENSE00001907785.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000239906.1',
#   'transcript_id': 'ENST00000493797.1',
#   'start': 139847,
#   'end': 140074,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00001922992.1',
#   'next_exon_id': 'ENSE00001913281.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000241860.7',
#   'transcript_id': 'ENST00000484859.1',
#   'start': 143011,
#   'end': 146385,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00001911218.1',
#   'next_exon_id': 'ENSE00001860404.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000241860.7',
#   'transcript_id': 'ENST00000490997.5',
#   'start': 143011,
#   'end': 146385,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00001838397.1',
#   'next_exon_id': 'ENSE00001853409.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000241860.7',
#   'transcript_id': 'ENST00000490997.5',
#   'start': 146509,
#   'end': 146641,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00001853409.1',
#   'next_exon_id': 'ENSE00001868647.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000241860.7',
#   'transcript_id': 'ENST00000466557.6',
#   'start': 146509,
#   'end': 155766,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00001853409.1',
#   'next_exon_id': 'ENSE00001799309.2'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000241860.7',
#   'transcript_id': 'ENST00000466557.6',
#   'start': 155831,
#   'end': 164262,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00001799309.2',
#   'next_exon_id': 'ENSE00001862111.2'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000241860.7',
#   'transcript_id': 'ENST00000466557.6',
#   'start': 164791,
#   'end': 165883,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00001862111.2',
#   'next_exon_id': 'ENSE00001949945.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000241860.7',
#   'transcript_id': 'ENST00000466557.6',
#   'start': 165942,
#   'end': 168099,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00001949945.1',
#   'next_exon_id': 'ENSE00001947087.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000241860.7',
#   'transcript_id': 'ENST00000466557.6',
#   'start': 168165,
#   'end': 169048,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00001947087.1',
#   'next_exon_id': 'ENSE00001922566.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000241860.7',
#   'transcript_id': 'ENST00000466557.6',
#   'start': 169264,
#   'end': 172556,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00001922566.1',
#   'next_exon_id': 'ENSE00001890990.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000241860.7',
#   'transcript_id': 'ENST00000466557.6',
#   'start': 172688,
#   'end': 173752,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00001890990.1',
#   'next_exon_id': 'ENSE00001947154.2'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000241860.7',
#   'transcript_id': 'ENST00000662089.1',
#   'start': 165942,
#   'end': 167958,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00003873220.1',
#   'next_exon_id': 'ENSE00003868429.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000241860.7',
#   'transcript_id': 'ENST00000662089.1',
#   'start': 168165,
#   'end': 169048,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00003868429.1',
#   'next_exon_id': 'ENSE00003878614.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000241860.7',
#   'transcript_id': 'ENST00000491962.1',
#   'start': 165942,
#   'end': 168099,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00001898156.1',
#   'next_exon_id': 'ENSE00001947087.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000241860.7',
#   'transcript_id': 'ENST00000491962.1',
#   'start': 168165,
#   'end': 168609,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00001947087.1',
#   'next_exon_id': 'ENSE00001939117.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000241860.7',
#   'transcript_id': 'ENST00000655252.1',
#   'start': 168165,
#   'end': 169048,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00003876756.1',
#   'next_exon_id': 'ENSE00003878771.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000241599.1',
#   'transcript_id': 'ENST00000496488.1',
#   'start': 160690,
#   'end': 161313,
#   'strand': '+',
#   'prev_exon_id': 'ENSE00001882727.1',
#   'next_exon_id': 'ENSE00001895361.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000279928.2',
#   'transcript_id': 'ENST00000624431.2',
#   'start': 182746,
#   'end': 183131,
#   'strand': '+',
#   'prev_exon_id': 'ENSE00003759020.2',
#   'next_exon_id': 'ENSE00003759581.2'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000279928.2',
#   'transcript_id': 'ENST00000624431.2',
#   'start': 183216,
#   'end': 183493,
#   'strand': '+',
#   'prev_exon_id': 'ENSE00003759581.2',
#   'next_exon_id': 'ENSE00003804405.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000279928.2',
#   'transcript_id': 'ENST00000624431.2',
#   'start': 183571,
#   'end': 183739,
#   'strand': '+',
#   'prev_exon_id': 'ENSE00003804405.1',
#   'next_exon_id': 'ENSE00003807458.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000279928.2',
#   'transcript_id': 'ENST00000624431.2',
#   'start': 183901,
#   'end': 183980,
#   'strand': '+',
#   'prev_exon_id': 'ENSE00003807458.1',
#   'next_exon_id': 'ENSE00003760199.2'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000279457.4',
#   'transcript_id': 'ENST00000623083.4',
#   'start': 185350,
#   'end': 185490,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00003755076.2',
#   'next_exon_id': 'ENSE00003757943.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000279457.4',
#   'transcript_id': 'ENST00000623083.4',
#   'start': 185559,
#   'end': 186316,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00003757943.1',
#   'next_exon_id': 'ENSE00003757727.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000279457.4',
#   'transcript_id': 'ENST00000623083.4',
#   'start': 186469,
#   'end': 187128,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00003757727.1',
#   'next_exon_id': 'ENSE00003759679.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000279457.4',
#   'transcript_id': 'ENST00000623083.4',
#   'start': 187287,
#   'end': 187375,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00003759679.1',
#   'next_exon_id': 'ENSE00003755701.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000279457.4',
#   'transcript_id': 'ENST00000623083.4',
#   'start': 187577,
#   'end': 187754,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00003755701.1',
#   'next_exon_id': 'ENSE00003757255.2'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000279457.4',
#   'transcript_id': 'ENST00000623083.4',
#   'start': 187890,
#   'end': 188129,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00003757255.2',
#   'next_exon_id': 'ENSE00003759270.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000279457.4',
#   'transcript_id': 'ENST00000623083.4',
#   'start': 188266,
#   'end': 188438,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00003759270.1',
#   'next_exon_id': 'ENSE00003755821.2'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000279457.4',
#   'transcript_id': 'ENST00000623083.4',
#   'start': 188584,
#   'end': 188790,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00003755821.2',
#   'next_exon_id': 'ENSE00003755850.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000279457.4',
#   'transcript_id': 'ENST00000623083.4',
#   'start': 188902,
#   'end': 195262,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00003755850.1',
#   'next_exon_id': 'ENSE00003755778.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000228463.10',
#   'transcript_id': 'ENST00000442116.1',
#   'start': 259025,
#   'end': 264603,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00001677641.1',
#   'next_exon_id': 'ENSE00001149252.5'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000228463.10',
#   'transcript_id': 'ENST00000448958.2',
#   'start': 259025,
#   'end': 261549,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00003813893.1',
#   'next_exon_id': 'ENSE00003786235.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000228463.10',
#   'transcript_id': 'ENST00000448958.2',
#   'start': 261634,
#   'end': 267302,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00003786235.1',
#   'next_exon_id': 'ENSE00001769002.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000228463.10',
#   'transcript_id': 'ENST00000448958.2',
#   'start': 268204,
#   'end': 268666,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00001769002.1',
#   'next_exon_id': 'ENSE00001688505.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000228463.10',
#   'transcript_id': 'ENST00000441866.2',
#   'start': 259025,
#   'end': 356684,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00001697698.1',
#   'next_exon_id': 'ENSE00003789911.2'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000228463.10',
#   'transcript_id': 'ENST00000441866.2',
#   'start': 357586,
#   'end': 358048,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00003789911.2',
#   'next_exon_id': 'ENSE00001729229.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000228463.10',
#   'transcript_id': 'ENST00000441866.2',
#   'start': 358183,
#   'end': 359344,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00001729229.1',
#   'next_exon_id': 'ENSE00001670287.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000228463.10',
#   'transcript_id': 'ENST00000634344.2',
#   'start': 259025,
#   'end': 267302,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00003789731.2',
#   'next_exon_id': 'ENSE00001769002.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000228463.10',
#   'transcript_id': 'ENST00000634344.2',
#   'start': 268204,
#   'end': 268666,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00001769002.1',
#   'next_exon_id': 'ENSE00001688505.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000228463.10',
#   'transcript_id': 'ENST00000424587.7',
#   'start': 268204,
#   'end': 268666,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00001785078.3',
#   'next_exon_id': 'ENSE00001688505.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000228463.10',
#   'transcript_id': 'ENST00000424587.7',
#   'start': 268816,
#   'end': 289265,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00001688505.1',
#   'next_exon_id': 'ENSE00001694491.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000228463.10',
#   'transcript_id': 'ENST00000424587.7',
#   'start': 289370,
#   'end': 297344,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00001694491.1',
#   'next_exon_id': 'ENSE00001697423.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000286448.1',
#   'transcript_id': 'ENST00000669836.1',
#   'start': 267056,
#   'end': 268121,
#   'strand': '+',
#   'prev_exon_id': 'ENSE00003865469.1',
#   'next_exon_id': 'ENSE00003852409.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000236601.2',
#   'transcript_id': 'ENST00000450983.1',
#   'start': 358929,
#   'end': 365170,
#   'strand': '+',
#   'prev_exon_id': 'ENSE00001634442.1',
#   'next_exon_id': 'ENSE00001787178.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000236601.2',
#   'transcript_id': 'ENST00000412666.1',
#   'start': 358957,
#   'end': 365170,
#   'strand': '+',
#   'prev_exon_id': 'ENSE00001700697.1',
#   'next_exon_id': 'ENSE00001745103.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000236601.2',
#   'transcript_id': 'ENST00000635159.1',
#   'start': 360168,
#   'end': 365170,
#   'strand': '+',
#   'prev_exon_id': 'ENSE00003784495.1',
#   'next_exon_id': 'ENSE00003791014.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000290385.1',
#   'transcript_id': 'ENST00000431321.2',
#   'start': 365692,
#   'end': 366018,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00001656291.1',
#   'next_exon_id': 'ENSE00001610890.3'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000290385.1',
#   'transcript_id': 'ENST00000453935.1',
#   'start': 365692,
#   'end': 368250,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00001798578.1',
#   'next_exon_id': 'ENSE00001651491.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000290385.1',
#   'transcript_id': 'ENST00000440163.1',
#   'start': 365692,
#   'end': 373143,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00001651822.1',
#   'next_exon_id': 'ENSE00001622961.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000290385.1',
#   'transcript_id': 'ENST00000440163.1',
#   'start': 373323,
#   'end': 379768,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00001622961.1',
#   'next_exon_id': 'ENSE00001687828.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000290385.1',
#   'transcript_id': 'ENST00000455207.5',
#   'start': 373323,
#   'end': 379768,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00001770724.1',
#   'next_exon_id': 'ENSE00001628100.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000290385.1',
#   'transcript_id': 'ENST00000455207.5',
#   'start': 379870,
#   'end': 485039,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00001628100.1',
#   'next_exon_id': 'ENSE00001794483.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000290385.1',
#   'transcript_id': 'ENST00000455464.7',
#   'start': 476945,
#   'end': 485039,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00001707425.2',
#   'next_exon_id': 'ENSE00001794483.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000290385.1',
#   'transcript_id': 'ENST00000455464.7',
#   'start': 485208,
#   'end': 497108,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00001794483.1',
#   'next_exon_id': 'ENSE00003016872.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000290385.1',
#   'transcript_id': 'ENST00000601814.5',
#   'start': 485208,
#   'end': 494991,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00001690296.2',
#   'next_exon_id': 'ENSE00003328882.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000290385.1',
#   'transcript_id': 'ENST00000601814.5',
#   'start': 495049,
#   'end': 495276,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00003328882.1',
#   'next_exon_id': 'ENSE00002997765.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000290385.1',
#   'transcript_id': 'ENST00000431812.1',
#   'start': 485208,
#   'end': 489360,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00001758832.1',
#   'next_exon_id': 'ENSE00001628206.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000290385.1',
#   'transcript_id': 'ENST00000419160.4',
#   'start': 494586,
#   'end': 496263,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00001760607.2',
#   'next_exon_id': 'ENSE00001650218.4'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000290385.1',
#   'transcript_id': 'ENST00000440038.7',
#   'start': 494898,
#   'end': 494991,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00003003869.1',
#   'next_exon_id': 'ENSE00003328882.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000290385.1',
#   'transcript_id': 'ENST00000440038.7',
#   'start': 495049,
#   'end': 497108,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00003328882.1',
#   'next_exon_id': 'ENSE00003075294.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000290385.1',
#   'transcript_id': 'ENST00000440038.7',
#   'start': 497299,
#   'end': 501555,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00003075294.1',
#   'next_exon_id': 'ENSE00003186556.2'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000290385.1',
#   'transcript_id': 'ENST00000440038.7',
#   'start': 501620,
#   'end': 502464,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00003186556.2',
#   'next_exon_id': 'ENSE00003813138.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000290385.1',
#   'transcript_id': 'ENST00000642074.1',
#   'start': 494898,
#   'end': 494991,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00003813292.1',
#   'next_exon_id': 'ENSE00003328882.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000290385.1',
#   'transcript_id': 'ENST00000642074.1',
#   'start': 495049,
#   'end': 495276,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00003328882.1',
#   'next_exon_id': 'ENSE00003812802.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000290385.1',
#   'transcript_id': 'ENST00000423728.6',
#   'start': 494898,
#   'end': 494991,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00003811533.1',
#   'next_exon_id': 'ENSE00003328882.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000290385.1',
#   'transcript_id': 'ENST00000423728.6',
#   'start': 495049,
#   'end': 498683,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00003328882.1',
#   'next_exon_id': 'ENSE00001736043.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000290385.1',
#   'transcript_id': 'ENST00000616311.5',
#   'start': 494898,
#   'end': 494991,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00001798174.2',
#   'next_exon_id': 'ENSE00003328882.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000290385.1',
#   'transcript_id': 'ENST00000616311.5',
#   'start': 495049,
#   'end': 497108,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00003328882.1',
#   'next_exon_id': 'ENSE00003075294.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000290385.1',
#   'transcript_id': 'ENST00000616311.5',
#   'start': 497299,
#   'end': 498398,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00003075294.1',
#   'next_exon_id': 'ENSE00001601447.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000290385.1',
#   'transcript_id': 'ENST00000616311.5',
#   'start': 498456,
#   'end': 498683,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00001601447.1',
#   'next_exon_id': 'ENSE00003724255.2'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000290385.1',
#   'transcript_id': 'ENST00000599771.6',
#   'start': 497299,
#   'end': 498072,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00003062243.1',
#   'next_exon_id': 'ENSE00001760542.2'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000290385.1',
#   'transcript_id': 'ENST00000599771.6',
#   'start': 498305,
#   'end': 498398,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00001760542.2',
#   'next_exon_id': 'ENSE00001601447.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000290385.1',
#   'transcript_id': 'ENST00000641845.1',
#   'start': 497228,
#   'end': 498072,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00003813098.1',
#   'next_exon_id': 'ENSE00001760542.2'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000290385.1',
#   'transcript_id': 'ENST00000641845.1',
#   'start': 498305,
#   'end': 498398,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00001760542.2',
#   'next_exon_id': 'ENSE00001601447.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000290385.1',
#   'transcript_id': 'ENST00000641845.1',
#   'start': 498456,
#   'end': 501555,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00001601447.1',
#   'next_exon_id': 'ENSE00003186556.2'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000290385.1',
#   'transcript_id': 'ENST00000641845.1',
#   'start': 501620,
#   'end': 502186,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00003186556.2',
#   'next_exon_id': 'ENSE00003812333.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000290385.1',
#   'transcript_id': 'ENST00000641845.1',
#   'start': 502243,
#   'end': 502464,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00003812333.1',
#   'next_exon_id': 'ENSE00003813663.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000290385.1',
#   'transcript_id': 'ENST00000641916.1',
#   'start': 497299,
#   'end': 498398,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00003812605.1',
#   'next_exon_id': 'ENSE00001601447.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000290385.1',
#   'transcript_id': 'ENST00000641916.1',
#   'start': 498456,
#   'end': 501555,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00001601447.1',
#   'next_exon_id': 'ENSE00003186556.2'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000290385.1',
#   'transcript_id': 'ENST00000641916.1',
#   'start': 501620,
#   'end': 502464,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00003186556.2',
#   'next_exon_id': 'ENSE00003811762.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000290385.1',
#   'transcript_id': 'ENST00000601486.5',
#   'start': 497299,
#   'end': 498046,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00003045569.1',
#   'next_exon_id': 'ENSE00003063936.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000290385.1',
#   'transcript_id': 'ENST00000601486.5',
#   'start': 498305,
#   'end': 498398,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00003063936.1',
#   'next_exon_id': 'ENSE00001601447.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000290385.1',
#   'transcript_id': 'ENST00000601486.5',
#   'start': 498456,
#   'end': 498683,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00001601447.1',
#   'next_exon_id': 'ENSE00003097839.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000290385.1',
#   'transcript_id': 'ENST00000641579.1',
#   'start': 497299,
#   'end': 498072,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00003772014.2',
#   'next_exon_id': 'ENSE00001760542.2'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000290385.1',
#   'transcript_id': 'ENST00000641579.1',
#   'start': 498305,
#   'end': 498398,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00001760542.2',
#   'next_exon_id': 'ENSE00001601447.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000290385.1',
#   'transcript_id': 'ENST00000641579.1',
#   'start': 498456,
#   'end': 501555,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00001601447.1',
#   'next_exon_id': 'ENSE00003186556.2'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000290385.1',
#   'transcript_id': 'ENST00000641579.1',
#   'start': 501620,
#   'end': 502464,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00003186556.2',
#   'next_exon_id': 'ENSE00003813663.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000290385.1',
#   'transcript_id': 'ENST00000616947.2',
#   'start': 497299,
#   'end': 498398,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00003771994.1',
#   'next_exon_id': 'ENSE00003748817.2'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000290385.1',
#   'transcript_id': 'ENST00000432964.1',
#   'start': 498305,
#   'end': 498398,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00001803078.1',
#   'next_exon_id': 'ENSE00001601447.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000290385.1',
#   'transcript_id': 'ENST00000432964.1',
#   'start': 498456,
#   'end': 498683,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00001601447.1',
#   'next_exon_id': 'ENSE00001736043.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000290385.1',
#   'transcript_id': 'ENST00000608420.1',
#   'start': 499369,
#   'end': 501555,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00003708499.1',
#   'next_exon_id': 'ENSE00003709813.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000290385.1',
#   'transcript_id': 'ENST00000641303.1',
#   'start': 501620,
#   'end': 502861,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00003812612.1',
#   'next_exon_id': 'ENSE00003813384.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000290385.1',
#   'transcript_id': 'ENST00000641303.1',
#   'start': 502955,
#   'end': 504979,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00003813384.1',
#   'next_exon_id': 'ENSE00003812904.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000290385.1',
#   'transcript_id': 'ENST00000641303.1',
#   'start': 505103,
#   'end': 514358,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00003812904.1',
#   'next_exon_id': 'ENSE00003812097.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000290385.1',
#   'transcript_id': 'ENST00000641303.1',
#   'start': 514423,
#   'end': 517184,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00003812097.1',
#   'next_exon_id': 'ENSE00003813716.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000290385.1',
#   'transcript_id': 'ENST00000641063.1',
#   'start': 501620,
#   'end': 502464,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00003814035.1',
#   'next_exon_id': 'ENSE00003814243.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000290385.1',
#   'transcript_id': 'ENST00000641063.1',
#   'start': 502661,
#   'end': 504979,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00003814243.1',
#   'next_exon_id': 'ENSE00003812904.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000290385.1',
#   'transcript_id': 'ENST00000641063.1',
#   'start': 505103,
#   'end': 514358,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00003812904.1',
#   'next_exon_id': 'ENSE00003812097.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000290385.1',
#   'transcript_id': 'ENST00000641063.1',
#   'start': 514423,
#   'end': 517155,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00003812097.1',
#   'next_exon_id': 'ENSE00003812919.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000290385.1',
#   'transcript_id': 'ENST00000641049.1',
#   'start': 504933,
#   'end': 514358,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00003812143.1',
#   'next_exon_id': 'ENSE00003812504.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000290385.1',
#   'transcript_id': 'ENST00000642124.1',
#   'start': 505103,
#   'end': 514358,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00003813395.1',
#   'next_exon_id': 'ENSE00003812097.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000290385.1',
#   'transcript_id': 'ENST00000642124.1',
#   'start': 514423,
#   'end': 517184,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00003812097.1',
#   'next_exon_id': 'ENSE00003813543.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000290385.1',
#   'transcript_id': 'ENST00000642124.1',
#   'start': 517266,
#   'end': 522858,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00003813543.1',
#   'next_exon_id': 'ENSE00003814041.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000233653.3',
#   'transcript_id': 'ENST00000432723.3',
#   'start': 489387,
#   'end': 489716,
#   'strand': '+',
#   'prev_exon_id': 'ENSE00001705369.3',
#   'next_exon_id': 'ENSE00003569252.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000250575.1',
#   'transcript_id': 'ENST00000514436.1',
#   'start': 491989,
#   'end': 492767,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00002064640.1',
#   'next_exon_id': 'ENSE00002058739.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000230021.10',
#   'transcript_id': 'ENST00000634833.2',
#   'start': 586358,
#   'end': 586820,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00003785196.2',
#   'next_exon_id': 'ENSE00001647781.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000230021.10',
#   'transcript_id': 'ENST00000634833.2',
#   'start': 586955,
#   'end': 594628,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00001647781.1',
#   'next_exon_id': 'ENSE00003785550.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000230021.10',
#   'transcript_id': 'ENST00000634833.2',
#   'start': 594756,
#   'end': 601397,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00003785550.1',
#   'next_exon_id': 'ENSE00003791521.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000230021.10',
#   'transcript_id': 'ENST00000634833.2',
#   'start': 601577,
#   'end': 607954,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00003791521.1',
#   'next_exon_id': 'ENSE00001718533.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000230021.10',
#   'transcript_id': 'ENST00000634833.2',
#   'start': 608056,
#   'end': 612740,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00001718533.1',
#   'next_exon_id': 'ENSE00003812707.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000230021.10',
#   'transcript_id': 'ENST00000417636.2',
#   'start': 586358,
#   'end': 586820,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00001680902.2',
#   'next_exon_id': 'ENSE00001647781.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000230021.10',
#   'transcript_id': 'ENST00000417636.2',
#   'start': 586955,
#   'end': 588116,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00001647781.1',
#   'next_exon_id': 'ENSE00001738702.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000230021.10',
#   'transcript_id': 'ENST00000419394.2',
#   'start': 586955,
#   'end': 703684,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00003813077.1',
#   'next_exon_id': 'ENSE00001671684.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000230021.10',
#   'transcript_id': 'ENST00000419394.2',
#   'start': 703789,
#   'end': 711710,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00001671684.1',
#   'next_exon_id': 'ENSE00001696741.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000230021.10',
#   'transcript_id': 'ENST00000419394.2',
#   'start': 711922,
#   'end': 720031,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00001696741.1',
#   'next_exon_id': 'ENSE00001595248.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000230021.10',
#   'transcript_id': 'ENST00000440196.3',
#   'start': 594756,
#   'end': 601397,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00001752275.3',
#   'next_exon_id': 'ENSE00003791521.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000230021.10',
#   'transcript_id': 'ENST00000440196.3',
#   'start': 601577,
#   'end': 607954,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00003791521.1',
#   'next_exon_id': 'ENSE00001718533.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000230021.10',
#   'transcript_id': 'ENST00000440196.3',
#   'start': 608056,
#   'end': 628918,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00001718533.1',
#   'next_exon_id': 'ENSE00003785487.2'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000230021.10',
#   'transcript_id': 'ENST00000440196.3',
#   'start': 629006,
#   'end': 633043,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00003785487.2',
#   'next_exon_id': 'ENSE00003813529.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000230021.10',
#   'transcript_id': 'ENST00000641296.1',
#   'start': 594756,
#   'end': 601397,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00001652759.3',
#   'next_exon_id': 'ENSE00003791521.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000230021.10',
#   'transcript_id': 'ENST00000641296.1',
#   'start': 601577,
#   'end': 607954,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00003791521.1',
#   'next_exon_id': 'ENSE00001718533.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000230021.10',
#   'transcript_id': 'ENST00000641296.1',
#   'start': 608056,
#   'end': 612740,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00001718533.1',
#   'next_exon_id': 'ENSE00003811489.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000230021.10',
#   'transcript_id': 'ENST00000641296.1',
#   'start': 612864,
#   'end': 628918,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00003811489.1',
#   'next_exon_id': 'ENSE00003785487.2'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000230021.10',
#   'transcript_id': 'ENST00000641296.1',
#   'start': 629006,
#   'end': 631130,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00003785487.2',
#   'next_exon_id': 'ENSE00003812400.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000230021.10',
#   'transcript_id': 'ENST00000357876.6',
#   'start': 594756,
#   'end': 597298,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00003788434.1',
#   'next_exon_id': 'ENSE00001651821.3'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000230021.10',
#   'transcript_id': 'ENST00000635509.2',
#   'start': 594756,
#   'end': 601397,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00003788434.1',
#   'next_exon_id': 'ENSE00003791521.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000230021.10',
#   'transcript_id': 'ENST00000635509.2',
#   'start': 601577,
#   'end': 711710,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00003791521.1',
#   'next_exon_id': 'ENSE00001696741.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000230021.10',
#   'transcript_id': 'ENST00000635509.2',
#   'start': 711922,
#   'end': 827669,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00001696741.1',
#   'next_exon_id': 'ENSE00003786980.2'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000230021.10',
#   'transcript_id': 'ENST00000634337.2',
#   'start': 594756,
#   'end': 601397,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00003788434.1',
#   'next_exon_id': 'ENSE00003791521.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000230021.10',
#   'transcript_id': 'ENST00000634337.2',
#   'start': 601577,
#   'end': 607954,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00003791521.1',
#   'next_exon_id': 'ENSE00001718533.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000230021.10',
#   'transcript_id': 'ENST00000634337.2',
#   'start': 608056,
#   'end': 698926,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00001718533.1',
#   'next_exon_id': 'ENSE00003786098.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000230021.10',
#   'transcript_id': 'ENST00000634337.2',
#   'start': 698959,
#   'end': 827669,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00003786098.1',
#   'next_exon_id': 'ENSE00003786823.2'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000230021.10',
#   'transcript_id': 'ENST00000648019.1',
#   'start': 594756,
#   'end': 601397,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00003837575.1',
#   'next_exon_id': 'ENSE00003791521.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000230021.10',
#   'transcript_id': 'ENST00000648019.1',
#   'start': 601577,
#   'end': 607954,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00003791521.1',
#   'next_exon_id': 'ENSE00001718533.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000230021.10',
#   'transcript_id': 'ENST00000648019.1',
#   'start': 608056,
#   'end': 698926,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00001718533.1',
#   'next_exon_id': 'ENSE00003786098.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000230021.10',
#   'transcript_id': 'ENST00000648019.1',
#   'start': 698959,
#   'end': 711764,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00003786098.1',
#   'next_exon_id': 'ENSE00003831422.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000230021.10',
#   'transcript_id': 'ENST00000648019.1',
#   'start': 711922,
#   'end': 720031,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00003831422.1',
#   'next_exon_id': 'ENSE00001745637.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000230021.10',
#   'transcript_id': 'ENST00000648019.1',
#   'start': 720200,
#   'end': 732016,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00001745637.1',
#   'next_exon_id': 'ENSE00003837629.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000230021.10',
#   'transcript_id': 'ENST00000648019.1',
#   'start': 732207,
#   'end': 732980,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00003837629.1',
#   'next_exon_id': 'ENSE00003832413.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000230021.10',
#   'transcript_id': 'ENST00000440200.5',
#   'start': 601577,
#   'end': 607954,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00001773655.1',
#   'next_exon_id': 'ENSE00001718533.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000230021.10',
#   'transcript_id': 'ENST00000440200.5',
#   'start': 608056,
#   'end': 720031,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00001718533.1',
#   'next_exon_id': 'ENSE00001745637.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000230021.10',
#   'transcript_id': 'ENST00000452176.2',
#   'start': 627823,
#   'end': 627960,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00001675353.1',
#   'next_exon_id': 'ENSE00001760488.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000230021.10',
#   'transcript_id': 'ENST00000452176.2',
#   'start': 628223,
#   'end': 628918,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00001760488.1',
#   'next_exon_id': 'ENSE00003785487.2'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000230021.10',
#   'transcript_id': 'ENST00000452176.2',
#   'start': 629006,
#   'end': 631130,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00003785487.2',
#   'next_exon_id': 'ENSE00003811836.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000230021.10',
#   'transcript_id': 'ENST00000441245.5',
#   'start': 702340,
#   'end': 703684,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00001753339.1',
#   'next_exon_id': 'ENSE00001671684.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000230021.10',
#   'transcript_id': 'ENST00000441245.5',
#   'start': 703789,
#   'end': 720031,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00001671684.1',
#   'next_exon_id': 'ENSE00001663889.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000230021.10',
#   'transcript_id': 'ENST00000414688.6',
#   'start': 711922,
#   'end': 720031,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00003814134.1',
#   'next_exon_id': 'ENSE00001745637.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000230021.10',
#   'transcript_id': 'ENST00000414688.6',
#   'start': 720200,
#   'end': 732016,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00001745637.1',
#   'next_exon_id': 'ENSE00003812502.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000230021.10',
#   'transcript_id': 'ENST00000447954.2',
#   'start': 720200,
#   'end': 724357,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00001675630.2',
#   'next_exon_id': 'ENSE00001688006.2'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000235146.2',
#   'transcript_id': 'ENST00000423796.1',
#   'start': 587701,
#   'end': 594234,
#   'strand': '+',
#   'prev_exon_id': 'ENSE00001621971.1',
#   'next_exon_id': 'ENSE00001665260.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000235146.2',
#   'transcript_id': 'ENST00000450696.1',
#   'start': 587729,
#   'end': 594234,
#   'strand': '+',
#   'prev_exon_id': 'ENSE00001734474.1',
#   'next_exon_id': 'ENSE00001607178.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000229376.3',
#   'transcript_id': 'ENST00000440782.3',
#   'start': 724360,
#   'end': 724717,
#   'strand': '+',
#   'prev_exon_id': 'ENSE00001731162.3',
#   'next_exon_id': 'ENSE00003593944.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000291215.1',
#   'transcript_id': 'ENST00000506640.3',
#   'start': 729804,
#   'end': 733306,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00002076418.2',
#   'next_exon_id': 'ENSE00003790078.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000291215.1',
#   'transcript_id': 'ENST00000506640.3',
#   'start': 733364,
#   'end': 735422,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00003790078.1',
#   'next_exon_id': 'ENSE00003787323.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000291215.1',
#   'transcript_id': 'ENST00000506640.3',
#   'start': 735613,
#   'end': 743179,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00003787323.1',
#   'next_exon_id': 'ENSE00001650007.2'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000291215.1',
#   'transcript_id': 'ENST00000506640.3',
#   'start': 743350,
#   'end': 744194,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00001650007.2',
#   'next_exon_id': 'ENSE00003786064.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000291215.1',
#   'transcript_id': 'ENST00000506640.3',
#   'start': 744391,
#   'end': 744727,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00003786064.1',
#   'next_exon_id': 'ENSE00003790979.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000291215.1',
#   'transcript_id': 'ENST00000506640.3',
#   'start': 744825,
#   'end': 746694,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00003790979.1',
#   'next_exon_id': 'ENSE00001605176.2'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000291215.1',
#   'transcript_id': 'ENST00000506640.3',
#   'start': 746818,
#   'end': 756076,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00001605176.2',
#   'next_exon_id': 'ENSE00003788233.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000291215.1',
#   'transcript_id': 'ENST00000506640.3',
#   'start': 756141,
#   'end': 758966,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00003788233.1',
#   'next_exon_id': 'ENSE00001609623.2'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000291215.1',
#   'transcript_id': 'ENST00000506640.3',
#   'start': 759123,
#   'end': 764722,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00001609623.2',
#   'next_exon_id': 'ENSE00001723311.2'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000291215.1',
#   'transcript_id': 'ENST00000506640.3',
#   'start': 765247,
#   'end': 766328,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00001723311.2',
#   'next_exon_id': 'ENSE00004015645.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000291215.1',
#   'transcript_id': 'ENST00000506640.3',
#   'start': 766387,
#   'end': 768547,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00004015645.1',
#   'next_exon_id': 'ENSE00004018242.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000291215.1',
#   'transcript_id': 'ENST00000506640.3',
#   'start': 768613,
#   'end': 769496,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00004018242.1',
#   'next_exon_id': 'ENSE00001703665.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000291215.1',
#   'transcript_id': 'ENST00000506640.3',
#   'start': 769712,
#   'end': 772975,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00001703665.1',
#   'next_exon_id': 'ENSE00001740558.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000291215.1',
#   'transcript_id': 'ENST00000506640.3',
#   'start': 773107,
#   'end': 774170,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00001740558.1',
#   'next_exon_id': 'ENSE00004015666.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000291215.1',
#   'transcript_id': 'ENST00000506640.3',
#   'start': 774280,
#   'end': 778283,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00004015666.1',
#   'next_exon_id': 'ENSE00003987060.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000229905.1',
#   'transcript_id': 'ENST00000422528.1',
#   'start': 761154,
#   'end': 761777,
#   'strand': '+',
#   'prev_exon_id': 'ENSE00001695448.1',
#   'next_exon_id': 'ENSE00001761034.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000228327.6',
#   'transcript_id': 'ENST00000428504.2',
#   'start': 764800,
#   'end': 765143,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00001674071.2',
#   'next_exon_id': 'ENSE00003791464.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000228327.6',
#   'transcript_id': 'ENST00000428504.2',
#   'start': 765247,
#   'end': 766328,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00003791464.1',
#   'next_exon_id': 'ENSE00001616222.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000228327.6',
#   'transcript_id': 'ENST00000428504.2',
#   'start': 766387,
#   'end': 768547,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00001616222.1',
#   'next_exon_id': 'ENSE00003987061.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000228327.6',
#   'transcript_id': 'ENST00000428504.2',
#   'start': 768613,
#   'end': 774170,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00003987061.1',
#   'next_exon_id': 'ENSE00001630466.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000237491.10',
#   'transcript_id': 'ENST00000655765.1',
#   'start': 779092,
#   'end': 803918,
#   'strand': '+',
#   'prev_exon_id': 'ENSE00003853005.1',
#   'next_exon_id': 'ENSE00001706796.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000237491.10',
#   'transcript_id': 'ENST00000655765.1',
#   'start': 804222,
#   'end': 804775,
#   'strand': '+',
#   'prev_exon_id': 'ENSE00001706796.1',
#   'next_exon_id': 'ENSE00001776151.2'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000237491.10',
#   'transcript_id': 'ENST00000412115.2',
#   'start': 779092,
#   'end': 803950,
#   'strand': '+',
#   'prev_exon_id': 'ENSE00003853005.1',
#   'next_exon_id': 'ENSE00002781548.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000237491.10',
# ...
#   'transcript_id': 'ENST00000427998.6',
#   'start': 1063201,
#   'end': 1065829,
#   'strand': '+',
#   'prev_exon_id': 'ENSE00004015638.1',
#   'next_exon_id': 'ENSE00001719282.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000291156.1',
#   'transcript_id': 'ENST00000685011.1',
#   'start': 1060393,
#   'end': 1065829,
#   'strand': '+',
#   'prev_exon_id': 'ENSE00003927986.1',
#   'next_exon_id': 'ENSE00003938139.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000291156.1',
#   'transcript_id': 'ENST00000692266.1',
#   'start': 1059846,
#   'end': 1060279,
#   'strand': '+',
#   'prev_exon_id': 'ENSE00001669701.1',
#   'next_exon_id': 'ENSE00001702890.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000291156.1',
#   'transcript_id': 'ENST00000692266.1',
#   'start': 1060393,
#   'end': 1065829,
#   'strand': '+',
#   'prev_exon_id': 'ENSE00001702890.1',
#   'next_exon_id': 'ENSE00003936451.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000291156.1',
#   'transcript_id': 'ENST00000433695.1',
#   'start': 1064589,
#   'end': 1065829,
#   'strand': '+',
#   'prev_exon_id': 'ENSE00001730292.1',
#   'next_exon_id': 'ENSE00001514952.2'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000291156.1',
#   'transcript_id': 'ENST00000451054.1',
#   'start': 1064589,
#   'end': 1065948,
#   'strand': '+',
#   'prev_exon_id': 'ENSE00001668262.1',
#   'next_exon_id': 'ENSE00001623309.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000273443.1',
#   'transcript_id': 'ENST00000442292.2',
#   'start': 1062808,
#   'end': 1063060,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00001660524.2',
#   'next_exon_id': 'ENSE00001670841.2'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000217801.13',
#   'transcript_id': 'ENST00000412397.2',
#   'start': 1063201,
#   'end': 1063479,
#   'strand': '+',
#   'prev_exon_id': 'ENSE00001613074.1',
#   'next_exon_id': 'ENSE00001758525.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000217801.13',
#   'transcript_id': 'ENST00000412397.2',
#   'start': 1063566,
#   'end': 1064209,
#   'strand': '+',
#   'prev_exon_id': 'ENSE00001758525.1',
#   'next_exon_id': 'ENSE00001671307.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000217801.13',
#   'transcript_id': 'ENST00000412397.2',
#   'start': 1064401,
#   'end': 1064489,
#   'strand': '+',
#   'prev_exon_id': 'ENSE00001671307.1',
#   'next_exon_id': 'ENSE00001775266.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000217801.13',
#   'transcript_id': 'ENST00000412397.2',
#   'start': 1064589,
#   'end': 1065351,
#   'strand': '+',
#   'prev_exon_id': 'ENSE00001775266.1',
#   'next_exon_id': 'ENSE00001731427.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000217801.13',
#   'transcript_id': 'ENST00000412397.2',
#   'start': 1065475,
#   'end': 1066586,
#   'strand': '+',
#   'prev_exon_id': 'ENSE00001731427.1',
#   'next_exon_id': 'ENSE00001666739.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000217801.13',
#   'transcript_id': 'ENST00000412397.2',
#   'start': 1066667,
#   'end': 1067565,
#   'strand': '+',
#   'prev_exon_id': 'ENSE00001666739.1',
#   'next_exon_id': 'ENSE00001654594.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000217801.13',
#   'transcript_id': 'ENST00000412397.2',
#   'start': 1067646,
#   'end': 1067868,
#   'strand': '+',
#   'prev_exon_id': 'ENSE00001654594.1',
#   'next_exon_id': 'ENSE00001680786.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000217801.13',
#   'transcript_id': 'ENST00000412397.2',
#   'start': 1068003,
#   'end': 1068576,
#   'strand': '+',
#   'prev_exon_id': 'ENSE00001680786.1',
#   'next_exon_id': 'ENSE00001609518.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000217801.13',
#   'transcript_id': 'ENST00000412397.2',
#   'start': 1068724,
#   'end': 1069207,
#   'strand': '+',
#   'prev_exon_id': 'ENSE00001609518.1',
#   'next_exon_id': 'ENSE00001797746.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000237330.3',
#   'transcript_id': 'ENST00000453464.3',
#   'start': 1072575,
#   'end': 1074015,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00001666214.3',
#   'next_exon_id': 'ENSE00001707588.2'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000131591.18',
#   'transcript_id': 'ENST00000379339.5',
#   'start': 1082987,
#   'end': 1083914,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00001662925.1',
#   'next_exon_id': 'ENSE00003664630.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000131591.18',
#   'transcript_id': 'ENST00000379339.5',
#   'start': 1084383,
#   'end': 1084480,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00003664630.1',
#   'next_exon_id': 'ENSE00003614342.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000131591.18',
#   'transcript_id': 'ENST00000379339.5',
#   'start': 1084506,
#   'end': 1085877,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00003614342.1',
#   'next_exon_id': 'ENSE00003678908.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000131591.18',
#   'transcript_id': 'ENST00000379339.5',
#   'start': 1086012,
#   'end': 1087138,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00003678908.1',
#   'next_exon_id': 'ENSE00003789790.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000131591.18',
#   'transcript_id': 'ENST00000379339.5',
#   'start': 1087204,
#   'end': 1087501,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00003789790.1',
#   'next_exon_id': 'ENSE00003463192.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000131591.18',
#   'transcript_id': 'ENST00000379339.5',
#   'start': 1087597,
#   'end': 1090352,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00003463192.1',
#   'next_exon_id': 'ENSE00003592709.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000131591.18',
#   'transcript_id': 'ENST00000379339.5',
#   'start': 1090428,
#   'end': 1090875,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00003592709.1',
#   'next_exon_id': 'ENSE00001480589.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000131591.18',
#   'transcript_id': 'ENST00000379339.5',
#   'start': 1090983,
#   'end': 1091471,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00001480589.1',
#   'next_exon_id': 'ENSE00003652001.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000131591.18',
#   'transcript_id': 'ENST00000379339.5',
#   'start': 1091565,
#   'end': 1091990,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00003652001.1',
#   'next_exon_id': 'ENSE00002711450.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000131591.18',
#   'transcript_id': 'ENST00000379339.5',
#   'start': 1092103,
#   'end': 1115021,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00002711450.1',
#   'next_exon_id': 'ENSE00001480604.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000131591.18',
#   'transcript_id': 'ENST00000379339.5',
#   'start': 1115075,
#   'end': 1116059,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00001480604.1',
#   'next_exon_id': 'ENSE00001480605.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000131591.18',
#   'transcript_id': 'ENST00000465822.5',
#   'start': 1082987,
#   'end': 1084352,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00003497458.1',
#   'next_exon_id': 'ENSE00001823263.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000131591.18',
#   'transcript_id': 'ENST00000465822.5',
#   'start': 1084506,
#   'end': 1085250,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00001823263.1',
#   'next_exon_id': 'ENSE00003466083.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000131591.18',
#   'transcript_id': 'ENST00000465822.5',
#   'start': 1085310,
#   'end': 1085877,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00003466083.1',
#   'next_exon_id': 'ENSE00003525085.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000131591.18',
#   'transcript_id': 'ENST00000465822.5',
#   'start': 1086012,
#   'end': 1087138,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00003525085.1',
#   'next_exon_id': 'ENSE00003680286.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000131591.18',
#   'transcript_id': 'ENST00000465822.5',
#   'start': 1087204,
#   'end': 1087501,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00003680286.1',
#   'next_exon_id': 'ENSE00003497379.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000131591.18',
#   'transcript_id': 'ENST00000465822.5',
#   'start': 1087597,
#   'end': 1090352,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00003497379.1',
#   'next_exon_id': 'ENSE00003541089.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000131591.18',
#   'transcript_id': 'ENST00000465822.5',
#   'start': 1090428,
#   'end': 1091471,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00003541089.1',
#   'next_exon_id': 'ENSE00003646498.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000131591.18',
#   'transcript_id': 'ENST00000465822.5',
#   'start': 1091565,
#   'end': 1091990,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00003646498.1',
#   'next_exon_id': 'ENSE00001882987.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000131591.18',
#   'transcript_id': 'ENST00000421241.7',
#   'start': 1082987,
#   'end': 1084352,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00003615395.1',
#   'next_exon_id': 'ENSE00003506442.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000131591.18',
#   'transcript_id': 'ENST00000421241.7',
#   'start': 1084383,
#   'end': 1084480,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00003506442.1',
#   'next_exon_id': 'ENSE00003614342.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000131591.18',
#   'transcript_id': 'ENST00000421241.7',
#   'start': 1084506,
#   'end': 1085877,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00003614342.1',
#   'next_exon_id': 'ENSE00003678908.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000131591.18',
#   'transcript_id': 'ENST00000421241.7',
#   'start': 1086012,
#   'end': 1087138,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00003678908.1',
#   'next_exon_id': 'ENSE00003789790.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000131591.18',
#   'transcript_id': 'ENST00000421241.7',
#   'start': 1087204,
#   'end': 1087501,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00003789790.1',
#   'next_exon_id': 'ENSE00003463192.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000131591.18',
#   'transcript_id': 'ENST00000421241.7',
#   'start': 1087597,
#   'end': 1090352,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00003463192.1',
#   'next_exon_id': 'ENSE00003592709.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000131591.18',
#   'transcript_id': 'ENST00000421241.7',
#   'start': 1090428,
#   'end': 1091471,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00003592709.1',
#   'next_exon_id': 'ENSE00003652001.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000131591.18',
#   'transcript_id': 'ENST00000421241.7',
#   'start': 1091565,
#   'end': 1091990,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00003652001.1',
#   'next_exon_id': 'ENSE00002711450.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000131591.18',
#   'transcript_id': 'ENST00000421241.7',
#   'start': 1092103,
#   'end': 1116059,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00002711450.1',
#   'next_exon_id': 'ENSE00001902417.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000131591.18',
#   'transcript_id': 'ENST00000379325.7',
#   'start': 1082987,
#   'end': 1083914,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00003497458.1',
#   'next_exon_id': 'ENSE00003657760.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000131591.18',
#   'transcript_id': 'ENST00000379325.7',
#   'start': 1084086,
#   'end': 1084352,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00003657760.1',
#   'next_exon_id': 'ENSE00003506442.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000131591.18',
#   'transcript_id': 'ENST00000379325.7',
#   'start': 1084383,
#   'end': 1084480,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00003506442.1',
#   'next_exon_id': 'ENSE00003614342.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000131591.18',
#   'transcript_id': 'ENST00000379325.7',
#   'start': 1084506,
#   'end': 1085877,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00003614342.1',
#   'next_exon_id': 'ENSE00003678908.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000131591.18',
#   'transcript_id': 'ENST00000379325.7',
#   'start': 1086012,
#   'end': 1087138,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00003678908.1',
#   'next_exon_id': 'ENSE00003789790.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000131591.18',
#   'transcript_id': 'ENST00000379325.7',
#   'start': 1087204,
#   'end': 1087501,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00003789790.1',
#   'next_exon_id': 'ENSE00003463192.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000131591.18',
#   'transcript_id': 'ENST00000379325.7',
#   'start': 1087597,
#   'end': 1090352,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00003463192.1',
#   'next_exon_id': 'ENSE00003592709.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000131591.18',
#   'transcript_id': 'ENST00000379325.7',
#   'start': 1090428,
#   'end': 1091471,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00003592709.1',
#   'next_exon_id': 'ENSE00003652001.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000131591.18',
#   'transcript_id': 'ENST00000379325.7',
#   'start': 1091565,
#   'end': 1091990,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00003652001.1',
#   'next_exon_id': 'ENSE00002711450.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000131591.18',
#   'transcript_id': 'ENST00000379325.7',
#   'start': 1092103,
#   'end': 1116059,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00002711450.1',
#   'next_exon_id': 'ENSE00001742039.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000131591.18',
#   'transcript_id': 'ENST00000487177.5',
#   'start': 1084506,
#   'end': 1085877,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00001859925.1',
#   'next_exon_id': 'ENSE00003525085.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000131591.18',
#   'transcript_id': 'ENST00000487177.5',
#   'start': 1086012,
#   'end': 1087138,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00003525085.1',
#   'next_exon_id': 'ENSE00001913500.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000131591.18',
#   'transcript_id': 'ENST00000467751.5',
#   'start': 1082987,
#   'end': 1083914,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00001775910.1',
#   'next_exon_id': 'ENSE00003620358.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000131591.18',
#   'transcript_id': 'ENST00000467751.5',
#   'start': 1084086,
#   'end': 1084352,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00003620358.1',
#   'next_exon_id': 'ENSE00003467290.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000131591.18',
#   'transcript_id': 'ENST00000467751.5',
#   'start': 1084383,
#   'end': 1084480,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00003467290.1',
#   'next_exon_id': 'ENSE00003506487.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000131591.18',
#   'transcript_id': 'ENST00000467751.5',
#   'start': 1084506,
#   'end': 1085877,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00003506487.1',
#   'next_exon_id': 'ENSE00003525085.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000131591.18',
#   'transcript_id': 'ENST00000467751.5',
#   'start': 1086012,
#   'end': 1087138,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00003525085.1',
#   'next_exon_id': 'ENSE00003680286.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000131591.18',
#   'transcript_id': 'ENST00000467751.5',
#   'start': 1087204,
#   'end': 1087501,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00003680286.1',
#   'next_exon_id': 'ENSE00003668521.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000131591.18',
#   'transcript_id': 'ENST00000467751.5',
#   'start': 1087597,
#   'end': 1090352,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00003668521.1',
#   'next_exon_id': 'ENSE00003589894.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000131591.18',
#   'transcript_id': 'ENST00000467751.5',
#   'start': 1090428,
#   'end': 1091277,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00003589894.1',
#   'next_exon_id': 'ENSE00001793213.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000131591.18',
#   'transcript_id': 'ENST00000467751.5',
#   'start': 1091374,
#   'end': 1091471,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00001793213.1',
#   'next_exon_id': 'ENSE00003652001.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000131591.18',
#   'transcript_id': 'ENST00000467751.5',
#   'start': 1091565,
#   'end': 1091990,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00003652001.1',
#   'next_exon_id': 'ENSE00002711450.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000131591.18',
#   'transcript_id': 'ENST00000467751.5',
#   'start': 1092103,
#   'end': 1116059,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00002711450.1',
#   'next_exon_id': 'ENSE00001902417.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000131591.18',
#   'transcript_id': 'ENST00000477196.5',
#   'start': 1082987,
#   'end': 1083914,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00001775910.1',
#   'next_exon_id': 'ENSE00003487799.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000131591.18',
#   'transcript_id': 'ENST00000477196.5',
#   'start': 1084383,
#   'end': 1084480,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00003487799.1',
#   'next_exon_id': 'ENSE00003506487.1'},
#  {'chr': 'chr1',
#   'gene_id': 'ENSG00000131591.18',
#   'transcript_id': 'ENST00000477196.5',
#   'start': 1084506,
#   'end': 1085877,
#   'strand': '-',
#   'prev_exon_id': 'ENSE00003506487.1',
#   'next_exon_id': 'ENSE00003525085.1'},
#  ...]

# %%
df_introns = pd.DataFrame(introns_lst.copy())
df_introns
# Out:
#           chr            gene_id      transcript_id     start       end  \
# 0        chr1  ENSG00000290825.1  ENST00000456328.2     12227     12612
# 1        chr1  ENSG00000290825.1  ENST00000456328.2     12721     13220
# 2        chr1  ENSG00000223972.6  ENST00000450305.2     12057     12178
# 3        chr1  ENSG00000223972.6  ENST00000450305.2     12227     12612
# 4        chr1  ENSG00000223972.6  ENST00000450305.2     12697     12974
# ...       ...                ...                ...       ...       ...
# 1396636  chrY  ENSG00000292372.1  ENST00000711285.1  57211569  57211760
# 1396637  chrY  ENSG00000292371.1  ENST00000711270.1  57213125  57213203
# 1396638  chrY  ENSG00000292371.1  ENST00000711270.1  57213357  57213525
# 1396639  chrY  ENSG00000292371.1  ENST00000711270.1  57213602  57213879
# 1396640  chrY  ENSG00000292371.1  ENST00000711270.1  57213964  57214349
#
#         strand       prev_exon_id       next_exon_id
# 0            +  ENSE00002234944.1  ENSE00003582793.1
# 1            +  ENSE00003582793.1  ENSE00002312635.1
# 2            +  ENSE00001948541.1  ENSE00001671638.2
# 3            +  ENSE00001671638.2  ENSE00001758273.2
# 4            +  ENSE00001758273.2  ENSE00001799933.2
# ...        ...                ...                ...
# 1396636      +  ENSE00004015174.1  ENSE00004015172.1
# 1396637      -  ENSE00004015127.1  ENSE00004015126.1
# 1396638      -  ENSE00004015126.1  ENSE00004015125.1
# 1396639      -  ENSE00004015125.1  ENSE00004015124.1
# 1396640      -  ENSE00004015124.1  ENSE00004015123.1
#
# [1396641 rows x 8 columns]

# %%
# Export it to tsv for next steps
df_introns.to_csv("data/All_introns_list.tsv", index=False, sep="\t")

# %%
# df_introns['Duplicate_Count'] = df_introns.groupby(["chr", "start", "end", "strand"]).transform('size')
df_introns.drop_duplicates(subset=["chr", "start", "end", "strand"], inplace=True)
df_introns
# Out:
#           chr            gene_id      transcript_id     start       end  \
# 0        chr1  ENSG00000290825.1  ENST00000456328.2     12227     12612
# 1        chr1  ENSG00000290825.1  ENST00000456328.2     12721     13220
# 2        chr1  ENSG00000223972.6  ENST00000450305.2     12057     12178
# 4        chr1  ENSG00000223972.6  ENST00000450305.2     12697     12974
# 5        chr1  ENSG00000223972.6  ENST00000450305.2     13052     13220
# ...       ...                ...                ...       ...       ...
# 1396636  chrY  ENSG00000292372.1  ENST00000711285.1  57211569  57211760
# 1396637  chrY  ENSG00000292371.1  ENST00000711270.1  57213125  57213203
# 1396638  chrY  ENSG00000292371.1  ENST00000711270.1  57213357  57213525
# 1396639  chrY  ENSG00000292371.1  ENST00000711270.1  57213602  57213879
# 1396640  chrY  ENSG00000292371.1  ENST00000711270.1  57213964  57214349
#
#         strand       prev_exon_id       next_exon_id
# 0            +  ENSE00002234944.1  ENSE00003582793.1
# 1            +  ENSE00003582793.1  ENSE00002312635.1
# 2            +  ENSE00001948541.1  ENSE00001671638.2
# 4            +  ENSE00001758273.2  ENSE00001799933.2
# 5            +  ENSE00001799933.2  ENSE00001746346.2
# ...        ...                ...                ...
# 1396636      +  ENSE00004015174.1  ENSE00004015172.1
# 1396637      -  ENSE00004015127.1  ENSE00004015126.1
# 1396638      -  ENSE00004015126.1  ENSE00004015125.1
# 1396639      -  ENSE00004015125.1  ENSE00004015124.1
# 1396640      -  ENSE00004015124.1  ENSE00004015123.1
#
# [402454 rows x 8 columns]

# %%
df_introns = df_introns.drop(columns=["gene_id", "transcript_id", "prev_exon_id", "next_exon_id"])
df_introns
# Out:
#           chr     start       end strand
# 0        chr1     12227     12612      +
# 1        chr1     12721     13220      +
# 2        chr1     12057     12178      +
# 4        chr1     12697     12974      +
# 5        chr1     13052     13220      +
# ...       ...       ...       ...    ...
# 1396636  chrY  57211569  57211760      +
# 1396637  chrY  57213125  57213203      -
# 1396638  chrY  57213357  57213525      -
# 1396639  chrY  57213602  57213879      -
# 1396640  chrY  57213964  57214349      -
#
# [402454 rows x 4 columns]

# %%
df_introns.to_csv("data/1-rmv_dup_introns_gencode_v44.tsv", index=False, sep="\t")

# %% [markdown]
# # Experimental code:

# %%
df_introns = pd.DataFrame(introns_lst.copy())
df_introns

# %%
# df_introns = pd.DataFrame(introns_lst.copy())
df_introns.to_csv("data/gencode_v44_introns.csv", index=False)
df_introns

# %%
df_introns_1_based = df_introns.copy()
df_introns_1_based.intron_start = df_introns_1_based.intron_start + 1
df_introns_1_based

# %%
df_introns_1_based[df_introns_1_based.intron_start == 962048]

# %%
df_introns_1_based[df_introns_1_based.intron_start == 155357520]

# %%
df_introns_1_based[df_introns_1_based.intron_start == 155759144]
