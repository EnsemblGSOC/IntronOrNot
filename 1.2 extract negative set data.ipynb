# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score, roc_auc_score, balanced_accuracy_score, precision_score, matthews_corrcoef, confusion_matrix
from xgboost import XGBClassifier

# %%
df_featurized = pd.read_csv("Featurized_gencode_introns")
df_featurized
# Out:
#        chrom  intron_start  intron_ends strand  Duplicate_Count  \
# 0       chr1         12227        12612      +                2
# 1       chr1         12721        13220      +                1
# 2       chr1         12057        12178      +                1
# 3       chr1         12697        12974      +                1
# 4       chr1         13052        13220      +                1
# ...      ...           ...          ...    ...              ...
# 517017  chrY         15955     57212183      -                1
# 517018  chrY      57213125     57213203      -                1
# 517019  chrY      57213357     57213525      -                1
# 517020  chrY      57213602     57213879      -                1
# 517021  chrY      57213964     57214349      -                1
#
#                                           Repeat_overlaps     GTExv2  \
# 0                                                      []  1122:3199
# 1                                                      []  1791:3198
# 2                                                      []        NaN
# 3                                                      []        1:1
# 4                                                      []      22:24
# ...                                                   ...        ...
# 517017  ['Centromere', 'Dust', 'Low complexity regions...        NaN
# 517018                                                 []        NaN
# 517019                                                 []        NaN
# 517020                                                 []        NaN
# 517021                                                 []        NaN
#
#           TCGAv2       SRAv3h RC3-Splice_site  RC3-Score
# 0       583:1460   9374:54492           GT:AG      59151
# 1       783:1104  14048:56719           GT:AG      61021
# 2            NaN          NaN             NaN         -1
# 3            1:1        15:19           GT:AG         21
# 4          17:18      433:484           GC:AG        526
# ...          ...          ...             ...        ...
# 517017       NaN          NaN             NaN         -1
# 517018       NaN          NaN             NaN         -1
# 517019       NaN          NaN             NaN         -1
# 517020       NaN          NaN             NaN         -1
# 517021       NaN          NaN             NaN         -1
#
# [517022 rows x 11 columns]

# %%
df_original_test = pd.read_csv("ftp-data/gene_annot_test.tsv", sep="\t")
df_original_test
# Out:
#                           coords   outcome   score  length prev_annot  \
# 0          chr1:261635-267302:-1  accepted     888    5668        yes
# 1          chr1:259026-261549:-1  accepted     650    2524        yes
# 2          chr1:732208-739802:-1  rejected       0    7595         no
# 3          chr1:720201-732016:-1  accepted       0   11816        yes
# 4          chr1:711923-720031:-1  accepted      27    8109        yes
# ...                          ...       ...     ...     ...        ...
# 11005   chrY:20582694-20584473:1  accepted  278936    1780        yes
# 11006   chrY:20584525-20588023:1  accepted  286043    3499        yes
# 11007   chrY:20588106-20589483:1  accepted  444721    1378        yes
# 11008   chrY:20589576-20592340:1  accepted  468983    2765        yes
# 11009  chrY:20726098-20734468:-1  accepted       9    8371         no
#
#         transcript_source intron_sources splice_site  \
# 0                  SLRseq        SLR,CLS      GT..AG
# 1                  SLRseq        SLR,CLS      GT..AG
# 2      PacBio Capture-seq            CLS      GT..AG
# 3      PacBio Capture-seq            CLS      GT..AG
# 4      PacBio Capture-seq            CLS      GT..AG
# ...                   ...            ...         ...
# 11005  PacBio Capture-seq    SLR,CLS,RAC      GT..AG
# 11006  PacBio Capture-seq    SLR,CLS,RAC      GT..AG
# 11007  PacBio Capture-seq    SLR,CLS,RAC      GT..AG
# 11008  PacBio Capture-seq    SLR,CLS,RAC      GT..AG
# 11009  PacBio Capture-seq            CLS      GT..AG
#
#                                         repeat_overlap ss_antisense  \
# 0                              Type I Transposons/LINE           no
# 1                              Type I Transposons/LINE           no
# 2                              Type I Transposons/SINE           no
# 3                                  Type II Transposons           no
# 4                                           No overlap           no
# ...                                                ...          ...
# 11005                                       No overlap           no
# 11006                                       No overlap           no
# 11007                                       No overlap           no
# 11008                                       No overlap           no
# 11009  Type I Transposons/LINE,Type I Transposons/SINE           no
#
#         rej_reason annot_match incorrect_locus opp_strand false_ret_int  \
# 0              NaN         yes              no         no            no
# 1              NaN         yes              no         no            no
# 2              NaN          no              no         no            no
# 3              NaN          no              no         no            no
# 4              NaN          no              no         no            no
# ...            ...         ...             ...        ...           ...
# 11005  seq quality         yes              no         no            no
# 11006  seq quality         yes              no         no            no
# 11007  seq quality         yes              no         no            no
# 11008  seq quality         yes              no         no            no
# 11009          NaN          no              no         no            no
#
#             transcript_id                             gtype    bbiotype  \
# 0      OTTHUMT00000499557  transcribed_processed_pseudogene  non-coding
# 1      OTTHUMT00000499557  transcribed_processed_pseudogene  non-coding
# 2      OTTHUMT00000500170  transcribed_processed_pseudogene  non-coding
# 3      OTTHUMT00000500170  transcribed_processed_pseudogene  non-coding
# 4      OTTHUMT00000500170  transcribed_processed_pseudogene  non-coding
# ...                   ...                               ...         ...
# 11005  OTTHUMT00000500440                    protein_coding      coding
# 11006  OTTHUMT00000500440                    protein_coding      coding
# 11007  OTTHUMT00000500440                    protein_coding      coding
# 11008  OTTHUMT00000500440                    protein_coding      coding
# 11009  OTTHUMT00000500305                         comp_pipe       novel
#
#        rel_int_sup  rel_int_sup_k
# 0         0.311999       0.311999
# 1        -0.311999      -0.311999
# 2        -2.525729      -2.708050
# 3        -2.525729      -2.931194
# 4         1.216395       0.810930
# ...            ...            ...
# 11005    -0.141738      -0.364851
# 11006    -0.112146      -0.335259
# 11007     0.433606       0.210496
# 11008     0.503702       0.280593
# 11009          NaN            NaN
#
# [11010 rows x 20 columns]

# %%
df_original_test_rejected = df_original_test[df_original_test.outcome == "rejected"]

# %%
drop_idx_lst = []
append_dict = {}
for index, row in df_original_test_rejected.iterrows():
	coords_split = row.coords.split(":")
	chromosome = coords_split[0]
	start = int(coords_split[1].split("-")[0])
	stop = int(coords_split[1].split("-")[1])
	strand = "+" if coords_split[2] == 1 else "-"

	append_dict


	if not df_featurized[(df_featurized.strand == strand) & (df_featurized.intron_start == start-1) & (df_featurized.intron_ends == stop) & (df_featurized.chrom == chromosome)].empty:
		# print(df_featurized[(df_featurized.strand == strand) & (df_featurized.intron_start == start-1) & (df_featurized.intron_ends == stop) & (df_featurized.chrom == chromosome)])
		drop_idx_lst.append(index)

# %%
# TODO add which rows are dropped for further investigation

# %%
# We drop the introns that has been annotated in the latest version of the read
df_original_test_rejected = df_original_test_rejected.drop(index=drop_idx_lst)
df_original_test_rejected
# Out:
#                             coords   outcome  score  length prev_annot  \
# 2            chr1:732208-739802:-1  rejected      0    7595         no
# 58         chr1:6634785-6634990:-1  rejected      0     206         no
# 71          chr1:9036721-9088663:1  rejected      0   51943         no
# 72          chr1:9088687-9100902:1  rejected      0   12216         no
# 93       chr1:11277019-11277484:-1  rejected      0     466         no
# ...                            ...       ...    ...     ...        ...
# 10972   chrX:151403680-151404937:1  rejected      0    1258         no
# 10973   chrX:151409211-151456968:1  rejected      0   47758         no
# 10977  chrX:153906578-153906694:-1  rejected      0     117         no
# 10978  chrX:153906410-153906520:-1  rejected      0     111         no
# 11004     chrY:20579692-20582591:1  rejected     49    2900         no
#
#         transcript_source intron_sources splice_site           repeat_overlap  \
# 2      PacBio Capture-seq            CLS      GT..AG  Type I Transposons/SINE
# 58                 SLRseq            SLR      GT..AG               No overlap
# 71                 SLRseq            SLR      GT..AG  Type I Transposons/SINE
# 72                 SLRseq            SLR      GC..AG  Type I Transposons/SINE
# 93         PacBio RACEseq            RAC      GC..AG  Type I Transposons/SINE
# ...                   ...            ...         ...                      ...
# 10972              SLRseq            SLR      GC..AG               No overlap
# 10973              SLRseq            SLR      GC..AG  Type I Transposons/SINE
# 10977      PacBio RACEseq            RAC      GC..AG               No overlap
# 10978      PacBio RACEseq            RAC      GT..AG               No overlap
# 11004  PacBio Capture-seq            CLS      GT..AG               No overlap
#
#       ss_antisense               rej_reason annot_match incorrect_locus  \
# 2               no                      NaN          no              no
# 58              no                      NaN          no              no
# 71             yes                      NaN          no              no
# 72             yes                      NaN          no              no
# 93              no                      NaN          no              no
# ...            ...                      ...         ...             ...
# 10972           no                   repeat          no              no
# 10973           no                   repeat          no              no
# 10977          yes  repeat, opposite strand          no              no
# 10978          yes  repeat, opposite strand          no              no
# 11004           no              seq quality         yes              no
#
#       opp_strand false_ret_int       transcript_id  \
# 2             no            no  OTTHUMT00000500170
# 58            no            no  OTTHUMT00000499635
# 71            no            no  OTTHUMT00000498962
# 72            no            no  OTTHUMT00000498962
# 93            no            no  OTTHUMT00000500638
# ...          ...           ...                 ...
# 10972         no            no  OTTHUMT00000498842
# 10973         no            no  OTTHUMT00000498842
# 10977         no            no  OTTHUMT00000500681
# 10978         no            no  OTTHUMT00000500681
# 11004         no            no  OTTHUMT00000500440
#
#                                   gtype    bbiotype  rel_int_sup  \
# 2      transcribed_processed_pseudogene  non-coding    -2.525729
# 58                       protein_coding      coding   -13.164612
# 71                            comp_pipe       novel          NaN
# 72                            comp_pipe       novel          NaN
# 93                 processed_pseudogene  non-coding          NaN
# ...                                 ...         ...          ...
# 10972                    protein_coding      coding   -11.391108
# 10973                    protein_coding      coding   -11.391108
# 10977                         comp_pipe       novel          NaN
# 10978                         comp_pipe       novel          NaN
# 11004                    protein_coding      coding    -8.948679
#
#        rel_int_sup_k
# 2          -2.708050
# 58        -13.164612
# 71               NaN
# 72               NaN
# 93               NaN
# ...              ...
# 10972     -12.084255
# 10973     -12.084255
# 10977            NaN
# 10978            NaN
# 11004      -8.948679
#
# [407 rows x 20 columns]

# %%
df_original_test_rejected
# Out:
#                             coords   outcome  score  length prev_annot  \
# 2            chr1:732208-739802:-1  rejected      0    7595         no
# 58         chr1:6634785-6634990:-1  rejected      0     206         no
# 71          chr1:9036721-9088663:1  rejected      0   51943         no
# 72          chr1:9088687-9100902:1  rejected      0   12216         no
# 93       chr1:11277019-11277484:-1  rejected      0     466         no
# ...                            ...       ...    ...     ...        ...
# 10972   chrX:151403680-151404937:1  rejected      0    1258         no
# 10973   chrX:151409211-151456968:1  rejected      0   47758         no
# 10977  chrX:153906578-153906694:-1  rejected      0     117         no
# 10978  chrX:153906410-153906520:-1  rejected      0     111         no
# 11004     chrY:20579692-20582591:1  rejected     49    2900         no
#
#         transcript_source intron_sources splice_site           repeat_overlap  \
# 2      PacBio Capture-seq            CLS      GT..AG  Type I Transposons/SINE
# 58                 SLRseq            SLR      GT..AG               No overlap
# 71                 SLRseq            SLR      GT..AG  Type I Transposons/SINE
# 72                 SLRseq            SLR      GC..AG  Type I Transposons/SINE
# 93         PacBio RACEseq            RAC      GC..AG  Type I Transposons/SINE
# ...                   ...            ...         ...                      ...
# 10972              SLRseq            SLR      GC..AG               No overlap
# 10973              SLRseq            SLR      GC..AG  Type I Transposons/SINE
# 10977      PacBio RACEseq            RAC      GC..AG               No overlap
# 10978      PacBio RACEseq            RAC      GT..AG               No overlap
# 11004  PacBio Capture-seq            CLS      GT..AG               No overlap
#
#       ss_antisense               rej_reason annot_match incorrect_locus  \
# 2               no                      NaN          no              no
# 58              no                      NaN          no              no
# 71             yes                      NaN          no              no
# 72             yes                      NaN          no              no
# 93              no                      NaN          no              no
# ...            ...                      ...         ...             ...
# 10972           no                   repeat          no              no
# 10973           no                   repeat          no              no
# 10977          yes  repeat, opposite strand          no              no
# 10978          yes  repeat, opposite strand          no              no
# 11004           no              seq quality         yes              no
#
#       opp_strand false_ret_int       transcript_id  \
# 2             no            no  OTTHUMT00000500170
# 58            no            no  OTTHUMT00000499635
# 71            no            no  OTTHUMT00000498962
# 72            no            no  OTTHUMT00000498962
# 93            no            no  OTTHUMT00000500638
# ...          ...           ...                 ...
# 10972         no            no  OTTHUMT00000498842
# 10973         no            no  OTTHUMT00000498842
# 10977         no            no  OTTHUMT00000500681
# 10978         no            no  OTTHUMT00000500681
# 11004         no            no  OTTHUMT00000500440
#
#                                   gtype    bbiotype  rel_int_sup  \
# 2      transcribed_processed_pseudogene  non-coding    -2.525729
# 58                       protein_coding      coding   -13.164612
# 71                            comp_pipe       novel          NaN
# 72                            comp_pipe       novel          NaN
# 93                 processed_pseudogene  non-coding          NaN
# ...                                 ...         ...          ...
# 10972                    protein_coding      coding   -11.391108
# 10973                    protein_coding      coding   -11.391108
# 10977                         comp_pipe       novel          NaN
# 10978                         comp_pipe       novel          NaN
# 11004                    protein_coding      coding    -8.948679
#
#        rel_int_sup_k
# 2          -2.708050
# 58        -13.164612
# 71               NaN
# 72               NaN
# 93               NaN
# ...              ...
# 10972     -12.084255
# 10973     -12.084255
# 10977            NaN
# 10978            NaN
# 11004      -8.948679
#
# [407 rows x 20 columns]

# %%
df_featurized
# Out:
#        chrom  intron_start  intron_ends strand  Duplicate_Count  \
# 0       chr1         12227        12612      +                2
# 1       chr1         12721        13220      +                1
# 2       chr1         12057        12178      +                1
# 3       chr1         12697        12974      +                1
# 4       chr1         13052        13220      +                1
# ...      ...           ...          ...    ...              ...
# 517017  chrY         15955     57212183      -                1
# 517018  chrY      57213125     57213203      -                1
# 517019  chrY      57213357     57213525      -                1
# 517020  chrY      57213602     57213879      -                1
# 517021  chrY      57213964     57214349      -                1
#
#                                           Repeat_overlaps     GTExv2  \
# 0                                                      []  1122:3199
# 1                                                      []  1791:3198
# 2                                                      []        NaN
# 3                                                      []        1:1
# 4                                                      []      22:24
# ...                                                   ...        ...
# 517017  ['Centromere', 'Dust', 'Low complexity regions...        NaN
# 517018                                                 []        NaN
# 517019                                                 []        NaN
# 517020                                                 []        NaN
# 517021                                                 []        NaN
#
#           TCGAv2       SRAv3h RC3-Splice_site  RC3-Score
# 0       583:1460   9374:54492           GT:AG      59151
# 1       783:1104  14048:56719           GT:AG      61021
# 2            NaN          NaN             NaN         -1
# 3            1:1        15:19           GT:AG         21
# 4          17:18      433:484           GC:AG        526
# ...          ...          ...             ...        ...
# 517017       NaN          NaN             NaN         -1
# 517018       NaN          NaN             NaN         -1
# 517019       NaN          NaN             NaN         -1
# 517020       NaN          NaN             NaN         -1
# 517021       NaN          NaN             NaN         -1
#
# [517022 rows x 11 columns]
